# %% [markdown]
# # Fuel assembly: 2G

# %% [markdown]
# ## Import modules

# %%
import sys
import os
import pathlib
import re

import openmc
import openmc.mgxs as mgxs

import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import Counter
from prettytable import PrettyTable

# %% [markdown]
# ## Add location of OpenMC XS executable, setup ENDF xs path

# %%
# Add path to OpenMC binary
# os.environ['PATH'] += r':/path/to/openmc/bin'
#os.environ['PATH'] += r':/Users/jean.ragusa/repo/openmc/local/bin'

# Add location of OpenMC xs data
#%env OPENMC_CROSS_SECTIONS=/Users/jean.ragusa/repo/endfb-vii.1-hdf5/cross_sections.xml

# Are you ragusa?
your_files = os.getcwd()
print(your_files)
if 'ragusa' in your_files:
    os.environ['OPENMC_CROSS_SECTIONS'] = '/home/ragusa/xs/endfb-viii.0-hdf5/cross_sections.xml'
# Out:
# /home/brent10/github/VERA-Examples/Benchmark Problems/2G

# %% [markdown]
# # Start model

# %%
model=openmc.Model()

# %% [markdown]
# ## Define Materials
# ***

# %%
uo2 = openmc.Material(name='uo2')

uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')

uo2.set_density('g/cm3', 10.257 )

uo2.temperature = 600

# %%
zirconium = openmc.Material(name="zirconium")

zirconium.add_nuclide('Zr90',  2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91',  4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92',  7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94',  7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96',  1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112', 4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54',  8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56',  1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57',  3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58',  4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50',  3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52',  6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53',  7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54',  1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')

zirconium.set_density('g/cm3',  6.56)

zirconium.temperature = 600

# %%
water = openmc.Material(name="water")

water.add_nuclide('H1',  4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')

water.add_s_alpha_beta('c_H_in_H2O')

water.set_density('g/cm3', 0.743)

water.temperature=600

# %%
helium = openmc.Material(name="helium")

helium.add_nuclide('He4',1, 'ao')

helium.set_density('g/cm3', 0.178E-03 )

helium.temperature=600

# %%
AIC_mat = openmc.Material(name="AIC_mat")

AIC_mat.add_nuclide('Ag107',2.36159E-02, 'ao')
AIC_mat.add_nuclide('Ag109',2.19403E-02, 'ao')
AIC_mat.add_nuclide('Cd106',3.41523E-05, 'ao')
AIC_mat.add_nuclide('Cd108',2.43165E-05, 'ao')
AIC_mat.add_nuclide('Cd110',3.41250E-04, 'ao')
AIC_mat.add_nuclide('Cd111',3.49720E-04, 'ao')
AIC_mat.add_nuclide('Cd112',6.59276E-04, 'ao')
AIC_mat.add_nuclide('Cd113',3.33873E-04, 'ao')
AIC_mat.add_nuclide('Cd114',7.84957E-04, 'ao')
AIC_mat.add_nuclide('Cd116',2.04641E-04, 'ao')
AIC_mat.add_nuclide('In113',3.44262E-04, 'ao')
AIC_mat.add_nuclide('In115',7.68050E-03, 'ao')

AIC_mat.set_density('g/cm3', 10.2 )

AIC_mat.temperature=600

# %%
SS304 = openmc.Material(name="SS304")

SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')

SS304.set_density('g/cm3', 8.00 )

SS304.temperature=600

# %%
model.materials = openmc.Materials([uo2, zirconium, water,helium,AIC_mat,SS304]) 
print(model.materials)
# Out:
# [Material
# 	ID             =	1
# 	Name           =	uo2
# 	Temperature    =	600
# 	Density        =	10.257 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	True
# 	S(a,b) Tables
# 	Nuclides
# 	U234           =	6.11864e-06  [ao]
# 	U235           =	0.000718132  [ao]
# 	U236           =	3.29861e-06  [ao]
# 	U238           =	0.0221546    [ao]
# 	O16            =	0.0457642    [ao]
# , Material
# 	ID             =	2
# 	Name           =	zirconium
# 	Temperature    =	600
# 	Density        =	6.56 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	False
# 	S(a,b) Tables
# 	Nuclides
# 	Zr90           =	0.0218865    [ao]
# 	Zr91           =	0.00477292   [ao]
# 	Zr92           =	0.00729551   [ao]
# 	Zr94           =	0.00739335   [ao]
# 	Zr96           =	0.0011911    [ao]
# 	Sn112          =	4.68066e-06  [ao]
# 	Sn114          =	3.18478e-06  [ao]
# 	Sn115          =	1.64064e-06  [ao]
# 	Sn116          =	7.01616e-05  [ao]
# 	Sn117          =	3.70592e-05  [ao]
# 	Sn118          =	0.000116872  [ao]
# 	Sn119          =	4.14504e-05  [ao]
# 	Sn120          =	0.000157212  [ao]
# 	Sn122          =	2.23417e-05  [ao]
# 	Sn124          =	2.79392e-05  [ao]
# 	Fe54           =	8.68307e-06  [ao]
# 	Fe56           =	0.000136306  [ao]
# 	Fe57           =	3.14789e-06  [ao]
# 	Fe58           =	4.18926e-07  [ao]
# 	Cr50           =	3.30121e-06  [ao]
# 	Cr52           =	6.36606e-05  [ao]
# 	Cr53           =	7.2186e-06   [ao]
# 	Cr54           =	1.79686e-06  [ao]
# 	Hf174          =	3.54138e-09  [ao]
# 	Hf176          =	1.16423e-07  [ao]
# 	Hf177          =	4.11686e-07  [ao]
# 	Hf178          =	6.03806e-07  [ao]
# 	Hf179          =	3.0146e-07   [ao]
# 	Hf180          =	7.76449e-07  [ao]
# , Material
# 	ID             =	3
# 	Name           =	water
# 	Temperature    =	600
# 	Density        =	0.743 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	False
# 	S(a,b) Tables
# 	S(a,b)         =	('c_H_in_H2O', 1.0)
# 	Nuclides
# 	H1             =	0.0496224    [ao]
# 	O16            =	0.0248112    [ao]
# 	B10            =	1.0707e-05   [ao]
# 	B11            =	4.30971e-05  [ao]
# , Material
# 	ID             =	4
# 	Name           =	helium
# 	Temperature    =	600
# 	Density        =	0.000178 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	False
# 	S(a,b) Tables
# 	Nuclides
# 	He4            =	1            [ao]
# , Material
# 	ID             =	5
# 	Name           =	AIC_mat
# 	Temperature    =	600
# 	Density        =	10.2 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	False
# 	S(a,b) Tables
# 	Nuclides
# 	Ag107          =	0.0236159    [ao]
# 	Ag109          =	0.0219403    [ao]
# 	Cd106          =	3.41523e-05  [ao]
# 	Cd108          =	2.43165e-05  [ao]
# 	Cd110          =	0.00034125   [ao]
# 	Cd111          =	0.00034972   [ao]
# 	Cd112          =	0.000659276  [ao]
# 	Cd113          =	0.000333873  [ao]
# 	Cd114          =	0.000784957  [ao]
# 	Cd116          =	0.000204641  [ao]
# 	In113          =	0.000344262  [ao]
# 	In115          =	0.0076805    [ao]
# , Material
# 	ID             =	6
# 	Name           =	SS304
# 	Temperature    =	600
# 	Density        =	8.0 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	False
# 	S(a,b) Tables
# 	Nuclides
# 	C0             =	0.000320895  [ao]
# 	Si28           =	0.00158197   [ao]
# 	Si29           =	8.03653e-05  [ao]
# 	Si30           =	5.30394e-05  [ao]
# 	P31            =	6.99938e-05  [ao]
# 	Cr50           =	0.000764915  [ao]
# 	Cr52           =	0.0147506    [ao]
# 	Cr53           =	0.0016726    [ao]
# 	Cr54           =	0.000416346  [ao]
# 	Mn55           =	0.00175387   [ao]
# 	Fe54           =	0.00344776   [ao]
# 	Fe56           =	0.0541225    [ao]
# 	Fe57           =	0.00124992   [ao]
# 	Fe58           =	0.000166342  [ao]
# 	Ni58           =	0.00530854   [ao]
# 	Ni60           =	0.00204484   [ao]
# 	Ni61           =	8.88879e-05  [ao]
# 	Ni62           =	0.000283413  [ao]
# 	Ni64           =	7.2177e-05   [ao]
# ]

# %% [markdown]
# ## Define individiual cells
# ***

# %%
# Global surfaces
pitch = 1.26

# Fuel radii
fuel_outer_radius = openmc.ZCylinder(r=0.4096)
clad_inner_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)

# Guide tube radii
gt_inner_radius = openmc.ZCylinder(r=0.561)
gt_outer_radius = openmc.ZCylinder(r=0.602)

# Instrumentation radii
it_inner_radius = openmc.ZCylinder(r=0.559)
it_outer_radius = openmc.ZCylinder(r=0.605)

#AIC
aic_radius= openmc.ZCylinder(r= 0.382)
aic_clad_inner_radius= openmc.ZCylinder(r= 0.386)
aic_clad_outer_radius= openmc.ZCylinder(r= 0.484)

# Universe bounds
left   = openmc.XPlane(-pitch/2, boundary_type='transmission')
right  = openmc.XPlane( pitch/2, boundary_type='transmission')
bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
top    = openmc.YPlane( pitch/2, boundary_type='transmission')

# %% [markdown]
# ### Define pincell universe

# %%
def pincell():

    fuel_region  = -fuel_outer_radius
    gap_region   = +fuel_outer_radius & -clad_inner_radius
    clad_region  = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius

    fuel = openmc.Cell(name='fuel')
    fuel.region = fuel_region
    fuel.fill = uo2
    #new_fuel = uo2.clone()
    #fuel.fill = new_fuel
    
    gap = openmc.Cell(name='gap')
    gap.region = gap_region
    gap.fill = helium     
    
    clad = openmc.Cell(name='clad')
    clad.region = clad_region
    clad.fill = zirconium
    
    moderator = openmc.Cell(name='moderator')
    moderator.region = water_region
    moderator.fill = water
    
    return openmc.Universe(name='pin-univ', cells=(fuel, clad, moderator,gap))

# %% [markdown]
# ### Create instrumentation tube universe

# %%
def instrument():
    
    it_water_in_region  = -it_inner_radius
    it_clad_region      = +it_inner_radius & -it_outer_radius
    it_water_out_region = +it_outer_radius & +left & -right & +bottom & -top
    
    it_water_in = openmc.Cell(name='it-water-in')
    it_water_in.region = it_water_in_region
    it_water_in.fill = water

    it_clad = openmc.Cell(name='it-clad')
    it_clad.region = it_clad_region
    it_clad.fill = zirconium

    it_water_out = openmc.Cell(name='it-water-out')
    it_water_out.region = it_water_out_region
    it_water_out.fill = water

    return openmc.Universe(name='it-univ', cells=(it_water_in, it_clad, it_water_out))

# %%
def aic():

    aic_region= -aic_radius
    water_region = +left & -right & +bottom & -top & +gt_outer_radius | +aic_clad_outer_radius & -gt_inner_radius
    guide_region = +gt_inner_radius & -gt_outer_radius
    steel_region = +aic_clad_inner_radius & -aic_clad_outer_radius
    gap_region = +aic_radius & - aic_clad_inner_radius
     
    steel_cell = openmc.Cell(name='aic_clad')
    steel_cell.fill = SS304
    steel_cell.region = steel_region  
    
    gap_cell = openmc.Cell(name='aic_gap')
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    
    aic_cell = openmc.Cell(name='aic')
    aic_cell.fill = AIC_mat
    aic_cell.region = aic_region  
    
    water_cell = openmc.Cell(name='aic_water')
    water_cell.fill = water
    water_cell.region = water_region
    
    guide_cell = openmc.Cell(name='aic_guide')
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    return openmc.Universe(name='aic-univ', cells=(steel_cell,gap_cell,aic_cell,water_cell,guide_cell))

# %% [markdown]
# ### Generate universes

# %%
pc_univ  = pincell()
it_univ  = instrument()
aic_univ = aic()

# %% [markdown]
# ## Generate assembly
# ***

# %%
height = 10 # height in z-dir
dr = 0.04   # cm of water that is outside assembly
one_eighth = True # either 1/8 or 1/4 of FA

# %%
def read_csv_to_2d_array(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        data = [row for row in reader]
    return np.asarray(data)

def count_frequencies(data):
    flattened_data = [item for row in data for item in row]  # Flatten 2D array into a 1D list
    cell_frequencies = Counter(flattened_data)
    print("cell name frequency:")
    total = 0
    for key, value in cell_frequencies.items():
        print(f'"{key}": {value}')
        total += value
    print("total: ",total)

csv_filepath = 'FA_cell_names_1_family.csv'

lattice_csv = read_csv_to_2d_array(csv_filepath)
count_frequencies(lattice_csv)

if lattice_csv.shape[0] != lattice_csv.shape[1]:
    raise Exception('CSV array of cell names is not square.')
    
size = lattice_csv.shape[0] #size of the assembly
# Out:
# cell name frequency:
# "fu": 264
# "a": 24
# "it": 1
# total:  289

# %% [markdown]
# ### Define assembly lattice

# %%
assembly = openmc.RectLattice()
assembly.pitch = (pitch,pitch)
assembly.lower_left = (-size*pitch/2, -size*pitch/2)

lattice_array = np.empty((size, size), dtype=openmc.universe.Universe)

for row in range(0,lattice_csv.shape[0]):
    for col in range(0,lattice_csv.shape[1]):
        if lattice_csv[row][col] == 'it':
            lattice_array[row][col] = it_univ
        elif lattice_csv[row][col] == 'fu':
            lattice_array[row][col] = pc_univ
        elif lattice_csv[row][col] == 'a':
            lattice_array[row][col] = aic_univ
        else:
            mesg = 'i={},j={},cell-name {} not recognized'.format(col, row, lattice_csv[row][col])
            raise ValueError(mesg)

assembly.universes = lattice_array

# %% [markdown]
# ### Define moderator outside of the assembly

# %%
# create cell that will contain the lattice
moderator_outside_cell = openmc.Cell( name = 'water_outside', fill = water )
assembly.outer = openmc.Universe( name='outer', cells = [moderator_outside_cell] )

# %% [markdown]
# ### Define 1/8 or 1/4 of full assembly

# %%
min_x = openmc.XPlane(x0= 0.               , boundary_type='reflective')
max_x = openmc.XPlane(x0= size*pitch/2+dr  , boundary_type='reflective')
min_y = openmc.YPlane(y0= 0.               , boundary_type='reflective')
max_y = openmc.YPlane(y0= size*pitch/2+dr  , boundary_type='reflective')
min_z = openmc.ZPlane(z0=-height/2         , boundary_type='reflective')
max_z = openmc.ZPlane(z0= height/2         , boundary_type='reflective')
xy    = openmc.Plane(-1., 1.               , boundary_type='reflective')

# define root universe
root_cell = openmc.Cell( name = 'root cell', fill = assembly )

if one_eighth:
    root_cell.region = -max_x & +min_y & -xy
else:
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name = 'root universe', cells=[root_cell])

# %% [markdown]
# ## Plotting

# %%
color_opt = 'material'
root_cell.plot(origin=(5,5,0), pixels=(1500,1500), width=(15,15),color_by=color_opt,outline=True)
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# ##  Settings
# ***

# %%
settings = openmc.Settings()

# %% [markdown]
# ### Source

# %%
bbox = openmc.BoundingBox(lower_left  = [0., 0., -height/2], 
                          upper_right = [size*pitch/2, size*pitch/2, height/2])
uniform_dist = openmc.stats.Box(bbox.lower_left, bbox.upper_right, only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings.source = source
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/stats/multivariate.py:943: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "

# %% [markdown]
# ### Destination path

# %%
my_case = '2g'
my_path = './mgxs_casl_' + my_case

# check if folder exists
path = pathlib.Path(my_path)
path.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ### Batching

# %%
test_mode = False

# %%
# add additional parameters
settings.batches =  150
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies': True, 'path':my_path}
settings.temperature['method'] = 'interpolation'

if test_mode == True:
    settings.batches = 300
    settings.inactive = 50
    settings.particles = 5000
    settings.keff_trigger = {'type':'std_dev','threshold':0.01}

model.settings = settings

# %% [markdown]
# ## Tallies
# ***

# %%
# egroup_name = 'XMAS-172'
egroup_name = 'SHEM-361'
egroup = openmc.mgxs.GROUP_STRUCTURES[egroup_name]

# %% [markdown]
# ### Power Tally

# %%
tally_power = openmc.Tally(name='power')

# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [size, size]
mesh._lower_left = [-size*pitch/2, -size*pitch/2]
mesh._upper_right = [size*pitch/2,  size*pitch/2]

# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)
tally_power.filters = [mesh_filter]

tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']

tallies = openmc.Tallies([tally_power])
# model.tallies=tallies

# %% [markdown]
# ### MGXS Tally

# %%
leg = 7
mgxs_domain = 'cell'

# %%
# Setup MGXS lib
mgxs_lib = openmc.mgxs.Library(model.geometry)
mgxs_lib.energy_groups = openmc.mgxs.EnergyGroups(egroup)
mgxs_lib.scatter_format = "legendre"
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi',
                       'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']

# Legendre order
mgxs_lib.legendre_order = leg
if leg == leg:
    mgxs_lib.correction = None

# No by_nuclide
mgxs_lib.by_nuclide = False

# MGXS domain type
mgxs_lib.domain_type = mgxs_domain
if mgxs_domain == 'cell':
    mgxs_lib.domains = model.geometry.get_all_material_cells().values()
elif mgxs_domain == 'universe':
    mgxs_lib.domains = model.geometry.get_all_universes().values()

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()
mgxs_lib.check_library_for_openmc_mgxs()

mgxs_lib.add_to_tallies_file(tallies, merge=True)

model.tallies = tallies
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 7 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
# trick to make several runs work with jupyter
try:
    sp 
    print('sp found')
    sp.close()
except NameError:
    print('sp NOT found')
# Out:
# sp NOT found

# %%
statepoint_filename = model.run()
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=477.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev2
#      Commit Hash | 3f3649da086fd296cde37dcda9218514f8c16c98
#        Date/Time | 2025-04-05 14:24:47
#   OpenMP Threads | 8
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /home/brent10/nndc_hdf5/neutron/U234.h5
#  Reading U235 from /home/brent10/nndc_hdf5/neutron/U235.h5
#  Reading U236 from /home/brent10/nndc_hdf5/neutron/U236.h5
#  Reading U238 from /home/brent10/nndc_hdf5/neutron/U238.h5
#  Reading O16 from /home/brent10/nndc_hdf5/neutron/O16.h5
#  Reading Zr90 from /home/brent10/nndc_hdf5/neutron/Zr90.h5
#  Reading Zr91 from /home/brent10/nndc_hdf5/neutron/Zr91.h5
#  Reading Zr92 from /home/brent10/nndc_hdf5/neutron/Zr92.h5
#  Reading Zr94 from /home/brent10/nndc_hdf5/neutron/Zr94.h5
#  Reading Zr96 from /home/brent10/nndc_hdf5/neutron/Zr96.h5
#  Reading Sn112 from /home/brent10/nndc_hdf5/neutron/Sn112.h5
#  Reading Sn114 from /home/brent10/nndc_hdf5/neutron/Sn114.h5
#  Reading Sn115 from /home/brent10/nndc_hdf5/neutron/Sn115.h5
#  Reading Sn116 from /home/brent10/nndc_hdf5/neutron/Sn116.h5
#  Reading Sn117 from /home/brent10/nndc_hdf5/neutron/Sn117.h5
#  Reading Sn118 from /home/brent10/nndc_hdf5/neutron/Sn118.h5
#  Reading Sn119 from /home/brent10/nndc_hdf5/neutron/Sn119.h5
#  Reading Sn120 from /home/brent10/nndc_hdf5/neutron/Sn120.h5
#  Reading Sn122 from /home/brent10/nndc_hdf5/neutron/Sn122.h5
#  Reading Sn124 from /home/brent10/nndc_hdf5/neutron/Sn124.h5
#  Reading Fe54 from /home/brent10/nndc_hdf5/neutron/Fe54.h5
#  Reading Fe56 from /home/brent10/nndc_hdf5/neutron/Fe56.h5
#  Reading Fe57 from /home/brent10/nndc_hdf5/neutron/Fe57.h5
#  Reading Fe58 from /home/brent10/nndc_hdf5/neutron/Fe58.h5
#  Reading Cr50 from /home/brent10/nndc_hdf5/neutron/Cr50.h5
#  Reading Cr52 from /home/brent10/nndc_hdf5/neutron/Cr52.h5
#  Reading Cr53 from /home/brent10/nndc_hdf5/neutron/Cr53.h5
#  Reading Cr54 from /home/brent10/nndc_hdf5/neutron/Cr54.h5
#  Reading Hf174 from /home/brent10/nndc_hdf5/neutron/Hf174.h5
#  Reading Hf176 from /home/brent10/nndc_hdf5/neutron/Hf176.h5
#  Reading Hf177 from /home/brent10/nndc_hdf5/neutron/Hf177.h5
#  Reading Hf178 from /home/brent10/nndc_hdf5/neutron/Hf178.h5
#  Reading Hf179 from /home/brent10/nndc_hdf5/neutron/Hf179.h5
#  Reading Hf180 from /home/brent10/nndc_hdf5/neutron/Hf180.h5
#  Reading H1 from /home/brent10/nndc_hdf5/neutron/H1.h5
#  Reading B10 from /home/brent10/nndc_hdf5/neutron/B10.h5
#  Reading B11 from /home/brent10/nndc_hdf5/neutron/B11.h5
#  Reading He4 from /home/brent10/nndc_hdf5/neutron/He4.h5
#  Reading Ag107 from /home/brent10/nndc_hdf5/neutron/Ag107.h5
#  Reading Ag109 from /home/brent10/nndc_hdf5/neutron/Ag109.h5
#  Reading Cd106 from /home/brent10/nndc_hdf5/neutron/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 900K
#  Reading Cd108 from /home/brent10/nndc_hdf5/neutron/Cd108.h5
#  Reading Cd110 from /home/brent10/nndc_hdf5/neutron/Cd110.h5
#  Reading Cd111 from /home/brent10/nndc_hdf5/neutron/Cd111.h5
#  Reading Cd112 from /home/brent10/nndc_hdf5/neutron/Cd112.h5
#  Reading Cd113 from /home/brent10/nndc_hdf5/neutron/Cd113.h5
#  Reading Cd114 from /home/brent10/nndc_hdf5/neutron/Cd114.h5
#  Reading Cd116 from /home/brent10/nndc_hdf5/neutron/Cd116.h5
#  Reading In113 from /home/brent10/nndc_hdf5/neutron/In113.h5
#  Reading In115 from /home/brent10/nndc_hdf5/neutron/In115.h5
#  Reading C0 from /home/brent10/nndc_hdf5/neutron/C0.h5
#  Reading Si28 from /home/brent10/nndc_hdf5/neutron/Si28.h5
#  Reading Si29 from /home/brent10/nndc_hdf5/neutron/Si29.h5
#  Reading Si30 from /home/brent10/nndc_hdf5/neutron/Si30.h5
#  Reading P31 from /home/brent10/nndc_hdf5/neutron/P31.h5
#  Reading Mn55 from /home/brent10/nndc_hdf5/neutron/Mn55.h5
#  Reading Ni58 from /home/brent10/nndc_hdf5/neutron/Ni58.h5
#  Reading Ni60 from /home/brent10/nndc_hdf5/neutron/Ni60.h5
#  Reading Ni61 from /home/brent10/nndc_hdf5/neutron/Ni61.h5
#  Reading Ni62 from /home/brent10/nndc_hdf5/neutron/Ni62.h5
#  Reading Ni64 from /home/brent10/nndc_hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from /home/brent10/nndc_hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 600 K
#  Maximum neutron data temperature: 900 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.83994
#         2/1    0.84703
#         3/1    0.84958
#         4/1    0.84810
#         5/1    0.84292
#         6/1    0.84167
#         7/1    0.84941
#         8/1    0.84408
#         9/1    0.84495
#        10/1    0.84790
#        11/1    0.84430
#        12/1    0.84599
#        13/1    0.85654
#        14/1    0.84687
#        15/1    0.85323
#        16/1    0.85600
#        17/1    0.85504
#        18/1    0.85628
#        19/1    0.85799
#        20/1    0.85495
#        21/1    0.85904
#        22/1    0.84900    0.85402 +/- 0.00502
#        23/1    0.84900    0.85235 +/- 0.00335
#        24/1    0.84382    0.85022 +/- 0.00319
#        25/1    0.84575    0.84932 +/- 0.00262
#        26/1    0.85226    0.84981 +/- 0.00220
#        27/1    0.84993    0.84983 +/- 0.00186
#        28/1    0.84232    0.84889 +/- 0.00186
#        29/1    0.84382    0.84833 +/- 0.00174
#        30/1    0.84734    0.84823 +/- 0.00156
#        31/1    0.85043    0.84843 +/- 0.00142
#        32/1    0.84197    0.84789 +/- 0.00141
#        33/1    0.85442    0.84839 +/- 0.00139
#        34/1    0.85204    0.84865 +/- 0.00131
#        35/1    0.84482    0.84840 +/- 0.00125
#        36/1    0.84962    0.84847 +/- 0.00117
#        37/1    0.85895    0.84909 +/- 0.00126
#        38/1    0.83543    0.84833 +/- 0.00141
#        39/1    0.85413    0.84864 +/- 0.00137
#        40/1    0.84248    0.84833 +/- 0.00133
#        41/1    0.84879    0.84835 +/- 0.00127
#        42/1    0.84979    0.84842 +/- 0.00121
#        43/1    0.85105    0.84853 +/- 0.00116
#        44/1    0.84603    0.84843 +/- 0.00112
#        45/1    0.84729    0.84838 +/- 0.00107
#        46/1    0.83994    0.84806 +/- 0.00108
#        47/1    0.84355    0.84789 +/- 0.00105
#        48/1    0.83667    0.84749 +/- 0.00109
#        49/1    0.85269    0.84767 +/- 0.00107
#        50/1    0.84631    0.84762 +/- 0.00103
#        51/1    0.84742    0.84762 +/- 0.00100
#        52/1    0.84531    0.84754 +/- 0.00097
#        53/1    0.85662    0.84782 +/- 0.00098
#        54/1    0.84166    0.84764 +/- 0.00097
#        55/1    0.85036    0.84772 +/- 0.00094
#        56/1    0.84523    0.84765 +/- 0.00092
#        57/1    0.85219    0.84777 +/- 0.00090
#        58/1    0.84677    0.84774 +/- 0.00088
#        59/1    0.84420    0.84765 +/- 0.00086
#        60/1    0.84452    0.84757 +/- 0.00084
#        61/1    0.84399    0.84749 +/- 0.00083
#        62/1    0.84659    0.84747 +/- 0.00081
#        63/1    0.85275    0.84759 +/- 0.00080
#        64/1    0.84020    0.84742 +/- 0.00080
#        65/1    0.84467    0.84736 +/- 0.00078
#        66/1    0.84410    0.84729 +/- 0.00077
#        67/1    0.84716    0.84729 +/- 0.00075
#        68/1    0.85001    0.84734 +/- 0.00074
#        69/1    0.83776    0.84715 +/- 0.00075
#        70/1    0.84781    0.84716 +/- 0.00073
#        71/1    0.84184    0.84706 +/- 0.00073
#        72/1    0.84486    0.84701 +/- 0.00071
#        73/1    0.85180    0.84710 +/- 0.00071
#        74/1    0.84823    0.84712 +/- 0.00069
#        75/1    0.85392    0.84725 +/- 0.00069
#        76/1    0.85891    0.84746 +/- 0.00071
#        77/1    0.84309    0.84738 +/- 0.00070
#        78/1    0.84547    0.84735 +/- 0.00069
#        79/1    0.84535    0.84731 +/- 0.00068
#        80/1    0.84923    0.84734 +/- 0.00067
#        81/1    0.84483    0.84730 +/- 0.00066
#        82/1    0.84409    0.84725 +/- 0.00065
#        83/1    0.84435    0.84721 +/- 0.00064
#        84/1    0.84787    0.84722 +/- 0.00063
#        85/1    0.85292    0.84730 +/- 0.00063
#        86/1    0.84493    0.84727 +/- 0.00062
#        87/1    0.84475    0.84723 +/- 0.00061
#        88/1    0.84636    0.84722 +/- 0.00060
#        89/1    0.84263    0.84715 +/- 0.00060
#        90/1    0.84756    0.84716 +/- 0.00059
#        91/1    0.83686    0.84701 +/- 0.00060
#        92/1    0.84870    0.84704 +/- 0.00059
#        93/1    0.84201    0.84697 +/- 0.00059
#        94/1    0.85195    0.84703 +/- 0.00058
#        95/1    0.84323    0.84698 +/- 0.00058
#        96/1    0.83976    0.84689 +/- 0.00058
#        97/1    0.84101    0.84681 +/- 0.00057
#        98/1    0.85046    0.84686 +/- 0.00057
#        99/1    0.83733    0.84674 +/- 0.00057
#       100/1    0.84421    0.84671 +/- 0.00057
#       101/1    0.84947    0.84674 +/- 0.00056
#       102/1    0.84799    0.84676 +/- 0.00055
#       103/1    0.85120    0.84681 +/- 0.00055
#       104/1    0.84990    0.84685 +/- 0.00055
#       105/1    0.85063    0.84689 +/- 0.00054
#       106/1    0.85403    0.84697 +/- 0.00054
#       107/1    0.85186    0.84703 +/- 0.00054
#       108/1    0.85318    0.84710 +/- 0.00054
#       109/1    0.84436    0.84707 +/- 0.00053
#       110/1    0.85223    0.84713 +/- 0.00053
#       111/1    0.84996    0.84716 +/- 0.00052
#       112/1    0.85021    0.84719 +/- 0.00052
#       113/1    0.85292    0.84725 +/- 0.00052
#       114/1    0.84659    0.84725 +/- 0.00051
#       115/1    0.84583    0.84723 +/- 0.00051
#       116/1    0.84535    0.84721 +/- 0.00050
#       117/1    0.85077    0.84725 +/- 0.00050
#       118/1    0.84957    0.84727 +/- 0.00049
#       119/1    0.85706    0.84737 +/- 0.00050
#       120/1    0.85179    0.84741 +/- 0.00049
#       121/1    0.84777    0.84742 +/- 0.00049
#       122/1    0.85036    0.84745 +/- 0.00049
#       123/1    0.84219    0.84740 +/- 0.00048
#       124/1    0.85766    0.84749 +/- 0.00049
#       125/1    0.84411    0.84746 +/- 0.00049
#       126/1    0.83922    0.84738 +/- 0.00049
#       127/1    0.85198    0.84743 +/- 0.00048
#       128/1    0.85096    0.84746 +/- 0.00048
#       129/1    0.83986    0.84739 +/- 0.00048
#       130/1    0.84590    0.84738 +/- 0.00048
#       131/1    0.85361    0.84743 +/- 0.00048
#       132/1    0.84900    0.84745 +/- 0.00047
#       133/1    0.83977    0.84738 +/- 0.00047
#       134/1    0.84138    0.84733 +/- 0.00047
#       135/1    0.85082    0.84736 +/- 0.00047
#       136/1    0.84959    0.84738 +/- 0.00047
#       137/1    0.85327    0.84743 +/- 0.00046
#       138/1    0.84295    0.84739 +/- 0.00046
#       139/1    0.84272    0.84735 +/- 0.00046
#       140/1    0.84546    0.84733 +/- 0.00046
#       141/1    0.84903    0.84735 +/- 0.00045
#       142/1    0.84369    0.84732 +/- 0.00045
#       143/1    0.84498    0.84730 +/- 0.00045
#       144/1    0.85025    0.84732 +/- 0.00044
#       145/1    0.84297    0.84729 +/- 0.00044
#       146/1    0.84309    0.84725 +/- 0.00044
#       147/1    0.84595    0.84724 +/- 0.00044
#       148/1    0.85290    0.84729 +/- 0.00043
#       149/1    0.84304    0.84726 +/- 0.00043
#       150/1    0.84769    0.84726 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.3936657776339 for eigenvalue
#  The estimated number of batches is 1518
#  Creating state point ./mgxs_casl_2g/statepoint.00150.h5...
#       151/1    0.85204    0.84729 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.4224995903019475 for eigenvalue
#  The estimated number of batches is 1555
#       152/1    0.85275    0.84734 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.3935688917111095 for eigenvalue
#  The estimated number of batches is 1541
#       153/1    0.85077    0.84736 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.3603928423088076 for eigenvalue
#  The estimated number of batches is 1522
#       154/1    0.83722    0.84729 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.3564500751389765 for eigenvalue
#  The estimated number of batches is 1530
#       155/1    0.84973    0.84730 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.3294584898863486 for eigenvalue
#  The estimated number of batches is 1517
#       156/1    0.85275    0.84734 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.326029823991316 for eigenvalue
#  The estimated number of batches is 1525
#       157/1    0.84772    0.84735 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.3006711577469523 for eigenvalue
#  The estimated number of batches is 1513
#       158/1    0.84647    0.84734 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2795489562236617 for eigenvalue
#  The estimated number of batches is 1505
#       159/1    0.84318    0.84731 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.266269125065656 for eigenvalue
#  The estimated number of batches is 1503
#       160/1    0.85048    0.84733 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.23991384627582 for eigenvalue
#  The estimated number of batches is 1490
#       161/1    0.85730    0.84740 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.246348373345259 for eigenvalue
#  The estimated number of batches is 1506
#       162/1    0.85372    0.84745 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.243975823127508 for eigenvalue
#  The estimated number of batches is 1515
#       163/1    0.84253    0.84741 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.2659633912100205 for eigenvalue
#  The estimated number of batches is 1546
#       164/1    0.84917    0.84743 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.248721306104831 for eigenvalue
#  The estimated number of batches is 1540
#       165/1    0.84076    0.84738 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.2358472676966916 for eigenvalue
#  The estimated number of batches is 1539
#       166/1    0.84169    0.84734 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.2189563409970625 for eigenvalue
#  The estimated number of batches is 1533
#       167/1    0.85240    0.84738 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.219088073504231 for eigenvalue
#  The estimated number of batches is 1544
#       168/1    0.84721    0.84737 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.198510080548361 for eigenvalue
#  The estimated number of batches is 1535
#       169/1    0.84878    0.84738 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1799483780393643 for eigenvalue
#  The estimated number of batches is 1527
#       170/1    0.84750    0.84739 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.158603330320689 for eigenvalue
#  The estimated number of batches is 1517
#       171/1    0.85040    0.84741 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1394581193324846 for eigenvalue
#  The estimated number of batches is 1509
#       172/1    0.84435    0.84739 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.133822035902395 for eigenvalue
#  The estimated number of batches is 1513
#       173/1    0.84573    0.84737 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.116743513180203 for eigenvalue
#  The estimated number of batches is 1507
#       174/1    0.84388    0.84735 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0994433636393666 for eigenvalue
#  The estimated number of batches is 1500
#       175/1    0.84788    0.84735 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.079133627298301 for eigenvalue
#  The estimated number of batches is 1490
#       176/1    0.84879    0.84736 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0705851230796353 for eigenvalue
#  The estimated number of batches is 1491
#       177/1    0.84817    0.84737 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.0584314956220107 for eigenvalue
#  The estimated number of batches is 1489
#       178/1    0.84411    0.84735 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.0418948611165457 for eigenvalue
#  The estimated number of batches is 1482
#       179/1    0.84393    0.84733 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.026795437380914 for eigenvalue
#  The estimated number of batches is 1477
#       180/1    0.84661    0.84732 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.0082776132442284 for eigenvalue
#  The estimated number of batches is 1468
#       181/1    0.84778    0.84733 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.989831961794565 for eigenvalue
#  The estimated number of batches is 1460
#       182/1    0.84854    0.84733 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9833183776473553 for eigenvalue
#  The estimated number of batches is 1462
#       183/1    0.84237    0.84730 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9801141821281076 for eigenvalue
#  The estimated number of batches is 1468
#       184/1    0.84248    0.84727 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.985755524902878 for eigenvalue
#  The estimated number of batches is 1483
#       185/1    0.84512    0.84726 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.971654483007124 for eigenvalue
#  The estimated number of batches is 1478
#       186/1    0.85790    0.84732 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.974435998269667 for eigenvalue
#  The estimated number of batches is 1489
#       187/1    0.84438    0.84731 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9585261656546895 for eigenvalue
#  The estimated number of batches is 1482
#       188/1    0.85160    0.84733 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.979229318506655 for eigenvalue
#  The estimated number of batches is 1512
#       189/1    0.85253    0.84736 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.959986721124027 for eigenvalue
#  The estimated number of batches is 1501
#       190/1    0.83771    0.84731 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9518590364073383 for eigenvalue
#  The estimated number of batches is 1502
#       191/1    0.84819    0.84731 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9344774285843465 for eigenvalue
#  The estimated number of batches is 1493
#       192/1    0.85154    0.84734 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9172445999744 for eigenvalue
#  The estimated number of batches is 1484
#       193/1    0.84304    0.84731 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.914955593341595 for eigenvalue
#  The estimated number of batches is 1490
#       194/1    0.85835    0.84737 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9239027909498643 for eigenvalue
#  The estimated number of batches is 1508
#       195/1    0.84521    0.84736 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.909193566373018 for eigenvalue
#  The estimated number of batches is 1502
#       196/1    0.84962    0.84737 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8970241713865863 for eigenvalue
#  The estimated number of batches is 1498
#       197/1    0.84389    0.84736 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.8876403004216677 for eigenvalue
#  The estimated number of batches is 1496
#       198/1    0.84908    0.84736 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.8757234158360885 for eigenvalue
#  The estimated number of batches is 1493
#       199/1    0.84868    0.84737 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.8604635111153156 for eigenvalue
#  The estimated number of batches is 1485
#       200/1    0.84771    0.84737 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.8442492861088713 for eigenvalue
#  The estimated number of batches is 1477
#       201/1    0.84363    0.84735 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.8346026752598306 for eigenvalue
#  The estimated number of batches is 1475
#       202/1    0.84436    0.84734 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.821019070712783 for eigenvalue
#  The estimated number of batches is 1469
#       203/1    0.85023    0.84735 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.8110219122160496 for eigenvalue
#  The estimated number of batches is 1467
#       204/1    0.84504    0.84734 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7964563641839026 for eigenvalue
#  The estimated number of batches is 1459
#       205/1    0.84200    0.84731 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7894773722000874 for eigenvalue
#  The estimated number of batches is 1460
#       206/1    0.85234    0.84734 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.768614681383413 for eigenvalue
#  The estimated number of batches is 1446
#       207/1    0.84862    0.84735 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.753210305144472 for eigenvalue
#  The estimated number of batches is 1438
#       208/1    0.85278    0.84737 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.742718709364482 for eigenvalue
#  The estimated number of batches is 1435
#       209/1    0.84900    0.84738 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7272512765190235 for eigenvalue
#  The estimated number of batches is 1426
#       210/1    0.84434    0.84737 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.7143431539000686 for eigenvalue
#  The estimated number of batches is 1420
#       211/1    0.85481    0.84741 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7149315820732682 for eigenvalue
#  The estimated number of batches is 1428
#       212/1    0.85247    0.84743 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6993531156892163 for eigenvalue
#  The estimated number of batches is 1420
#       213/1    0.84588    0.84742 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6861928814231684 for eigenvalue
#  The estimated number of batches is 1413
#       214/1    0.85114    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.691463459208897 for eigenvalue
#  The estimated number of batches is 1426
#       215/1    0.85142    0.84746 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.680259164647016 for eigenvalue
#  The estimated number of batches is 1421
#       216/1    0.84096    0.84743 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.675784147517705 for eigenvalue
#  The estimated number of batches is 1424
#       217/1    0.85555    0.84747 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.676235490206434 for eigenvalue
#  The estimated number of batches is 1431
#       218/1    0.85168    0.84749 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.662440627647629 for eigenvalue
#  The estimated number of batches is 1424
#       219/1    0.84326    0.84747 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6683537110755613 for eigenvalue
#  The estimated number of batches is 1437
#       220/1    0.84852    0.84748 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.653998021572724 for eigenvalue
#  The estimated number of batches is 1429
#       221/1    0.84717    0.84748 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6407553641737938 for eigenvalue
#  The estimated number of batches is 1422
#       222/1    0.84613    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6287288892787837 for eigenvalue
#  The estimated number of batches is 1416
#       223/1    0.85169    0.84749 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.616719663771857 for eigenvalue
#  The estimated number of batches is 1410
#       224/1    0.83707    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6357014243881585 for eigenvalue
#  The estimated number of batches is 1438
#       225/1    0.84909    0.84745 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6193117942551316 for eigenvalue
#  The estimated number of batches is 1427
#       226/1    0.84132    0.84742 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.610900817770406 for eigenvalue
#  The estimated number of batches is 1425
#       227/1    0.84488    0.84740 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6010212026113666 for eigenvalue
#  The estimated number of batches is 1421
#       228/1    0.84686    0.84740 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5908746142913017 for eigenvalue
#  The estimated number of batches is 1417
#       229/1    0.84191    0.84738 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5959132197652495 for eigenvalue
#  The estimated number of batches is 1429
#       230/1    0.84823    0.84738 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5857709369329824 for eigenvalue
#  The estimated number of batches is 1425
#       231/1    0.85165    0.84740 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5902429686755353 for eigenvalue
#  The estimated number of batches is 1436
#       232/1    0.85143    0.84742 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5983777124335403 for eigenvalue
#  The estimated number of batches is 1452
#       233/1    0.85564    0.84746 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5906063214106867 for eigenvalue
#  The estimated number of batches is 1450
#       234/1    0.84928    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.583080534446744 for eigenvalue
#  The estimated number of batches is 1448
#       235/1    0.84305    0.84745 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.573229793973556 for eigenvalue
#  The estimated number of batches is 1444
#       236/1    0.84809    0.84745 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.56179148099461 for eigenvalue
#  The estimated number of batches is 1438
#       237/1    0.85199    0.84747 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5477629484293334 for eigenvalue
#  The estimated number of batches is 1429
#       238/1    0.85024    0.84748 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.538860140396234 for eigenvalue
#  The estimated number of batches is 1426
#       239/1    0.85488    0.84752 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5392047912942886 for eigenvalue
#  The estimated number of batches is 1433
#       240/1    0.84369    0.84750 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5391727120123306 for eigenvalue
#  The estimated number of batches is 1439
#       241/1    0.85289    0.84752 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5311000778420167 for eigenvalue
#  The estimated number of batches is 1436
#       242/1    0.85185    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.543471579829052 for eigenvalue
#  The estimated number of batches is 1457
#       243/1    0.85167    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.529582293201666 for eigenvalue
#  The estimated number of batches is 1447
#       244/1    0.83633    0.84751 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.532808033626542 for eigenvalue
#  The estimated number of batches is 1457
#       245/1    0.85568    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.535029068660047 for eigenvalue
#  The estimated number of batches is 1466
#       246/1    0.85365    0.84757 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5199687205357506 for eigenvalue
#  The estimated number of batches is 1456
#       247/1    0.84140    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5146283516758428 for eigenvalue
#  The estimated number of batches is 1456
#       248/1    0.85165    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5035961916745304 for eigenvalue
#  The estimated number of batches is 1450
#       249/1    0.84581    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4958766895737936 for eigenvalue
#  The estimated number of batches is 1447
#       250/1    0.84628    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4853890046133733 for eigenvalue
#  The estimated number of batches is 1441
#       251/1    0.84667    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4765733572933835 for eigenvalue
#  The estimated number of batches is 1437
#       252/1    0.85130    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4629762094721173 for eigenvalue
#  The estimated number of batches is 1428
#       253/1    0.85012    0.84758 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4587996250235165 for eigenvalue
#  The estimated number of batches is 1429
#       254/1    0.84977    0.84758 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4464423395382657 for eigenvalue
#  The estimated number of batches is 1421
#       255/1    0.84136    0.84756 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.441267241976688 for eigenvalue
#  The estimated number of batches is 1421
#       256/1    0.84364    0.84754 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4357313165201844 for eigenvalue
#  The estimated number of batches is 1421
#       257/1    0.85424    0.84757 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4291673983237874 for eigenvalue
#  The estimated number of batches is 1419
#       258/1    0.84530    0.84756 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.420671803808404 for eigenvalue
#  The estimated number of batches is 1415
#       259/1    0.85579    0.84759 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4334033373997515 for eigenvalue
#  The estimated number of batches is 1436
#       260/1    0.84351    0.84758 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4311805433464473 for eigenvalue
#  The estimated number of batches is 1439
#       261/1    0.84288    0.84756 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.431093683307729 for eigenvalue
#  The estimated number of batches is 1445
#       262/1    0.84279    0.84754 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4239198649710185 for eigenvalue
#  The estimated number of batches is 1442
#       263/1    0.85691    0.84758 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4193377965010763 for eigenvalue
#  The estimated number of batches is 1443
#       264/1    0.85509    0.84761 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.429307532024947 for eigenvalue
#  The estimated number of batches is 1460
#       265/1    0.84998    0.84762 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.417489381722495 for eigenvalue
#  The estimated number of batches is 1452
#       266/1    0.85432    0.84764 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.406938109548447 for eigenvalue
#  The estimated number of batches is 1446
#       267/1    0.85820    0.84769 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.443531697360009 for eigenvalue
#  The estimated number of batches is 1495
#       268/1    0.85200    0.84770 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.432316845557498 for eigenvalue
#  The estimated number of batches is 1488
#       269/1    0.85003    0.84771 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.422796976160669 for eigenvalue
#  The estimated number of batches is 1482
#       270/1    0.84717    0.84771 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4119602662278568 for eigenvalue
#  The estimated number of batches is 1475
#       271/1    0.84322    0.84769 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.409013860800801 for eigenvalue
#  The estimated number of batches is 1477
#       272/1    0.85529    0.84772 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.403311422503265 for eigenvalue
#  The estimated number of batches is 1476
#       273/1    0.85322    0.84775 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.397059379064299 for eigenvalue
#  The estimated number of batches is 1474
#       274/1    0.84747    0.84774 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.386672712784571 for eigenvalue
#  The estimated number of batches is 1467
#       275/1    0.84694    0.84774 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.379325434660003 for eigenvalue
#  The estimated number of batches is 1464
#       276/1    0.84524    0.84773 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3750075590259865 for eigenvalue
#  The estimated number of batches is 1465
#       277/1    0.84582    0.84772 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3685185824663773 for eigenvalue
#  The estimated number of batches is 1462
#       278/1    0.84747    0.84772 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3591492020286893 for eigenvalue
#  The estimated number of batches is 1456
#       279/1    0.83977    0.84769 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.353037775686284 for eigenvalue
#  The estimated number of batches is 1455
#       280/1    0.84513    0.84768 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.344251844181218 for eigenvalue
#  The estimated number of batches is 1449
#       281/1    0.84772    0.84768 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3360687449042405 for eigenvalue
#  The estimated number of batches is 1445
#       282/1    0.84263    0.84766 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.334950026925652 for eigenvalue
#  The estimated number of batches is 1449
#       283/1    0.84719    0.84766 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3263406845432097 for eigenvalue
#  The estimated number of batches is 1444
#       284/1    0.85410    0.84769 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3152033819964504 for eigenvalue
#  The estimated number of batches is 1436
#       285/1    0.85165    0.84770 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3063766149637477 for eigenvalue
#  The estimated number of batches is 1430
#       286/1    0.84302    0.84768 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3005943681122116 for eigenvalue
#  The estimated number of batches is 1428
#       287/1    0.83337    0.84763 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.308614874846201 for eigenvalue
#  The estimated number of batches is 1444
#       288/1    0.84807    0.84763 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.300149514461748 for eigenvalue
#  The estimated number of batches is 1438
#       289/1    0.84992    0.84764 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.2967487729893143 for eigenvalue
#  The estimated number of batches is 1439
#       290/1    0.85022    0.84765 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.2905210921109846 for eigenvalue
#  The estimated number of batches is 1437
#       291/1    0.84161    0.84763 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.2838739138823834 for eigenvalue
#  The estimated number of batches is 1434
#       292/1    0.85275    0.84765 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.275915716238125 for eigenvalue
#  The estimated number of batches is 1429
#       293/1    0.84324    0.84763 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.272355604703349 for eigenvalue
#  The estimated number of batches is 1430
#       294/1    0.84795    0.84763 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.264102878400724 for eigenvalue
#  The estimated number of batches is 1425
#       295/1    0.85054    0.84764 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.255548824087893 for eigenvalue
#  The estimated number of batches is 1420
#       296/1    0.84716    0.84764 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2495218170158853 for eigenvalue
#  The estimated number of batches is 1417
#       297/1    0.85124    0.84765 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2422193537275006 for eigenvalue
#  The estimated number of batches is 1413
#       298/1    0.84498    0.84764 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.234492060416173 for eigenvalue
#  The estimated number of batches is 1409
#       299/1    0.83943    0.84761 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.241466069327893 for eigenvalue
#  The estimated number of batches is 1422
#       300/1    0.84753    0.84761 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2334172694248067 for eigenvalue
#  The estimated number of batches is 1417
#       301/1    0.84174    0.84759 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2290670801234467 for eigenvalue
#  The estimated number of batches is 1417
#       302/1    0.84875    0.84760 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.220916018391982 for eigenvalue
#  The estimated number of batches is 1411
#       303/1    0.85167    0.84761 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2127193854286475 for eigenvalue
#  The estimated number of batches is 1406
#       304/1    0.85162    0.84763 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2028333055207105 for eigenvalue
#  The estimated number of batches is 1399
#       305/1    0.84703    0.84762 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.195602864870805 for eigenvalue
#  The estimated number of batches is 1394
#       306/1    0.84672    0.84762 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.193806855677653 for eigenvalue
#  The estimated number of batches is 1397
#       307/1    0.84940    0.84763 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1868462837323532 for eigenvalue
#  The estimated number of batches is 1393
#       308/1    0.85074    0.84764 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.179324290861047 for eigenvalue
#  The estimated number of batches is 1388
#       309/1    0.85152    0.84765 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.170944289134499 for eigenvalue
#  The estimated number of batches is 1383
#       310/1    0.84019    0.84762 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.187383607355049 for eigenvalue
#  The estimated number of batches is 1408
#       311/1    0.84806    0.84763 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1817761989628726 for eigenvalue
#  The estimated number of batches is 1406
#       312/1    0.83959    0.84760 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1926748898040427 for eigenvalue
#  The estimated number of batches is 1424
#       313/1    0.84234    0.84758 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.186108390745698 for eigenvalue
#  The estimated number of batches is 1421
#       314/1    0.84139    0.84756 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1807758826477825 for eigenvalue
#  The estimated number of batches is 1419
#       315/1    0.85130    0.84757 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1839629839742085 for eigenvalue
#  The estimated number of batches is 1428
#       316/1    0.84450    0.84756 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1793897514495426 for eigenvalue
#  The estimated number of batches is 1426
#       317/1    0.84543    0.84756 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1730240573050863 for eigenvalue
#  The estimated number of batches is 1423
#       318/1    0.84990    0.84756 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1697938869153033 for eigenvalue
#  The estimated number of batches is 1423
#       319/1    0.85115    0.84757 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1618262739521676 for eigenvalue
#  The estimated number of batches is 1418
#       320/1    0.83925    0.84755 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1630384835641454 for eigenvalue
#  The estimated number of batches is 1424
#       321/1    0.84490    0.84754 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1571031817697 for eigenvalue
#  The estimated number of batches is 1421
#       322/1    0.85052    0.84755 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.148018716040781 for eigenvalue
#  The estimated number of batches is 1414
#       323/1    0.84529    0.84754 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1433529524543737 for eigenvalue
#  The estimated number of batches is 1412
#       324/1    0.84407    0.84753 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1378032396408186 for eigenvalue
#  The estimated number of batches is 1410
#       325/1    0.84693    0.84753 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1331235967277746 for eigenvalue
#  The estimated number of batches is 1408
#       326/1    0.84379    0.84752 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1303366694647012 for eigenvalue
#  The estimated number of batches is 1409
#       327/1    0.85535    0.84754 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1270756602706142 for eigenvalue
#  The estimated number of batches is 1410
#       328/1    0.85099    0.84755 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1193637901619797 for eigenvalue
#  The estimated number of batches is 1404
#       329/1    0.84436    0.84754 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1129576766554514 for eigenvalue
#  The estimated number of batches is 1400
#       330/1    0.84600    0.84754 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.113343523173485 for eigenvalue
#  The estimated number of batches is 1405
#       331/1    0.84910    0.84754 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.106401663919897 for eigenvalue
#  The estimated number of batches is 1400
#       332/1    0.85592    0.84757 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.114238905620379 for eigenvalue
#  The estimated number of batches is 1415
#       333/1    0.84924    0.84757 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.11077598900995 for eigenvalue
#  The estimated number of batches is 1415
#       334/1    0.84096    0.84755 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.105773852657897 for eigenvalue
#  The estimated number of batches is 1413
#       335/1    0.84856    0.84756 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.10068235698898 for eigenvalue
#  The estimated number of batches is 1411
#       336/1    0.84580    0.84755 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0957175408183444 for eigenvalue
#  The estimated number of batches is 1408
#       337/1    0.84537    0.84754 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0908756445244236 for eigenvalue
#  The estimated number of batches is 1406
#       338/1    0.85427    0.84756 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.083995346096615 for eigenvalue
#  The estimated number of batches is 1402
#       339/1    0.85508    0.84759 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0812372229900817 for eigenvalue
#  The estimated number of batches is 1402
#       340/1    0.84544    0.84758 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0767464550842387 for eigenvalue
#  The estimated number of batches is 1401
#       341/1    0.85526    0.84761 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0693348913964895 for eigenvalue
#  The estimated number of batches is 1395
#       342/1    0.84423    0.84759 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0646537956714033 for eigenvalue
#  The estimated number of batches is 1393
#       343/1    0.85350    0.84761 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0613461504112593 for eigenvalue
#  The estimated number of batches is 1393
#       344/1    0.84794    0.84761 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0546722801804447 for eigenvalue
#  The estimated number of batches is 1388
#       345/1    0.84436    0.84760 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.049875947230668 for eigenvalue
#  The estimated number of batches is 1386
#       346/1    0.84637    0.84760 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0452609561470703 for eigenvalue
#  The estimated number of batches is 1384
#       347/1    0.85207    0.84761 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0392659737460077 for eigenvalue
#  The estimated number of batches is 1380
#       348/1    0.84995    0.84762 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.032938083365922 for eigenvalue
#  The estimated number of batches is 1376
#       349/1    0.85101    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.025799743621978 for eigenvalue
#  The estimated number of batches is 1371
#       350/1    0.85203    0.84764 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0285286037798875 for eigenvalue
#  The estimated number of batches is 1378
#       351/1    0.84436    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0247803604312664 for eigenvalue
#  The estimated number of batches is 1378
#       352/1    0.85050    0.84764 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0232260954900503 for eigenvalue
#  The estimated number of batches is 1380
#       353/1    0.84731    0.84764 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0176800207913144 for eigenvalue
#  The estimated number of batches is 1376
#       354/1    0.84342    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0125995727386607 for eigenvalue
#  The estimated number of batches is 1373
#       355/1    0.84605    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.007641902567806 for eigenvalue
#  The estimated number of batches is 1371
#       356/1    0.84778    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 2.0031902974887785 for eigenvalue
#  The estimated number of batches is 1369
#       357/1    0.84999    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9969744177087834 for eigenvalue
#  The estimated number of batches is 1364
#       358/1    0.84721    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9925551696854795 for eigenvalue
#  The estimated number of batches is 1362
#       359/1    0.85149    0.84764 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9874722665833502 for eigenvalue
#  The estimated number of batches is 1360
#       360/1    0.84195    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9831249331399825 for eigenvalue
#  The estimated number of batches is 1358
#       361/1    0.84758    0.84763 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9772096389684017 for eigenvalue
#  The estimated number of batches is 1354
#       362/1    0.85214    0.84764 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.972343539229665 for eigenvalue
#  The estimated number of batches is 1351
#       363/1    0.84169    0.84762 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.9718700099651574 for eigenvalue
#  The estimated number of batches is 1354
#       364/1    0.84694    0.84762 +/- 0.00025
# ...
#      1547/1    1.17729    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0301035963435026 for eigenvalue
#  The estimated number of batches is 1641
#      1548/1    1.18031    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0300538740818195 for eigenvalue
#  The estimated number of batches is 1642
#      1549/1    1.18297    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0293793799791333 for eigenvalue
#  The estimated number of batches is 1641
#      1550/1    1.17603    1.18156 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028755726482358 for eigenvalue
#  The estimated number of batches is 1640
#      1551/1    1.18275    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028237282791269 for eigenvalue
#  The estimated number of batches is 1639
#      1552/1    1.19465    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0281418557430162 for eigenvalue
#  The estimated number of batches is 1640
#      1553/1    1.19815    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0282050446357744 for eigenvalue
#  The estimated number of batches is 1641
#      1554/1    1.18030    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0275472944250499 for eigenvalue
#  The estimated number of batches is 1640
#      1555/1    1.17580    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0269972897301543 for eigenvalue
#  The estimated number of batches is 1640
#      1556/1    1.18738    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.026386918526928 for eigenvalue
#  The estimated number of batches is 1639
#      1557/1    1.18066    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025790294234683 for eigenvalue
#  The estimated number of batches is 1638
#      1558/1    1.17388    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0254246381132006 for eigenvalue
#  The estimated number of batches is 1638
#      1559/1    1.17726    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.024897488408665 for eigenvalue
#  The estimated number of batches is 1637
#      1560/1    1.18453    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0243955101952398 for eigenvalue
#  The estimated number of batches is 1637
#      1561/1    1.18952    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023724800402937 for eigenvalue
#  The estimated number of batches is 1635
#      1562/1    1.18906    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0230504146796842 for eigenvalue
#  The estimated number of batches is 1634
#      1563/1    1.17200    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229731776748137 for eigenvalue
#  The estimated number of batches is 1635
#      1564/1    1.19330    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023644813917082 for eigenvalue
#  The estimated number of batches is 1638
#      1565/1    1.18698    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0231004180931969 for eigenvalue
#  The estimated number of batches is 1638
#      1566/1    1.18275    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0224387562644779 for eigenvalue
#  The estimated number of batches is 1637
#      1567/1    1.18114    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0222953823179548 for eigenvalue
#  The estimated number of batches is 1637
#      1568/1    1.17656    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0216800720811214 for eigenvalue
#  The estimated number of batches is 1636
#      1569/1    1.17750    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214739584148051 for eigenvalue
#  The estimated number of batches is 1637
#      1570/1    1.17708    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020973946587673 for eigenvalue
#  The estimated number of batches is 1636
#      1571/1    1.17414    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204353241137618 for eigenvalue
#  The estimated number of batches is 1636
#      1572/1    1.18905    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019780010095114 for eigenvalue
#  The estimated number of batches is 1635
#      1573/1    1.18456    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0191199900117829 for eigenvalue
#  The estimated number of batches is 1633
#      1574/1    1.18758    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018446303246402 for eigenvalue
#  The estimated number of batches is 1632
#      1575/1    1.19896    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0206251872600502 for eigenvalue
#  The estimated number of batches is 1640
#      1576/1    1.18885    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0203702790956495 for eigenvalue
#  The estimated number of batches is 1641
#      1577/1    1.17704    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198083309650556 for eigenvalue
#  The estimated number of batches is 1640
#      1578/1    1.18494    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193552734501277 for eigenvalue
#  The estimated number of batches is 1639
#      1579/1    1.17612    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193272037796448 for eigenvalue
#  The estimated number of batches is 1640
#      1580/1    1.18114    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018693106440465 for eigenvalue
#  The estimated number of batches is 1639
#      1581/1    1.18327    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180990117238888 for eigenvalue
#  The estimated number of batches is 1639
#      1582/1    1.17552    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177101478337598 for eigenvalue
#  The estimated number of batches is 1638
#      1583/1    1.18171    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017055617579926 for eigenvalue
#  The estimated number of batches is 1637
#      1584/1    1.18061    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166066394424342 for eigenvalue
#  The estimated number of batches is 1637
#      1585/1    1.18898    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166703721576775 for eigenvalue
#  The estimated number of batches is 1638
#      1586/1    1.19299    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170147113536505 for eigenvalue
#  The estimated number of batches is 1640
#      1587/1    1.18200    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164002888413703 for eigenvalue
#  The estimated number of batches is 1639
#      1588/1    1.17333    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163525080544988 for eigenvalue
#  The estimated number of batches is 1640
#      1589/1    1.17201    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163591592136667 for eigenvalue
#  The estimated number of batches is 1641
#      1590/1    1.19385    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0157396025627834 for eigenvalue
#  The estimated number of batches is 1640
#      1591/1    1.17461    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0153930863979466 for eigenvalue
#  The estimated number of batches is 1640
#      1592/1    1.18195    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147457542785452 for eigenvalue
#  The estimated number of batches is 1639
#      1593/1    1.17720    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141802130458109 for eigenvalue
#  The estimated number of batches is 1638
#      1594/1    1.17407    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0138467421118313 for eigenvalue
#  The estimated number of batches is 1638
#      1595/1    1.18518    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0131819493192356 for eigenvalue
#  The estimated number of batches is 1637
#      1596/1    1.18464    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0125456052706236 for eigenvalue
#  The estimated number of batches is 1636
#      1597/1    1.18597    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011912182478488 for eigenvalue
#  The estimated number of batches is 1635
#      1598/1    1.18274    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0117330866216734 for eigenvalue
#  The estimated number of batches is 1636
#      1599/1    1.17492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111431212777842 for eigenvalue
#  The estimated number of batches is 1635
#      1600/1    1.17466    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115921829661432 for eigenvalue
#  The estimated number of batches is 1637
#      1601/1    1.17892    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111091804467538 for eigenvalue
#  The estimated number of batches is 1637
#      1602/1    1.17046    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011036386897514 for eigenvalue
#  The estimated number of batches is 1638
#      1603/1    1.18729    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0104155377473154 for eigenvalue
#  The estimated number of batches is 1637
#      1604/1    1.17693    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0101722166241356 for eigenvalue
#  The estimated number of batches is 1637
#      1605/1    1.18002    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102251400270015 for eigenvalue
#  The estimated number of batches is 1638
#      1606/1    1.17419    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096029800085493 for eigenvalue
#  The estimated number of batches is 1637
#      1607/1    1.20125    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009310772641225 for eigenvalue
#  The estimated number of batches is 1637
#      1608/1    1.19361    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01003134212993 for eigenvalue
#  The estimated number of batches is 1641
#      1609/1    1.18837    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0103322457331263 for eigenvalue
#  The estimated number of batches is 1643
#      1610/1    1.18598    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097721002448734 for eigenvalue
#  The estimated number of batches is 1642
#      1611/1    1.16718    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099989214196454 for eigenvalue
#  The estimated number of batches is 1643
#      1612/1    1.18902    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097935254104733 for eigenvalue
#  The estimated number of batches is 1644
#      1613/1    1.17884    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009868904941159 for eigenvalue
#  The estimated number of batches is 1645
#      1614/1    1.18538    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00923643556946 for eigenvalue
#  The estimated number of batches is 1644
#      1615/1    1.17623    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0089435196061098 for eigenvalue
#  The estimated number of batches is 1644
#      1616/1    1.17859    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008905829515394 for eigenvalue
#  The estimated number of batches is 1645
#      1617/1    1.18204    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0082770770746678 for eigenvalue
#  The estimated number of batches is 1644
#      1618/1    1.18125    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0078402208466295 for eigenvalue
#  The estimated number of batches is 1644
#      1619/1    1.16938    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0072610890245743 for eigenvalue
#  The estimated number of batches is 1643
#      1620/1    1.17142    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007230250663518 for eigenvalue
#  The estimated number of batches is 1644
#      1621/1    1.18646    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0066032255007418 for eigenvalue
#  The estimated number of batches is 1643
#      1622/1    1.19101    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060696868892256 for eigenvalue
#  The estimated number of batches is 1642
#      1623/1    1.18579    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061795196531884 for eigenvalue
#  The estimated number of batches is 1643
#      1624/1    1.19450    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055575122805613 for eigenvalue
#  The estimated number of batches is 1642
#      1625/1    1.16829    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0053873296357614 for eigenvalue
#  The estimated number of batches is 1643
#      1626/1    1.18023    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0048340109843639 for eigenvalue
#  The estimated number of batches is 1642
#      1627/1    1.18033    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041977923388297 for eigenvalue
#  The estimated number of batches is 1641
#      1628/1    1.19163    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038282741136422 for eigenvalue
#  The estimated number of batches is 1641
#      1629/1    1.18492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032524589422542 for eigenvalue
#  The estimated number of batches is 1640
#      1630/1    1.19150    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029040132426896 for eigenvalue
#  The estimated number of batches is 1640
#      1631/1    1.17866    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025054245466567 for eigenvalue
#  The estimated number of batches is 1640
#      1632/1    1.17531    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020537859066725 for eigenvalue
#  The estimated number of batches is 1639
#      1633/1    1.19327    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015243856120508 for eigenvalue
#  The estimated number of batches is 1638
#      1634/1    1.18072    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000900482333582 for eigenvalue
#  The estimated number of batches is 1637
#      1635/1    1.18718    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004631248772617 for eigenvalue
#  The estimated number of batches is 1637
#      1636/1    1.18024    1.18161 +/- 0.00016
#  Triggers satisfied for batch 1636
#  Creating state point statepoint.01636.h5...
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.5020e+00 seconds
#    Reading cross sections          = 3.4659e+00 seconds
#  Total time in simulation          = 1.1285e+03 seconds
#    Time in transport only          = 1.1199e+03 seconds
#    Time in inactive batches        = 8.3742e+00 seconds
#    Time in active batches          = 1.1201e+03 seconds
#    Time synchronizing fission bank = 1.1071e+00 seconds
#      Sampling source sites         = 8.4232e-01 seconds
#      SEND/RECV source sites        = 2.6396e-01 seconds
#    Time accumulating tallies       = 6.2389e+00 seconds
#    Time writing statepoints        = 5.1530e-01 seconds
#  Total time for finalization       = 1.1527e+01 seconds
#  Total time elapsed                = 1.1436e+03 seconds
#  Calculation Rate (inactive)       = 119414 particles/second
#  Calculation Rate (active)         = 72135.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18174 +/- 0.00013
#  k-effective (Track-length)  = 1.18161 +/- 0.00016
#  k-effective (Absorption)    = 1.18170 +/- 0.00011
#  Combined k-effective        = 1.18170 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(statepoint_filename)

# %% [markdown]
# ## MGXS Tally Outputs

# %%
xs_names = [] 
for set in (mgxs_lib.domains):
    print(set.name)
    xs_names.append(set.name)

#print(mgxs_lib.domains)
# Out:
# fuel
# clad
# moderator
# gap
# aic_clad
# aic_gap
# aic
# aic_water
# aic_guide
# it-water-in
# it-clad
# it-water-out
# water_outside

# %%
if one_eighth:
    txt = 'one_eighth'
else:
    txt = 'one_quarter'

# %%
mgxs_lib.load_from_statepoint(sp)
    
h5_file_path = my_path + f'/mgxs_{my_case}_{txt}_{egroup_name}.h5'
print(h5_file_path)

# below, no need for xs_type = 'macro' as it is the default
mgxs_lib.create_mg_library(xsdata_names=xs_names).export_to_hdf5(h5_file_path)
# Out:
# ./mgxs_casl_2g/mgxs_2g_one_eighth_SHEM-361.h5

# %% [markdown]
# ## Power Tally Outputs

# %%
computed_power_tallies = sp.get_tally()
power_tally_values = computed_power_tallies.get_values()

pin_power_file_path = my_path + f'/pinpow_{my_case}_{txt}_{egroup_name}.npy'
np.save(pin_power_file_path, power_tally_values)

# %%
for score_id in range(0,len(computed_power_tallies.scores)):
     # get name of the score
    score = computed_power_tallies.scores[score_id]
    print('score = ',score)
    # extract + shape the data
    vals = power_tally_values[:,0,score_id].reshape(17,17)
    vals = vals[8:,8:]
    
    dd = np.copy(vals)

    # multiply axis of symeetry by 2 for power display
    dd[0,:] *= 2
    dd[np.diag_indices_from(dd)] *= 2

    dd = np.flip(dd,axis=0)
    
    # normalize
    idx_fuel_cells = np.argwhere(dd>0)
    nnz_fuel_cells = np.asarray(idx_fuel_cells).shape[0]
    dd /= np.sum(dd)
    dd *= nnz_fuel_cells

    table = PrettyTable()

    n_list = [str(n) for n in range(1, 10)]
    table.field_names = n_list

    # Convert ndarray to list of lists
    data_list = dd.tolist()

    for row in data_list:
        # Format each value to 2 decimal places
        formatted_row = [f"{x:.6g}" for x in row]
        table.add_row(formatted_row)

    print(table)
# Out:
# score =  fission
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 1 |    2    |    3     |    4     |    5     |    6     |    7     |    8     |    9    |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     |    0     | 1.26329 |
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     | 1.19724  | 1.23352 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 1.06706  | 1.14936  | 1.19815 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 0.96191  | 1.09151  |  1.1555 |
# | 0 |    0    |    0     |    0     | 0.869257 | 0.848396 | 0.905069 | 1.03629  | 1.11795 |
# | 0 |    0    |    0     |    0     | 0.851664 | 0.854307 |    0     | 0.975328 | 1.08668 |
# | 0 |    0    | 0.939621 | 0.874482 | 0.912687 | 0.918867 | 0.904531 | 1.00875  | 1.08355 |
# | 0 | 1.03484 | 0.964273 | 0.883713 | 0.917008 | 0.924141 | 0.905548 |  1.0033  | 1.07704 |
# | 0 | 1.07306 | 0.93754  |    0     | 0.870886 | 0.877934 |    0     | 0.959274 |  1.0665 |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# score =  nu-fission
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 1 |    2    |    3     |    4     |    5     |    6     |    7     |    8     |    9    |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     |    0     | 1.26134 |
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     | 1.19592  | 1.23186 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 1.06678  |  1.1484  | 1.19674 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 0.962491 |  1.091   | 1.15437 |
# | 0 |    0    |    0     |    0     | 0.870313 | 0.849784 | 0.906051 | 1.03612  | 1.11703 |
# | 0 |    0    |    0     |    0     | 0.852863 | 0.855621 |    0     | 0.975675 |  1.086  |
# | 0 |    0    | 0.93985  | 0.875409 | 0.91325  | 0.91947  | 0.905386 | 1.00867  | 1.08279 |
# | 0 | 1.03407 | 0.964245 | 0.884538 | 0.917519 | 0.92465  | 0.906348 | 1.00323  | 1.07629 |
# | 0 | 1.07181 | 0.937786 |    0     | 0.871858 | 0.878928 |    0     | 0.959675 | 1.06588 |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# score =  kappa-fission
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 1 |    2    |    3     |    4     |    5     |    6     |    7     |    8     |    9    |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     |    0     | 1.26301 |
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     | 1.19705  | 1.23327 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 1.06702  | 1.14922  | 1.19794 |
# | 0 |    0    |    0     |    0     |    0     |    0     | 0.961995 | 1.09144  | 1.15534 |
# | 0 |    0    |    0     |    0     | 0.869413 | 0.848599 | 0.905213 | 1.03626  | 1.11781 |
# | 0 |    0    |    0     |    0     | 0.85184  | 0.854498 |    0     | 0.975377 | 1.08658 |
# | 0 |    0    | 0.939655 | 0.874617 | 0.91277  | 0.918954 | 0.904657 | 1.00873  | 1.08344 |
# | 0 | 1.03473 | 0.96427  | 0.883833 | 0.917083 | 0.924215 | 0.905666 | 1.00329  | 1.07693 |
# | 0 | 1.07288 | 0.937577 |    0     | 0.87103  | 0.878079 |    0     | 0.959331 |  1.0664 |
# +---+---------+----------+----------+----------+----------+----------+----------+---------+

# %%
plt.figure()
plt.imshow(dd, cmap='viridis')  # You can change the colormap if desired
plt.title('2D Array Plot')
plt.colorbar()  # Adds a colorbar to show the scale
plt.clim([0.7,1.3])
plt.show()

# %% [markdown]
# ## Clean up by deleting unwanted files

# %%
def delete_runtime_files(directory='.'):
    """
    Deletes all files with a .xml extension, files named statepoint.NNNNN.h5 where N is a digit,
    and the file named summary.h5 in the specified directory.

    Parameters:
    directory (str): The directory to search for files. Defaults to the current directory.
    """
    
    # Regular expression pattern to match files named statepoint.NNNNN.h5
    pattern = re.compile(r'statepoint\.\d{5}\.h5')

    # Iterate through files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if the file has a .xml extension, matches the pattern, or is named summary.h5
        if filename.endswith('.xml') or pattern.match(filename) or filename == 'summary.h5' \
           or filename == 'tallies.out':
            # Delete the file
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")


# Example usage:
# delete_runtime_files('/path/to/directory')  # specify the directory path if needed

# %%
delete_runtime_files('./')
delete_runtime_files(my_path)
# Out:
# Deleted: ./model.xml
# Deleted: ./mgxs_casl_2g/statepoint.01385.h5
# Deleted: ./mgxs_casl_2g/tallies.out
# Deleted: ./mgxs_casl_2g/summary.h5
# Deleted: ./mgxs_casl_2g/statepoint.00150.h5
