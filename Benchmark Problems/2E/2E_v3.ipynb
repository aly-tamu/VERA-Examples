# %% [markdown]
# # Fuel assembly: 2E

# %% [markdown]
# ## Import modules

# %%
import sys
import os
import pathlib
import re

import openmc
import openmc.mgxs as mgxs

import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import Counter
from prettytable import PrettyTable

# %% [markdown]
# ## Add location of OpenMC XS executable, setup ENDF xs path

# %%
# Add path to OpenMC binary
# os.environ['PATH'] += r':/path/to/openmc/bin'
#os.environ['PATH'] += r':/Users/jean.ragusa/repo/openmc/local/bin'

# Add location of OpenMC xs data
#%env OPENMC_CROSS_SECTIONS=/Users/jean.ragusa/repo/endfb-vii.1-hdf5/cross_sections.xml

# Are you ragusa?
your_files = os.getcwd()
print(your_files)
if 'ragusa' in your_files:
    os.environ['OPENMC_CROSS_SECTIONS'] = '/home/ragusa/xs/endfb-viii.0-hdf5/cross_sections.xml'
# Out:
# /home/brent10/github/VERA-Examples/Benchmark Problems/2E

# %% [markdown]
# # Start model

# %%
model=openmc.Model()

# %% [markdown]
# ## Define Materials
# ***

# %%
uo2 = openmc.Material(name='uo2')

uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')

uo2.set_density('g/cm3', 10.257 )

uo2.temperature = 600

# %%
zirconium = openmc.Material(name="zirconium")

zirconium.add_nuclide('Zr90',  2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91',  4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92',  7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94',  7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96',  1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112', 4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54',  8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56',  1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57',  3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58',  4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50',  3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52',  6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53',  7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54',  1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')

zirconium.set_density('g/cm3',  6.56)

zirconium.temperature = 600

# %%
water = openmc.Material(name="water")

water.add_nuclide('H1',  4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')

water.add_s_alpha_beta('c_H_in_H2O')

water.set_density('g/cm3', 0.743)

water.temperature=600

# %%
helium = openmc.Material(name="helium")

helium.add_nuclide('He4',1, 'ao')

helium.set_density('g/cm3', 0.178E-03 )

helium.temperature=600

# %%
pyrex_mat = openmc.Material(name="pyrex_mat")

pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')

pyrex_mat.set_density('g/cm3', 2.25 )

pyrex_mat.temperature=600

# %%
SS304 = openmc.Material(name="SS304")

SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')

SS304.set_density('g/cm3', 8.00 )

SS304.temperature=600

# %%
model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#print(model.materials)

# %% [markdown]
# ## Define individiual cells
# ***

# %%
# Global surfaces
pitch = 1.26

# Fuel radii
fuel_outer_radius = openmc.ZCylinder(r=0.4096)
clad_inner_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)

# Guide tube radii
gt_inner_radius = openmc.ZCylinder(r=0.561)
gt_outer_radius = openmc.ZCylinder(r=0.602)

# Instrumentation radii
it_inner_radius = openmc.ZCylinder(r=0.559)
it_outer_radius = openmc.ZCylinder(r=0.605)

#Pyrex
Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
Outer_Tube_Inner_Radius= openmc.ZCylinder(r= 0.437)
Outer_Tube_Outer_Radius= openmc.ZCylinder(r= 0.484)

# Universe bounds
left   = openmc.XPlane(-pitch/2, boundary_type='transmission')
right  = openmc.XPlane( pitch/2, boundary_type='transmission')
bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
top    = openmc.YPlane( pitch/2, boundary_type='transmission')

# %% [markdown]
# ### Define pincell universe

# %%
def pincell():

    fuel_region  = -fuel_outer_radius
    gap_region   = +fuel_outer_radius & -clad_inner_radius
    clad_region  = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius

    fuel = openmc.Cell(name='fuel')
    fuel.region = fuel_region
    fuel.fill = uo2
    #new_fuel = uo2.clone()
    #fuel.fill = new_fuel
    
    gap = openmc.Cell(name='gap')
    gap.region = gap_region
    gap.fill = helium     
    
    clad = openmc.Cell(name='clad')
    clad.region = clad_region
    clad.fill = zirconium
    
    moderator = openmc.Cell(name='moderator')
    moderator.region = water_region
    moderator.fill = water
    
    return openmc.Universe(name='pin-univ', cells=(fuel, clad, moderator,gap))

# %% [markdown]
# ### Create guide tube universe

# %%
def guide():
    
    gt_water_in_region  = -gt_inner_radius
    gt_clad_region      = +gt_inner_radius & -gt_outer_radius
    gt_water_out_region = +gt_outer_radius & +left & -right & +bottom & -top
     
    gt_water_in = openmc.Cell(name='gt-water-in')
    gt_water_in.region = gt_water_in_region
    gt_water_in.fill = water
 
    gt_clad = openmc.Cell(name='gt-clad')
    gt_clad.region = gt_clad_region
    gt_clad.fill = zirconium

    gt_water_out = openmc.Cell(name='gt-water-out')
    gt_water_out.region = gt_water_out_region
    gt_water_out.fill = water
    
    return openmc.Universe(name='gt-univ', cells=(gt_water_in, gt_clad, gt_water_out))

# %% [markdown]
# ### Create instrumentation tube universe

# %%
def instrument():
    
    it_water_in_region  = -it_inner_radius
    it_clad_region      = +it_inner_radius & -it_outer_radius
    it_water_out_region = +it_outer_radius & +left & -right & +bottom & -top
    
    it_water_in = openmc.Cell(name='it-water-in')
    it_water_in.region = it_water_in_region
    it_water_in.fill = water

    it_clad = openmc.Cell(name='it-clad')
    it_clad.region = it_clad_region
    it_clad.fill = zirconium

    it_water_out = openmc.Cell(name='it-water-out')
    it_water_out.region = it_water_out_region
    it_water_out.fill = water

    return openmc.Universe(name='it-univ', cells=(it_water_in, it_clad, it_water_out))

# %%
def pyrex_pin():

    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +gt_outer_radius | +Outer_Tube_Outer_Radius & -gt_inner_radius 
    guide_region = +gt_inner_radius & -gt_outer_radius
    steel_region = +Outer_Tube_Inner_Radius & -Outer_Tube_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Outer_Tube_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='pyrex_clad')
    steel_cell.fill = SS304
    steel_cell.region = steel_region  
    
    gap_cell = openmc.Cell(name='pyrex_gap')
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    
    pyrex_cell = openmc.Cell(name='pyrex')
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region  
    
    water_cell = openmc.Cell(name='pyrex_water')
    water_cell.fill = water
    water_cell.region = water_region
    
    guide_cell = openmc.Cell(name='pyrex_guide')
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    return openmc.Universe(name='py-univ', cells=(steel_cell,gap_cell,pyrex_cell,water_cell,guide_cell))

# %% [markdown]
# ### Generate universes

# %%
pc_univ  = pincell()
gt_univ  = guide()
it_univ  = instrument()
py_univ = pyrex_pin()

# %% [markdown]
# ## Generate assembly
# ***

# %%
height = 10 # height in z-dir
dr = 0.04   # cm of water that is outside assembly
one_eighth = True # either 1/8 or 1/4 of FA

# %%
def read_csv_to_2d_array(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        data = [row for row in reader]
    return np.asarray(data)

def count_frequencies(data):
    flattened_data = [item for row in data for item in row]  # Flatten 2D array into a 1D list
    cell_frequencies = Counter(flattened_data)
    print("cell name frequency:")
    total = 0
    for key, value in cell_frequencies.items():
        print(f'"{key}": {value}')
        total += value
    print("total: ",total)

csv_filepath = 'FA_cell_names_1_family.csv'

lattice_csv = read_csv_to_2d_array(csv_filepath)
count_frequencies(lattice_csv)

if lattice_csv.shape[0] != lattice_csv.shape[1]:
    raise Exception('CSV array of cell names is not square.')
    
size = lattice_csv.shape[0] #size of the assembly
# Out:
# cell name frequency:
# "fu": 264
# "p": 12
# "gt": 12
# "it": 1
# total:  289

# %% [markdown]
# ### Define assembly lattice

# %%
assembly = openmc.RectLattice()
assembly.pitch = (pitch,pitch)
assembly.lower_left = (-size*pitch/2, -size*pitch/2)

lattice_array = np.empty((size, size), dtype=openmc.universe.Universe)

for row in range(0,lattice_csv.shape[0]):
    for col in range(0,lattice_csv.shape[1]):
        if lattice_csv[row][col] == 'gt': 
            lattice_array[row][col] = gt_univ
        elif lattice_csv[row][col] == 'it':
            lattice_array[row][col] = it_univ
        elif lattice_csv[row][col] == 'fu':
            lattice_array[row][col] = pc_univ
        elif lattice_csv[row][col] == 'p':
            lattice_array[row][col] = py_univ
        else:
            mesg = 'i={},j={},cell-name {} not recognized'.format(col, row, lattice_csv[row][col])
            raise ValueError(mesg)

assembly.universes = lattice_array

# %% [markdown]
# ### Define moderator outside of the assembly

# %%
# create cell that will contain the lattice
moderator_outside_cell = openmc.Cell( name = 'water_outside', fill = water )
assembly.outer = openmc.Universe( name='outer', cells = [moderator_outside_cell] )

# %% [markdown]
# ### Define 1/8 or 1/4 of full assembly

# %%
min_x = openmc.XPlane(x0= 0.               , boundary_type='reflective')
max_x = openmc.XPlane(x0= size*pitch/2+dr  , boundary_type='reflective')
min_y = openmc.YPlane(y0= 0.               , boundary_type='reflective')
max_y = openmc.YPlane(y0= size*pitch/2+dr  , boundary_type='reflective')
min_z = openmc.ZPlane(z0=-height/2         , boundary_type='reflective')
max_z = openmc.ZPlane(z0= height/2         , boundary_type='reflective')
xy    = openmc.Plane(-1., 1.               , boundary_type='reflective')

# define root universe
root_cell = openmc.Cell( name = 'root cell', fill = assembly )

if one_eighth:
    root_cell.region = -max_x & +min_y & -xy
else:
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name = 'root universe', cells=[root_cell])

# %% [markdown]
# ## Plotting

# %%
color_opt = 'material'
root_cell.plot(origin=(5,5,0), pixels=(1500,1500), width=(15,15),color_by=color_opt,outline=True)
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# ##  Settings
# ***

# %%
settings = openmc.Settings()

# %% [markdown]
# ### Source

# %%
bbox = openmc.BoundingBox(lower_left  = [0., 0., -height/2], 
                          upper_right = [size*pitch/2, size*pitch/2, height/2])
uniform_dist = openmc.stats.Box(bbox.lower_left, bbox.upper_right, only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings.source = source
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/stats/multivariate.py:943: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "

# %% [markdown]
# ### Destination path

# %%
my_case = '2e'
my_path = './mgxs_casl_' + my_case

# check if folder exists
path = pathlib.Path(my_path)
path.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ### Batching

# %%
test_mode = False

# %%
# add additional parameters
settings.batches =  150
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies': True, 'path':my_path}
settings.temperature['method'] = 'interpolation'

if test_mode == True:
    settings.batches = 200
    settings.inactive = 50
    settings.particles = 1000
    settings.keff_trigger = {'type':'std_dev','threshold':0.001}

model.settings = settings

# %% [markdown]
# ## Tallies
# ***

# %%
# egroup_name = 'XMAS-172'
egroup_name = 'SHEM-361'
egroup = openmc.mgxs.GROUP_STRUCTURES[egroup_name]

# %% [markdown]
# ### Power Tally

# %%
tally_power = openmc.Tally(name='power')

# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [size, size]
mesh._lower_left = [-size*pitch/2, -size*pitch/2]
mesh._upper_right = [size*pitch/2,  size*pitch/2]

# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)
tally_power.filters = [mesh_filter]

tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']

tallies = openmc.Tallies([tally_power])
# model.tallies=tallies

# %% [markdown]
# ### MGXS Tally

# %%
leg = 7
mgxs_domain = 'cell'

# %%
# Setup MGXS lib
mgxs_lib = openmc.mgxs.Library(model.geometry)
mgxs_lib.energy_groups = openmc.mgxs.EnergyGroups(egroup)
mgxs_lib.scatter_format = "legendre"
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi',
                       'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']

# Legendre order
mgxs_lib.legendre_order = leg
if leg == leg:
    mgxs_lib.correction = None

# No by_nuclide
mgxs_lib.by_nuclide = False

# MGXS domain type
mgxs_lib.domain_type = mgxs_domain
if mgxs_domain == 'cell':
    mgxs_lib.domains = model.geometry.get_all_material_cells().values()
elif mgxs_domain == 'universe':
    mgxs_lib.domains = model.geometry.get_all_universes().values()

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()
mgxs_lib.check_library_for_openmc_mgxs()

mgxs_lib.add_to_tallies_file(tallies, merge=True)

model.tallies = tallies
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 7 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
# trick to make several runs work with jupyter
try:
    sp 
    print('sp found')
    sp.close()
except NameError:
    print('sp NOT found')
# Out:
# sp NOT found

# %%
statepoint_filename = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev2
#      Commit Hash | 3f3649da086fd296cde37dcda9218514f8c16c98
#        Date/Time | 2025-03-31 12:02:16
#   OpenMP Threads | 8
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /home/brent10/nndc_hdf5/neutron/U234.h5
#  Reading U235 from /home/brent10/nndc_hdf5/neutron/U235.h5
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=591.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#  Reading U236 from /home/brent10/nndc_hdf5/neutron/U236.h5
#  Reading U238 from /home/brent10/nndc_hdf5/neutron/U238.h5
#  Reading O16 from /home/brent10/nndc_hdf5/neutron/O16.h5
#  Reading Zr90 from /home/brent10/nndc_hdf5/neutron/Zr90.h5
#  Reading Zr91 from /home/brent10/nndc_hdf5/neutron/Zr91.h5
#  Reading Zr92 from /home/brent10/nndc_hdf5/neutron/Zr92.h5
#  Reading Zr94 from /home/brent10/nndc_hdf5/neutron/Zr94.h5
#  Reading Zr96 from /home/brent10/nndc_hdf5/neutron/Zr96.h5
#  Reading Sn112 from /home/brent10/nndc_hdf5/neutron/Sn112.h5
#  Reading Sn114 from /home/brent10/nndc_hdf5/neutron/Sn114.h5
#  Reading Sn115 from /home/brent10/nndc_hdf5/neutron/Sn115.h5
#  Reading Sn116 from /home/brent10/nndc_hdf5/neutron/Sn116.h5
#  Reading Sn117 from /home/brent10/nndc_hdf5/neutron/Sn117.h5
#  Reading Sn118 from /home/brent10/nndc_hdf5/neutron/Sn118.h5
#  Reading Sn119 from /home/brent10/nndc_hdf5/neutron/Sn119.h5
#  Reading Sn120 from /home/brent10/nndc_hdf5/neutron/Sn120.h5
#  Reading Sn122 from /home/brent10/nndc_hdf5/neutron/Sn122.h5
#  Reading Sn124 from /home/brent10/nndc_hdf5/neutron/Sn124.h5
#  Reading Fe54 from /home/brent10/nndc_hdf5/neutron/Fe54.h5
#  Reading Fe56 from /home/brent10/nndc_hdf5/neutron/Fe56.h5
#  Reading Fe57 from /home/brent10/nndc_hdf5/neutron/Fe57.h5
#  Reading Fe58 from /home/brent10/nndc_hdf5/neutron/Fe58.h5
#  Reading Cr50 from /home/brent10/nndc_hdf5/neutron/Cr50.h5
#  Reading Cr52 from /home/brent10/nndc_hdf5/neutron/Cr52.h5
#  Reading Cr53 from /home/brent10/nndc_hdf5/neutron/Cr53.h5
#  Reading Cr54 from /home/brent10/nndc_hdf5/neutron/Cr54.h5
#  Reading Hf174 from /home/brent10/nndc_hdf5/neutron/Hf174.h5
#  Reading Hf176 from /home/brent10/nndc_hdf5/neutron/Hf176.h5
#  Reading Hf177 from /home/brent10/nndc_hdf5/neutron/Hf177.h5
#  Reading Hf178 from /home/brent10/nndc_hdf5/neutron/Hf178.h5
#  Reading Hf179 from /home/brent10/nndc_hdf5/neutron/Hf179.h5
#  Reading Hf180 from /home/brent10/nndc_hdf5/neutron/Hf180.h5
#  Reading H1 from /home/brent10/nndc_hdf5/neutron/H1.h5
#  Reading B10 from /home/brent10/nndc_hdf5/neutron/B10.h5
#  Reading B11 from /home/brent10/nndc_hdf5/neutron/B11.h5
#  Reading He4 from /home/brent10/nndc_hdf5/neutron/He4.h5
#  Reading Si28 from /home/brent10/nndc_hdf5/neutron/Si28.h5
#  Reading Si29 from /home/brent10/nndc_hdf5/neutron/Si29.h5
#  Reading Si30 from /home/brent10/nndc_hdf5/neutron/Si30.h5
#  Reading C0 from /home/brent10/nndc_hdf5/neutron/C0.h5
#  Reading P31 from /home/brent10/nndc_hdf5/neutron/P31.h5
#  Reading Mn55 from /home/brent10/nndc_hdf5/neutron/Mn55.h5
#  Reading Ni58 from /home/brent10/nndc_hdf5/neutron/Ni58.h5
#  Reading Ni60 from /home/brent10/nndc_hdf5/neutron/Ni60.h5
#  Reading Ni61 from /home/brent10/nndc_hdf5/neutron/Ni61.h5
#  Reading Ni62 from /home/brent10/nndc_hdf5/neutron/Ni62.h5
#  Reading Ni64 from /home/brent10/nndc_hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from /home/brent10/nndc_hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 600 K
#  Maximum neutron data temperature: 900 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.01972
#         2/1    1.12437
#         3/1    1.04114
#         4/1    1.01655
#         5/1    1.08640
#         6/1    1.11029
#         7/1    1.06611
#         8/1    1.09060
#         9/1    1.01713
#        10/1    0.98974
#        11/1    0.97810
#        12/1    1.08997
#        13/1    1.01106
#        14/1    1.09628
#        15/1    1.04839
#        16/1    1.15498
#        17/1    1.04897
#        18/1    1.05134
#        19/1    1.03199
#        20/1    1.06743
#        21/1    1.07408
#        22/1    1.09002
#        23/1    1.16185
#        24/1    1.09426
#        25/1    1.02632
#        26/1    1.11381
#        27/1    1.08516
#        28/1    1.03061
#        29/1    1.05685
#        30/1    1.01316
#        31/1    1.03123
#        32/1    1.01536
#        33/1    1.04474
#        34/1    1.04316
#        35/1    1.08048
#        36/1    1.13561
#        37/1    1.06435
#        38/1    1.07702
#        39/1    1.16574
#        40/1    1.07752
#        41/1    1.01877
#        42/1    1.01343
#        43/1    1.05085
#        44/1    0.98342
#        45/1    1.03038
#        46/1    1.11045
#        47/1    1.07862
#        48/1    1.04544
#        49/1    1.01046
#        50/1    1.08815
#        51/1    1.14212
#        52/1    1.12713    1.13462 +/- 0.00750
#        53/1    1.05402    1.10776 +/- 0.02722
#        54/1    1.08307    1.10158 +/- 0.02021
#        55/1    1.03155    1.08758 +/- 0.02101
#        56/1    1.00735    1.07421 +/- 0.02175
#        57/1    1.05096    1.07088 +/- 0.01868
#        58/1    1.03112    1.06591 +/- 0.01692
#        59/1    1.06963    1.06633 +/- 0.01493
#        60/1    1.04618    1.06431 +/- 0.01350
#        61/1    1.01591    1.05991 +/- 0.01298
#        62/1    1.03204    1.05759 +/- 0.01208
#        63/1    1.06198    1.05793 +/- 0.01111
#        64/1    1.08905    1.06015 +/- 0.01053
#        65/1    1.04692    1.05927 +/- 0.00984
#        66/1    1.01973    1.05680 +/- 0.00953
#        67/1    1.04538    1.05613 +/- 0.00898
#        68/1    1.10638    1.05892 +/- 0.00891
#        69/1    0.99325    1.05546 +/- 0.00911
#        70/1    0.98356    1.05187 +/- 0.00936
#        71/1    1.06949    1.05271 +/- 0.00894
#        72/1    1.02934    1.05164 +/- 0.00859
#        73/1    1.04580    1.05139 +/- 0.00822
#        74/1    1.05278    1.05145 +/- 0.00787
#        75/1    1.08983    1.05298 +/- 0.00770
#        76/1    1.05700    1.05314 +/- 0.00740
#        77/1    1.06563    1.05360 +/- 0.00713
#        78/1    1.13346    1.05645 +/- 0.00744
#        79/1    1.07186    1.05698 +/- 0.00720
#        80/1    1.18079    1.06111 +/- 0.00809
#        81/1    1.11402    1.06282 +/- 0.00801
#        82/1    1.07533    1.06321 +/- 0.00776
#        83/1    1.04786    1.06274 +/- 0.00754
#        84/1    1.09747    1.06376 +/- 0.00739
#        85/1    1.10473    1.06493 +/- 0.00727
#        86/1    1.08840    1.06559 +/- 0.00709
#        87/1    1.08394    1.06608 +/- 0.00691
#        88/1    1.07460    1.06631 +/- 0.00673
#        89/1    1.11687    1.06760 +/- 0.00669
#        90/1    1.13000    1.06916 +/- 0.00670
#        91/1    1.07401    1.06928 +/- 0.00654
#        92/1    1.05756    1.06900 +/- 0.00638
#        93/1    1.14323    1.07073 +/- 0.00647
#        94/1    1.05992    1.07048 +/- 0.00633
#        95/1    1.08935    1.07090 +/- 0.00620
#        96/1    1.03833    1.07019 +/- 0.00610
#        97/1    1.05407    1.06985 +/- 0.00598
#        98/1    1.08782    1.07023 +/- 0.00587
#        99/1    1.06933    1.07021 +/- 0.00575
#       100/1    1.08986    1.07060 +/- 0.00564
#       101/1    1.10965    1.07137 +/- 0.00558
#       102/1    1.05236    1.07100 +/- 0.00549
#       103/1    1.02731    1.07018 +/- 0.00545
#       104/1    1.08762    1.07050 +/- 0.00535
#       105/1    1.15207    1.07198 +/- 0.00546
#       106/1    1.03656    1.07135 +/- 0.00540
#       107/1    1.02231    1.07049 +/- 0.00537
#       108/1    1.09645    1.07094 +/- 0.00530
#       109/1    1.04147    1.07044 +/- 0.00523
#       110/1    1.10314    1.07098 +/- 0.00517
#       111/1    1.09240    1.07133 +/- 0.00510
#       112/1    1.02644    1.07061 +/- 0.00507
#       113/1    1.03468    1.07004 +/- 0.00502
#       114/1    1.04142    1.06959 +/- 0.00496
#       115/1    1.04883    1.06927 +/- 0.00490
#       116/1    1.08306    1.06948 +/- 0.00482
#       117/1    1.10622    1.07003 +/- 0.00478
#       118/1    1.01598    1.06923 +/- 0.00478
#       119/1    1.08660    1.06949 +/- 0.00472
#       120/1    1.08452    1.06970 +/- 0.00465
#       121/1    1.08723    1.06995 +/- 0.00459
#       122/1    1.09493    1.07030 +/- 0.00454
#       123/1    1.04636    1.06997 +/- 0.00449
#       124/1    1.11510    1.07058 +/- 0.00447
#       125/1    1.02655    1.06999 +/- 0.00445
#       126/1    0.96047    1.06855 +/- 0.00462
#       127/1    1.07460    1.06863 +/- 0.00456
#       128/1    1.06114    1.06853 +/- 0.00451
#       129/1    1.06094    1.06844 +/- 0.00445
#       130/1    1.10085    1.06884 +/- 0.00441
#       131/1    1.02016    1.06824 +/- 0.00440
#       132/1    1.11932    1.06886 +/- 0.00439
#       133/1    1.05925    1.06875 +/- 0.00434
#       134/1    1.08800    1.06898 +/- 0.00429
#       135/1    1.01480    1.06834 +/- 0.00429
#       136/1    1.07199    1.06838 +/- 0.00424
#       137/1    1.10221    1.06877 +/- 0.00421
#       138/1    1.18565    1.07010 +/- 0.00437
#       139/1    1.10128    1.07045 +/- 0.00433
#       140/1    1.04188    1.07013 +/- 0.00429
#       141/1    1.05137    1.06992 +/- 0.00425
#       142/1    1.07428    1.06997 +/- 0.00421
#       143/1    0.97754    1.06898 +/- 0.00428
#       144/1    1.12119    1.06953 +/- 0.00427
#       145/1    1.07913    1.06963 +/- 0.00422
#       146/1    1.05610    1.06949 +/- 0.00418
#       147/1    1.09950    1.06980 +/- 0.00415
#       148/1    1.05584    1.06966 +/- 0.00411
#       149/1    1.04370    1.06940 +/- 0.00408
#       150/1    1.02532    1.06896 +/- 0.00406
#       151/1    1.14340    1.06969 +/- 0.00409
#       152/1    1.12464    1.07023 +/- 0.00408
#       153/1    1.10907    1.07061 +/- 0.00406
#       154/1    1.04625    1.07038 +/- 0.00403
#       155/1    1.01649    1.06986 +/- 0.00402
#       156/1    1.10654    1.07021 +/- 0.00400
#       157/1    1.07257    1.07023 +/- 0.00396
#       158/1    0.98822    1.06947 +/- 0.00400
#       159/1    1.01338    1.06896 +/- 0.00399
#       160/1    1.00011    1.06833 +/- 0.00401
#       161/1    1.02736    1.06796 +/- 0.00399
#       162/1    1.17208    1.06889 +/- 0.00406
#       163/1    1.06441    1.06885 +/- 0.00402
#       164/1    1.03616    1.06857 +/- 0.00400
#       165/1    1.03375    1.06826 +/- 0.00397
#       166/1    1.06122    1.06820 +/- 0.00394
#       167/1    1.04096    1.06797 +/- 0.00391
#       168/1    1.04007    1.06773 +/- 0.00389
#       169/1    1.08875    1.06791 +/- 0.00386
#       170/1    1.06714    1.06790 +/- 0.00383
#       171/1    1.10371    1.06820 +/- 0.00381
#       172/1    1.10780    1.06852 +/- 0.00379
#       173/1    1.06295    1.06848 +/- 0.00376
#       174/1    1.00243    1.06795 +/- 0.00377
#       175/1    1.04535    1.06776 +/- 0.00374
#       176/1    1.02374    1.06742 +/- 0.00373
#       177/1    1.06849    1.06742 +/- 0.00370
#       178/1    1.00134    1.06691 +/- 0.00370
#       179/1    1.09245    1.06711 +/- 0.00368
#       180/1    1.03902    1.06689 +/- 0.00366
#       181/1    1.07574    1.06696 +/- 0.00363
#       182/1    1.14463    1.06755 +/- 0.00365
#       183/1    1.02164    1.06720 +/- 0.00364
#       184/1    1.01872    1.06684 +/- 0.00363
#       185/1    1.08759    1.06699 +/- 0.00361
#       186/1    1.03562    1.06676 +/- 0.00359
#       187/1    1.08764    1.06691 +/- 0.00357
#       188/1    1.07210    1.06695 +/- 0.00354
#       189/1    1.06205    1.06692 +/- 0.00351
#       190/1    1.04958    1.06679 +/- 0.00349
#       191/1    1.13093    1.06725 +/- 0.00350
#       192/1    1.03347    1.06701 +/- 0.00348
#       193/1    1.05670    1.06694 +/- 0.00346
#       194/1    1.04223    1.06677 +/- 0.00344
#       195/1    1.01841    1.06643 +/- 0.00343
#       196/1    1.07784    1.06651 +/- 0.00341
#       197/1    1.06181    1.06648 +/- 0.00338
#       198/1    1.06596    1.06647 +/- 0.00336
#       199/1    1.09655    1.06668 +/- 0.00334
#       200/1    1.02689    1.06641 +/- 0.00333
#  Triggers unsatisfied, max unc./thresh. is 2.072245266203943 for eigenvalue
#  The estimated number of batches is 695
#  Creating state point ./mgxs_casl_2e/statepoint.00200.h5...
#       201/1    1.08521    1.06654 +/- 0.00331
#  Triggers unsatisfied, max unc./thresh. is 2.088710055900249 for eigenvalue
#  The estimated number of batches is 709
#       202/1    1.08964    1.06669 +/- 0.00329
#  Triggers unsatisfied, max unc./thresh. is 2.0749582381089806 for eigenvalue
#  The estimated number of batches is 705
#       203/1    1.07753    1.06676 +/- 0.00327
#  Triggers unsatisfied, max unc./thresh. is 2.068373475745201 for eigenvalue
#  The estimated number of batches is 705
#       204/1    1.04461    1.06661 +/- 0.00325
#  Triggers unsatisfied, max unc./thresh. is 2.07317917227143 for eigenvalue
#  The estimated number of batches is 712
#       205/1    1.07344    1.06666 +/- 0.00323
#  Triggers unsatisfied, max unc./thresh. is 2.061280666170817 for eigenvalue
#  The estimated number of batches is 709
#       206/1    1.07487    1.06671 +/- 0.00321
#  Triggers unsatisfied, max unc./thresh. is 2.0576829384574973 for eigenvalue
#  The estimated number of batches is 711
#       207/1    1.06908    1.06673 +/- 0.00319
#  Triggers unsatisfied, max unc./thresh. is 2.051422545228925 for eigenvalue
#  The estimated number of batches is 711
#       208/1    1.06343    1.06671 +/- 0.00317
#  Triggers unsatisfied, max unc./thresh. is 2.0485269449748422 for eigenvalue
#  The estimated number of batches is 714
#       209/1    1.08436    1.06682 +/- 0.00315
#  Triggers unsatisfied, max unc./thresh. is 2.0370060741998386 for eigenvalue
#  The estimated number of batches is 710
#       210/1    1.09697    1.06701 +/- 0.00314
#  Triggers unsatisfied, max unc./thresh. is 2.031364550174588 for eigenvalue
#  The estimated number of batches is 711
#       211/1    1.09550    1.06718 +/- 0.00313
#  Triggers unsatisfied, max unc./thresh. is 2.0239640430424863 for eigenvalue
#  The estimated number of batches is 710
#       212/1    1.04771    1.06706 +/- 0.00311
#  Triggers unsatisfied, max unc./thresh. is 2.0097980700622293 for eigenvalue
#  The estimated number of batches is 705
#       213/1    1.05829    1.06701 +/- 0.00309
#  Triggers unsatisfied, max unc./thresh. is 1.999615859371995 for eigenvalue
#  The estimated number of batches is 702
#       214/1    1.06147    1.06697 +/- 0.00307
#  Triggers unsatisfied, max unc./thresh. is 1.9924506364645518 for eigenvalue
#  The estimated number of batches is 702
#       215/1    1.08670    1.06709 +/- 0.00306
#  Triggers unsatisfied, max unc./thresh. is 1.9860874861547744 for eigenvalue
#  The estimated number of batches is 701
#       216/1    1.05059    1.06699 +/- 0.00304
#  Triggers unsatisfied, max unc./thresh. is 1.9774215700108821 for eigenvalue
#  The estimated number of batches is 700
#       217/1    0.99795    1.06658 +/- 0.00305
#  Triggers unsatisfied, max unc./thresh. is 1.973736315646863 for eigenvalue
#  The estimated number of batches is 701
#       218/1    1.09476    1.06675 +/- 0.00303
#  Triggers unsatisfied, max unc./thresh. is 1.9653649231331392 for eigenvalue
#  The estimated number of batches is 699
#       219/1    1.11622    1.06704 +/- 0.00303
#  Triggers unsatisfied, max unc./thresh. is 1.9565524261066467 for eigenvalue
#  The estimated number of batches is 697
#       220/1    1.08583    1.06715 +/- 0.00301
#  Triggers unsatisfied, max unc./thresh. is 1.9459135850960305 for eigenvalue
#  The estimated number of batches is 694
#       221/1    1.05596    1.06709 +/- 0.00300
#  Triggers unsatisfied, max unc./thresh. is 1.934090963661252 for eigenvalue
#  The estimated number of batches is 690
#       222/1    1.04508    1.06696 +/- 0.00298
#  Triggers unsatisfied, max unc./thresh. is 1.9236215537364194 for eigenvalue
#  The estimated number of batches is 687
#       223/1    1.08807    1.06708 +/- 0.00297
#  Triggers unsatisfied, max unc./thresh. is 1.9210334420103798 for eigenvalue
#  The estimated number of batches is 689
#       224/1    1.18177    1.06774 +/- 0.00302
#  Triggers unsatisfied, max unc./thresh. is 1.9416007655560465 for eigenvalue
#  The estimated number of batches is 706
#       225/1    0.99552    1.06733 +/- 0.00303
#  Triggers unsatisfied, max unc./thresh. is 1.9311656855678696 for eigenvalue
#  The estimated number of batches is 703
#       226/1    1.02046    1.06706 +/- 0.00303
#  Triggers unsatisfied, max unc./thresh. is 1.9303414243101555 for eigenvalue
#  The estimated number of batches is 706
#       227/1    1.03557    1.06688 +/- 0.00302
#  Triggers unsatisfied, max unc./thresh. is 1.9264216148623143 for eigenvalue
#  The estimated number of batches is 707
#       228/1    1.06342    1.06686 +/- 0.00300
#  Triggers unsatisfied, max unc./thresh. is 1.915674942967842 for eigenvalue
#  The estimated number of batches is 704
#       229/1    1.12845    1.06721 +/- 0.00300
#  Triggers unsatisfied, max unc./thresh. is 1.908389107137723 for eigenvalue
#  The estimated number of batches is 702
#       230/1    1.02372    1.06697 +/- 0.00300
#  Triggers unsatisfied, max unc./thresh. is 1.9096271423789826 for eigenvalue
#  The estimated number of batches is 707
#       231/1    0.96887    1.06642 +/- 0.00303
#  Triggers unsatisfied, max unc./thresh. is 1.9145842870625198 for eigenvalue
#  The estimated number of batches is 714
#       232/1    0.97638    1.06593 +/- 0.00305
#  Triggers unsatisfied, max unc./thresh. is 1.9456523045381577 for eigenvalue
#  The estimated number of batches is 739
#       233/1    1.07332    1.06597 +/- 0.00304
#  Triggers unsatisfied, max unc./thresh. is 1.934659686410852 for eigenvalue
#  The estimated number of batches is 735
#       234/1    1.03886    1.06582 +/- 0.00302
#  Triggers unsatisfied, max unc./thresh. is 1.9251795053983665 for eigenvalue
#  The estimated number of batches is 732
#       235/1    1.08308    1.06592 +/- 0.00301
#  Triggers unsatisfied, max unc./thresh. is 1.9178319602254734 for eigenvalue
#  The estimated number of batches is 731
#       236/1    1.06169    1.06589 +/- 0.00299
#  Triggers unsatisfied, max unc./thresh. is 1.9073974930292545 for eigenvalue
#  The estimated number of batches is 727
#       237/1    1.10099    1.06608 +/- 0.00298
#  Triggers unsatisfied, max unc./thresh. is 1.8976848374218473 for eigenvalue
#  The estimated number of batches is 724
#       238/1    1.09328    1.06623 +/- 0.00297
#  Triggers unsatisfied, max unc./thresh. is 1.9006524736907755 for eigenvalue
#  The estimated number of batches is 730
#       239/1    1.09222    1.06636 +/- 0.00296
#  Triggers unsatisfied, max unc./thresh. is 1.890392373206261 for eigenvalue
#  The estimated number of batches is 726
#       240/1    1.02133    1.06613 +/- 0.00295
#  Triggers unsatisfied, max unc./thresh. is 1.8818433125971727 for eigenvalue
#  The estimated number of batches is 723
#       241/1    1.00506    1.06581 +/- 0.00295
#  Triggers unsatisfied, max unc./thresh. is 1.8792023011972352 for eigenvalue
#  The estimated number of batches is 725
#       242/1    1.09363    1.06595 +/- 0.00294
#  Triggers unsatisfied, max unc./thresh. is 1.8691414933037478 for eigenvalue
#  The estimated number of batches is 721
#       243/1    1.04716    1.06585 +/- 0.00293
#  Triggers unsatisfied, max unc./thresh. is 1.8767584780583166 for eigenvalue
#  The estimated number of batches is 730
#       244/1    1.06132    1.06583 +/- 0.00291
#  Triggers unsatisfied, max unc./thresh. is 1.8712090954047558 for eigenvalue
#  The estimated number of batches is 730
#       245/1    1.11849    1.06610 +/- 0.00291
#  Triggers unsatisfied, max unc./thresh. is 1.8637123769195052 for eigenvalue
#  The estimated number of batches is 728
#       246/1    1.07955    1.06617 +/- 0.00290
#  Triggers unsatisfied, max unc./thresh. is 1.8556538261083415 for eigenvalue
#  The estimated number of batches is 725
#       247/1    1.00087    1.06584 +/- 0.00290
#  Triggers unsatisfied, max unc./thresh. is 1.8613940846313464 for eigenvalue
#  The estimated number of batches is 733
#       248/1    1.09961    1.06601 +/- 0.00289
#  Triggers unsatisfied, max unc./thresh. is 1.8591507446630624 for eigenvalue
#  The estimated number of batches is 735
#       249/1    1.04727    1.06591 +/- 0.00288
#  Triggers unsatisfied, max unc./thresh. is 1.8509383439427618 for eigenvalue
#  The estimated number of batches is 732
#       250/1    1.05167    1.06584 +/- 0.00286
#  Triggers unsatisfied, max unc./thresh. is 1.8446014645737894 for eigenvalue
#  The estimated number of batches is 731
#       251/1    1.00062    1.06552 +/- 0.00287
#  Triggers unsatisfied, max unc./thresh. is 1.8460954225807091 for eigenvalue
#  The estimated number of batches is 736
#       252/1    1.09185    1.06565 +/- 0.00286
#  Triggers unsatisfied, max unc./thresh. is 1.8481102226575485 for eigenvalue
#  The estimated number of batches is 740
#       253/1    1.05425    1.06559 +/- 0.00284
#  Triggers unsatisfied, max unc./thresh. is 1.8461356846791197 for eigenvalue
#  The estimated number of batches is 742
#       254/1    1.06343    1.06558 +/- 0.00283
#  Triggers unsatisfied, max unc./thresh. is 1.8464535521431285 for eigenvalue
#  The estimated number of batches is 746
#       255/1    1.07250    1.06562 +/- 0.00282
#  Triggers unsatisfied, max unc./thresh. is 1.8374034056603314 for eigenvalue
#  The estimated number of batches is 743
#       256/1    1.12772    1.06592 +/- 0.00282
#  Triggers unsatisfied, max unc./thresh. is 1.8363860933319005 for eigenvalue
#  The estimated number of batches is 745
#       257/1    1.02517    1.06572 +/- 0.00281
#  Triggers unsatisfied, max unc./thresh. is 1.8283817906822675 for eigenvalue
#  The estimated number of batches is 742
#       258/1    1.04100    1.06560 +/- 0.00280
#  Triggers unsatisfied, max unc./thresh. is 1.8307108428849252 for eigenvalue
#  The estimated number of batches is 748
#       259/1    1.18523    1.06617 +/- 0.00284
#  Triggers unsatisfied, max unc./thresh. is 1.8289528949113227 for eigenvalue
#  The estimated number of batches is 750
#       260/1    1.01322    1.06592 +/- 0.00284
#  Triggers unsatisfied, max unc./thresh. is 1.828702183254264 for eigenvalue
#  The estimated number of batches is 753
#       261/1    1.08832    1.06603 +/- 0.00283
#  Triggers unsatisfied, max unc./thresh. is 1.8373348657401352 for eigenvalue
#  The estimated number of batches is 763
#       262/1    1.07278    1.06606 +/- 0.00282
#  Triggers unsatisfied, max unc./thresh. is 1.8292005020626794 for eigenvalue
#  The estimated number of batches is 760
#       263/1    1.04177    1.06595 +/- 0.00281
#  Triggers unsatisfied, max unc./thresh. is 1.8223411818237025 for eigenvalue
#  The estimated number of batches is 758
#       264/1    1.04682    1.06586 +/- 0.00280
#  Triggers unsatisfied, max unc./thresh. is 1.8142480171641977 for eigenvalue
#  The estimated number of batches is 755
#       265/1    1.01865    1.06564 +/- 0.00279
#  Triggers unsatisfied, max unc./thresh. is 1.8102340742565421 for eigenvalue
#  The estimated number of batches is 755
#       266/1    1.00978    1.06538 +/- 0.00279
#  Triggers unsatisfied, max unc./thresh. is 1.8037823539399314 for eigenvalue
#  The estimated number of batches is 753
#       267/1    1.09001    1.06549 +/- 0.00278
#  Triggers unsatisfied, max unc./thresh. is 1.7949514664079955 for eigenvalue
#  The estimated number of batches is 750
#       268/1    1.09538    1.06563 +/- 0.00277
#  Triggers unsatisfied, max unc./thresh. is 1.793654913898402 for eigenvalue
#  The estimated number of batches is 752
#       269/1    1.05198    1.06557 +/- 0.00276
#  Triggers unsatisfied, max unc./thresh. is 1.7846070252176272 for eigenvalue
#  The estimated number of batches is 748
#       270/1    1.01041    1.06532 +/- 0.00276
#  Triggers unsatisfied, max unc./thresh. is 1.7796130174588192 for eigenvalue
#  The estimated number of batches is 747
#       271/1    1.12877    1.06560 +/- 0.00276
#  Triggers unsatisfied, max unc./thresh. is 1.7785321742414215 for eigenvalue
#  The estimated number of batches is 750
#       272/1    1.05941    1.06557 +/- 0.00275
#  Triggers unsatisfied, max unc./thresh. is 1.7831735580232622 for eigenvalue
#  The estimated number of batches is 756
#       273/1    1.11757    1.06581 +/- 0.00274
#  Triggers unsatisfied, max unc./thresh. is 1.7736733640761024 for eigenvalue
#  The estimated number of batches is 752
#       274/1    1.09649    1.06594 +/- 0.00274
#  Triggers unsatisfied, max unc./thresh. is 1.7683575004384835 for eigenvalue
#  The estimated number of batches is 751
#       275/1    1.01762    1.06573 +/- 0.00273
#  Triggers unsatisfied, max unc./thresh. is 1.773406878345986 for eigenvalue
#  The estimated number of batches is 758
#       276/1    1.01052    1.06549 +/- 0.00273
#  Triggers unsatisfied, max unc./thresh. is 1.7735496226765997 for eigenvalue
#  The estimated number of batches is 761
#       277/1    1.10518    1.06566 +/- 0.00272
#  Triggers unsatisfied, max unc./thresh. is 1.781400155627356 for eigenvalue
#  The estimated number of batches is 771
#       278/1    1.02220    1.06547 +/- 0.00272
#  Triggers unsatisfied, max unc./thresh. is 1.7739931596928251 for eigenvalue
#  The estimated number of batches is 768
#       279/1    1.09733    1.06561 +/- 0.00271
#  Triggers unsatisfied, max unc./thresh. is 1.765795440253293 for eigenvalue
#  The estimated number of batches is 765
#       280/1    1.07922    1.06567 +/- 0.00270
#  Triggers unsatisfied, max unc./thresh. is 1.7579623457564726 for eigenvalue
#  The estimated number of batches is 761
#       281/1    1.03236    1.06552 +/- 0.00269
#  Triggers unsatisfied, max unc./thresh. is 1.753012736479973 for eigenvalue
#  The estimated number of batches is 760
#       282/1    0.96261    1.06508 +/- 0.00272
#  Triggers unsatisfied, max unc./thresh. is 1.7619406624759752 for eigenvalue
#  The estimated number of batches is 771
#       283/1    1.11409    1.06529 +/- 0.00271
#  Triggers unsatisfied, max unc./thresh. is 1.7562596062847433 for eigenvalue
#  The estimated number of batches is 769
#       284/1    1.08858    1.06539 +/- 0.00270
#  Triggers unsatisfied, max unc./thresh. is 1.751208654761569 for eigenvalue
#  The estimated number of batches is 768
#       285/1    1.01791    1.06519 +/- 0.00270
#  Triggers unsatisfied, max unc./thresh. is 1.746257405004975 for eigenvalue
#  The estimated number of batches is 767
#       286/1    1.03759    1.06507 +/- 0.00269
#  Triggers unsatisfied, max unc./thresh. is 1.7384838158721958 for eigenvalue
#  The estimated number of batches is 764
#       287/1    1.16757    1.06550 +/- 0.00271
#  Triggers unsatisfied, max unc./thresh. is 1.7328795620936954 for eigenvalue
#  The estimated number of batches is 762
#       288/1    1.07053    1.06553 +/- 0.00270
#  Triggers unsatisfied, max unc./thresh. is 1.7254502237147793 for eigenvalue
#  The estimated number of batches is 759
#       289/1    1.10406    1.06569 +/- 0.00270
#  Triggers unsatisfied, max unc./thresh. is 1.7225628617017303 for eigenvalue
#  The estimated number of batches is 760
#       290/1    1.03029    1.06554 +/- 0.00269
#  Triggers unsatisfied, max unc./thresh. is 1.7385394600655084 for eigenvalue
#  The estimated number of batches is 776
#       291/1    1.03584    1.06542 +/- 0.00268
#  Triggers unsatisfied, max unc./thresh. is 1.7314985402302105 for eigenvalue
#  The estimated number of batches is 773
#       292/1    1.09176    1.06552 +/- 0.00267
#  Triggers unsatisfied, max unc./thresh. is 1.724449178790005 for eigenvalue
#  The estimated number of batches is 770
#       293/1    1.06935    1.06554 +/- 0.00266
#  Triggers unsatisfied, max unc./thresh. is 1.728575501528178 for eigenvalue
#  The estimated number of batches is 777
#       294/1    1.02916    1.06539 +/- 0.00265
#  Triggers unsatisfied, max unc./thresh. is 1.72226958927245 for eigenvalue
#  The estimated number of batches is 774
#       295/1    1.06487    1.06539 +/- 0.00264
#  Triggers unsatisfied, max unc./thresh. is 1.719597735859235 for eigenvalue
#  The estimated number of batches is 775
#       296/1    0.97997    1.06504 +/- 0.00265
#  Triggers unsatisfied, max unc./thresh. is 1.714473874911167 for eigenvalue
#  The estimated number of batches is 774
#       297/1    1.07271    1.06507 +/- 0.00264
#  Triggers unsatisfied, max unc./thresh. is 1.7117964374550045 for eigenvalue
#  The estimated number of batches is 774
#       298/1    1.05958    1.06505 +/- 0.00263
#  Triggers unsatisfied, max unc./thresh. is 1.7066856555449639 for eigenvalue
#  The estimated number of batches is 773
#       299/1    1.10693    1.06522 +/- 0.00263
#  Triggers unsatisfied, max unc./thresh. is 1.7151795089878485 for eigenvalue
#  The estimated number of batches is 783
#       300/1    1.08132    1.06528 +/- 0.00262
#  Triggers unsatisfied, max unc./thresh. is 1.708935158101672 for eigenvalue
#  The estimated number of batches is 781
#       301/1    1.05740    1.06525 +/- 0.00261
#  Triggers unsatisfied, max unc./thresh. is 1.7031905484976142 for eigenvalue
#  The estimated number of batches is 779
#       302/1    1.04799    1.06518 +/- 0.00260
#  Triggers unsatisfied, max unc./thresh. is 1.6994139459484838 for eigenvalue
#  The estimated number of batches is 778
#       303/1    1.10425    1.06534 +/- 0.00259
#  Triggers unsatisfied, max unc./thresh. is 1.6940589984284369 for eigenvalue
#  The estimated number of batches is 777
#       304/1    1.07227    1.06537 +/- 0.00258
#  Triggers unsatisfied, max unc./thresh. is 1.6867118657577957 for eigenvalue
#  The estimated number of batches is 773
#       305/1    1.10576    1.06552 +/- 0.00258
#  Triggers unsatisfied, max unc./thresh. is 1.6805913738905955 for eigenvalue
#  The estimated number of batches is 771
#       306/1    0.98160    1.06520 +/- 0.00259
#  Triggers unsatisfied, max unc./thresh. is 1.6781472333280139 for eigenvalue
#  The estimated number of batches is 771
#       307/1    1.14929    1.06552 +/- 0.00260
#  Triggers unsatisfied, max unc./thresh. is 1.6712345884055455 for eigenvalue
#  The estimated number of batches is 768
#       308/1    1.12795    1.06576 +/- 0.00260
#  Triggers unsatisfied, max unc./thresh. is 1.6637477083724976 for eigenvalue
#  The estimated number of batches is 765
#       309/1    1.08652    1.06584 +/- 0.00259
#  Triggers unsatisfied, max unc./thresh. is 1.6575348306846263 for eigenvalue
#  The estimated number of batches is 762
#       310/1    1.07964    1.06590 +/- 0.00258
#  Triggers unsatisfied, max unc./thresh. is 1.6517218923085375 for eigenvalue
#  The estimated number of batches is 760
#       311/1    1.11521    1.06609 +/- 0.00258
#  Triggers unsatisfied, max unc./thresh. is 1.647227612695101 for eigenvalue
#  The estimated number of batches is 759
#       312/1    1.14502    1.06639 +/- 0.00259
#  Triggers unsatisfied, max unc./thresh. is 1.6445835951372845 for eigenvalue
#  The estimated number of batches is 759
#       313/1    1.07717    1.06643 +/- 0.00258
#  Triggers unsatisfied, max unc./thresh. is 1.6388363866936038 for eigenvalue
#  The estimated number of batches is 757
#       314/1    1.10949    1.06659 +/- 0.00257
#  Triggers unsatisfied, max unc./thresh. is 1.6345784995995132 for eigenvalue
#  The estimated number of batches is 756
#       315/1    1.04251    1.06650 +/- 0.00256
#  Triggers unsatisfied, max unc./thresh. is 1.6288198517561274 for eigenvalue
#  The estimated number of batches is 754
#       316/1    1.09368    1.06660 +/- 0.00256
#  Triggers unsatisfied, max unc./thresh. is 1.6231360514443443 for eigenvalue
#  The estimated number of batches is 751
#       317/1    1.08128    1.06666 +/- 0.00255
#  Triggers unsatisfied, max unc./thresh. is 1.6169354119571484 for eigenvalue
#  The estimated number of batches is 749
#       318/1    1.08544    1.06673 +/- 0.00254
#  Triggers unsatisfied, max unc./thresh. is 1.6115867914297313 for eigenvalue
#  The estimated number of batches is 747
#       319/1    1.03005    1.06659 +/- 0.00253
#  Triggers unsatisfied, max unc./thresh. is 1.6079997857069723 for eigenvalue
#  The estimated number of batches is 746
#       320/1    1.07245    1.06661 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6017243783629196 for eigenvalue
#  The estimated number of batches is 743
#       321/1    1.12704    1.06684 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6122353175294224 for eigenvalue
#  The estimated number of batches is 755
#       322/1    1.10619    1.06698 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6154947536813193 for eigenvalue
#  The estimated number of batches is 760
#       323/1    1.13414    1.06723 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6112156456333295 for eigenvalue
#  The estimated number of batches is 759
#       324/1    0.96330    1.06685 +/- 0.00254
#  Triggers unsatisfied, max unc./thresh. is 1.6235062479113131 for eigenvalue
#  The estimated number of batches is 773
#       325/1    1.10921    1.06700 +/- 0.00254
#  Triggers unsatisfied, max unc./thresh. is 1.6363950039825927 for eigenvalue
#  The estimated number of batches is 787
#       326/1    1.07801    1.06704 +/- 0.00253
#  Triggers unsatisfied, max unc./thresh. is 1.6306747470522898 for eigenvalue
#  The estimated number of batches is 784
#       327/1    1.12181    1.06724 +/- 0.00253
#  Triggers unsatisfied, max unc./thresh. is 1.6275135103699978 for eigenvalue
#  The estimated number of batches is 784
#       328/1    1.16142    1.06758 +/- 0.00254
#  Triggers unsatisfied, max unc./thresh. is 1.6207532277248842 for eigenvalue
#  The estimated number of batches is 781
#       329/1    1.02290    1.06742 +/- 0.00254
#  Triggers unsatisfied, max unc./thresh. is 1.6156690606959576 for eigenvalue
#  The estimated number of batches is 779
#       330/1    1.09924    1.06753 +/- 0.00253
#  Triggers unsatisfied, max unc./thresh. is 1.6126861161579162 for eigenvalue
#  The estimated number of batches is 779
#       331/1    1.03090    1.06740 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6103568278885207 for eigenvalue
#  The estimated number of batches is 779
#       332/1    1.06716    1.06740 +/- 0.00252
#  Triggers unsatisfied, max unc./thresh. is 1.6036867268947357 for eigenvalue
#  The estimated number of batches is 776
#       333/1    1.12497    1.06760 +/- 0.00251
#  Triggers unsatisfied, max unc./thresh. is 1.5987168576077229 for eigenvalue
#  The estimated number of batches is 774
#       334/1    1.07243    1.06762 +/- 0.00251
#  Triggers unsatisfied, max unc./thresh. is 1.5990655945676053 for eigenvalue
#  The estimated number of batches is 777
#       335/1    1.04832    1.06755 +/- 0.00250
#  Triggers unsatisfied, max unc./thresh. is 1.6033201663957484 for eigenvalue
#  The estimated number of batches is 783
#       336/1    1.12616    1.06776 +/- 0.00250
#  Triggers unsatisfied, max unc./thresh. is 1.6074849150633845 for eigenvalue
#  The estimated number of batches is 790
#       337/1    1.12159    1.06795 +/- 0.00250
#  Triggers unsatisfied, max unc./thresh. is 1.6028893928643477 for eigenvalue
#  The estimated number of batches is 788
#       338/1    1.09396    1.06804 +/- 0.00249
#  Triggers unsatisfied, max unc./thresh. is 1.6004094960878228 for eigenvalue
#  The estimated number of batches is 788
#       339/1    1.02403    1.06788 +/- 0.00248
#  Triggers unsatisfied, max unc./thresh. is 1.595083868517125 for eigenvalue
#  The estimated number of batches is 786
#       340/1    1.01312    1.06770 +/- 0.00248
#  Triggers unsatisfied, max unc./thresh. is 1.5952106209027903 for eigenvalue
#  The estimated number of batches is 788
#       341/1    1.06503    1.06769 +/- 0.00248
#  Triggers unsatisfied, max unc./thresh. is 1.5898135473233195 for eigenvalue
#  The estimated number of batches is 786
#       342/1    1.05252    1.06763 +/- 0.00247
#  Triggers unsatisfied, max unc./thresh. is 1.586528221215061 for eigenvalue
#  The estimated number of batches is 785
#       343/1    1.08942    1.06771 +/- 0.00246
#  Triggers unsatisfied, max unc./thresh. is 1.581502377985694 for eigenvalue
#  The estimated number of batches is 783
#       344/1    1.03432    1.06760 +/- 0.00245
#  Triggers unsatisfied, max unc./thresh. is 1.5765812686899408 for eigenvalue
#  The estimated number of batches is 781
#       345/1    1.03102    1.06747 +/- 0.00245
#  Triggers unsatisfied, max unc./thresh. is 1.5718424740649954 for eigenvalue
#  The estimated number of batches is 779
#       346/1    1.03193    1.06735 +/- 0.00244
#  Triggers unsatisfied, max unc./thresh. is 1.5668362184829885 for eigenvalue
#  The estimated number of batches is 777
#       347/1    1.10194    1.06747 +/- 0.00244
#  Triggers unsatisfied, max unc./thresh. is 1.5627683616191725 for eigenvalue
#  The estimated number of batches is 776
#       348/1    1.05940    1.06744 +/- 0.00243
#  Triggers unsatisfied, max unc./thresh. is 1.557285339371935 for eigenvalue
#  The estimated number of batches is 773
#       349/1    1.05397    1.06740 +/- 0.00242
#  Triggers unsatisfied, max unc./thresh. is 1.5544842348916557 for eigenvalue
#  The estimated number of batches is 773
#       350/1    1.09197    1.06748 +/- 0.00242
#  Triggers unsatisfied, max unc./thresh. is 1.549892319318529 for eigenvalue
#  The estimated number of batches is 771
#       351/1    1.02461    1.06733 +/- 0.00241
#  Triggers unsatisfied, max unc./thresh. is 1.548031586016383 for eigenvalue
#  The estimated number of batches is 772
#       352/1    1.16177    1.06765 +/- 0.00242
#  Triggers unsatisfied, max unc./thresh. is 1.5465369355169205 for eigenvalue
#  The estimated number of batches is 773
#       353/1    1.05475    1.06760 +/- 0.00242
#  Triggers unsatisfied, max unc./thresh. is 1.5418801582462627 for eigenvalue
#  The estimated number of batches is 771
#       354/1    1.10357    1.06772 +/- 0.00241
#  Triggers unsatisfied, max unc./thresh. is 1.5389884130099636 for eigenvalue
#  The estimated number of batches is 771
#       355/1    1.12812    1.06792 +/- 0.00241
#  Triggers unsatisfied, max unc./thresh. is 1.53474941781563 for eigenvalue
#  The estimated number of batches is 769
#       356/1    1.02543    1.06778 +/- 0.00241
#  Triggers unsatisfied, max unc./thresh. is 1.5346677831522622 for eigenvalue
#  The estimated number of batches is 771
#       357/1    1.05027    1.06773 +/- 0.00240
#  Triggers unsatisfied, max unc./thresh. is 1.529206404257912 for eigenvalue
#  The estimated number of batches is 768
#       358/1    1.09739    1.06782 +/- 0.00239
#  Triggers unsatisfied, max unc./thresh. is 1.5245472554961792 for eigenvalue
#  The estimated number of batches is 766
#       359/1    1.05435    1.06778 +/- 0.00239
#  Triggers unsatisfied, max unc./thresh. is 1.5198493459747546 for eigenvalue
#  The estimated number of batches is 764
#       360/1    1.04502    1.06770 +/- 0.00238
#  Triggers unsatisfied, max unc./thresh. is 1.516760956894352 for eigenvalue
#  The estimated number of batches is 764
#       361/1    1.12102    1.06788 +/- 0.00238
#  Triggers unsatisfied, max unc./thresh. is 1.511906699247402 for eigenvalue
#  The estimated number of batches is 761
#       362/1    1.04076    1.06779 +/- 0.00237
#  Triggers unsatisfied, max unc./thresh. is 1.5073922462000182 for eigenvalue
#  The estimated number of batches is 759
#       363/1    1.12141    1.06796 +/- 0.00237
#  Triggers unsatisfied, max unc./thresh. is 1.5128518151343513 for eigenvalue
#  The estimated number of batches is 767
#       364/1    1.04026    1.06787 +/- 0.00237
#  Triggers unsatisfied, max unc./thresh. is 1.5080575398243945 for eigenvalue
#  The estimated number of batches is 765
#       365/1    1.05822    1.06784 +/- 0.00236
#  Triggers unsatisfied, max unc./thresh. is 1.5035503230013896 for eigenvalue
#  The estimated number of batches is 763
#       366/1    1.06868    1.06784 +/- 0.00235
#  Triggers unsatisfied, max unc./thresh. is 1.4988510794214633 for eigenvalue
#  The estimated number of batches is 760
#       367/1    1.06788    1.06784 +/- 0.00234
#  Triggers unsatisfied, max unc./thresh. is 1.4951320790205465 for eigenvalue
#  The estimated number of batches is 759
#       368/1    1.07441    1.06787 +/- 0.00234
#  Triggers unsatisfied, max unc./thresh. is 1.4950432406568968 for eigenvalue
#  The estimated number of batches is 761
#       369/1    1.10826    1.06799 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.4940973077706141 for eigenvalue
#  The estimated number of batches is 763
#       370/1    1.10021    1.06809 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.489609933657903 for eigenvalue
#  The estimated number of batches is 761
#       371/1    1.09258    1.06817 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4867334601002944 for eigenvalue
#  The estimated number of batches is 760
#       372/1    0.95485    1.06782 +/- 0.00234
#  Triggers unsatisfied, max unc./thresh. is 1.4844731719301023 for eigenvalue
#  The estimated number of batches is 760
#       373/1    1.03334    1.06771 +/- 0.00234
#  Triggers unsatisfied, max unc./thresh. is 1.4809208585912979 for eigenvalue
#  The estimated number of batches is 759
#       374/1    1.06522    1.06770 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.477681703943071 for eigenvalue
#  The estimated number of batches is 758
#       375/1    1.02056    1.06756 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.4735443894219602 for eigenvalue
#  The estimated number of batches is 756
#       376/1    1.07130    1.06757 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4694022064897554 for eigenvalue
#  The estimated number of batches is 754
#       377/1    0.98185    1.06731 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.4723526298874243 for eigenvalue
#  The estimated number of batches is 759
#       378/1    1.00160    1.06711 +/- 0.00233
#  Triggers unsatisfied, max unc./thresh. is 1.4702413334630127 for eigenvalue
#  The estimated number of batches is 760
#       379/1    1.04671    1.06704 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4716736896524596 for eigenvalue
#  The estimated number of batches is 763
#       380/1    1.00191    1.06685 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4692311513211735 for eigenvalue
#  The estimated number of batches is 763
#       381/1    1.02470    1.06672 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4648346744429896 for eigenvalue
#  The estimated number of batches is 761
#       382/1    1.13245    1.06692 +/- 0.00232
#  Triggers unsatisfied, max unc./thresh. is 1.4645582118986986 for eigenvalue
#  The estimated number of batches is 763
#       383/1    1.05553    1.06688 +/- 0.00231
#  Triggers unsatisfied, max unc./thresh. is 1.4604077623832725 for eigenvalue
#  The estimated number of batches is 761
#       384/1    1.10625    1.06700 +/- 0.00231
#  Triggers unsatisfied, max unc./thresh. is 1.4589062330368854 for eigenvalue
#  The estimated number of batches is 761
#       385/1    1.04038    1.06692 +/- 0.00230
#  Triggers unsatisfied, max unc./thresh. is 1.4547279645798374 for eigenvalue
#  The estimated number of batches is 759
#       386/1    1.02259    1.06679 +/- 0.00230
#  Triggers unsatisfied, max unc./thresh. is 1.4624587060867533 for eigenvalue
#  The estimated number of batches is 769
#       387/1    1.08723    1.06685 +/- 0.00230
#  Triggers unsatisfied, max unc./thresh. is 1.4582195110257785 for eigenvalue
#  The estimated number of batches is 767
#       388/1    1.02434    1.06672 +/- 0.00229
#  Triggers unsatisfied, max unc./thresh. is 1.4565944849787529 for eigenvalue
#  The estimated number of batches is 768
#       389/1    1.04256    1.06665 +/- 0.00229
#  Triggers unsatisfied, max unc./thresh. is 1.4568992383734785 for eigenvalue
#  The estimated number of batches is 770
#       390/1    1.06000    1.06663 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.4569284873214219 for eigenvalue
#  The estimated number of batches is 772
#       391/1    1.01371    1.06648 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.452673920554754 for eigenvalue
#  The estimated number of batches is 770
#       392/1    1.11434    1.06662 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.4488122713137308 for eigenvalue
#  The estimated number of batches is 768
#       393/1    0.97951    1.06636 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.4564589137521489 for eigenvalue
#  The estimated number of batches is 778
#       394/1    1.01216    1.06621 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.4554921788873605 for eigenvalue
#  The estimated number of batches is 779
#       395/1    1.05406    1.06617 +/- 0.00228
#  Triggers unsatisfied, max unc./thresh. is 1.4514983055389201 for eigenvalue
#  The estimated number of batches is 777
#       396/1    1.04452    1.06611 +/- 0.00227
#  Triggers unsatisfied, max unc./thresh. is 1.4482270769824461 for eigenvalue
#  The estimated number of batches is 776
#       397/1    1.02774    1.06600 +/- 0.00227
#  Triggers unsatisfied, max unc./thresh. is 1.445793173765425 for eigenvalue
#  The estimated number of batches is 776
#       398/1    1.05194    1.06596 +/- 0.00226
#  Triggers unsatisfied, max unc./thresh. is 1.4427855292235563 for eigenvalue
#  The estimated number of batches is 775
#       399/1    1.08230    1.06601 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4480704876578683 for eigenvalue
#  The estimated number of batches is 782
#       400/1    1.09895    1.06610 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4474677433558962 for eigenvalue
#  The estimated number of batches is 784
#       401/1    1.09990    1.06620 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.443772635426431 for eigenvalue
#  The estimated number of batches is 782
#       402/1    0.96944    1.06592 +/- 0.00226
#  Triggers unsatisfied, max unc./thresh. is 1.4447883610608845 for eigenvalue
#  The estimated number of batches is 785
#       403/1    1.04669    1.06587 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4439180632902107 for eigenvalue
#  The estimated number of batches is 786
#       404/1    1.06857    1.06587 +/- 0.00224
#  Triggers unsatisfied, max unc./thresh. is 1.4409741797716364 for eigenvalue
#  The estimated number of batches is 786
#       405/1    1.16126    1.06614 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4449472951119786 for eigenvalue
#  The estimated number of batches is 792
#       406/1    1.07213    1.06616 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4447639086372581 for eigenvalue
#  The estimated number of batches is 794
#       407/1    1.10871    1.06628 +/- 0.00224
#  Triggers unsatisfied, max unc./thresh. is 1.4423769597694334 for eigenvalue
#  The estimated number of batches is 793
#       408/1    1.01372    1.06613 +/- 0.00224
#  Triggers unsatisfied, max unc./thresh. is 1.4414938856346626 for eigenvalue
#  The estimated number of batches is 794
#       409/1    0.98677    1.06591 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4389140424938593 for eigenvalue
#  The estimated number of batches is 794
#       410/1    1.01408    1.06577 +/- 0.00225
#  Triggers unsatisfied, max unc./thresh. is 1.4438139764821767 for eigenvalue
# ...
#      1547/1    1.17729    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0301035963435026 for eigenvalue
#  The estimated number of batches is 1641
#      1548/1    1.18031    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0300538740818195 for eigenvalue
#  The estimated number of batches is 1642
#      1549/1    1.18297    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0293793799791333 for eigenvalue
#  The estimated number of batches is 1641
#      1550/1    1.17603    1.18156 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028755726482358 for eigenvalue
#  The estimated number of batches is 1640
#      1551/1    1.18275    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028237282791269 for eigenvalue
#  The estimated number of batches is 1639
#      1552/1    1.19465    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0281418557430162 for eigenvalue
#  The estimated number of batches is 1640
#      1553/1    1.19815    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0282050446357744 for eigenvalue
#  The estimated number of batches is 1641
#      1554/1    1.18030    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0275472944250499 for eigenvalue
#  The estimated number of batches is 1640
#      1555/1    1.17580    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0269972897301543 for eigenvalue
#  The estimated number of batches is 1640
#      1556/1    1.18738    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.026386918526928 for eigenvalue
#  The estimated number of batches is 1639
#      1557/1    1.18066    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025790294234683 for eigenvalue
#  The estimated number of batches is 1638
#      1558/1    1.17388    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0254246381132006 for eigenvalue
#  The estimated number of batches is 1638
#      1559/1    1.17726    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.024897488408665 for eigenvalue
#  The estimated number of batches is 1637
#      1560/1    1.18453    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0243955101952398 for eigenvalue
#  The estimated number of batches is 1637
#      1561/1    1.18952    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023724800402937 for eigenvalue
#  The estimated number of batches is 1635
#      1562/1    1.18906    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0230504146796842 for eigenvalue
#  The estimated number of batches is 1634
#      1563/1    1.17200    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229731776748137 for eigenvalue
#  The estimated number of batches is 1635
#      1564/1    1.19330    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023644813917082 for eigenvalue
#  The estimated number of batches is 1638
#      1565/1    1.18698    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0231004180931969 for eigenvalue
#  The estimated number of batches is 1638
#      1566/1    1.18275    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0224387562644779 for eigenvalue
#  The estimated number of batches is 1637
#      1567/1    1.18114    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0222953823179548 for eigenvalue
#  The estimated number of batches is 1637
#      1568/1    1.17656    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0216800720811214 for eigenvalue
#  The estimated number of batches is 1636
#      1569/1    1.17750    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214739584148051 for eigenvalue
#  The estimated number of batches is 1637
#      1570/1    1.17708    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020973946587673 for eigenvalue
#  The estimated number of batches is 1636
#      1571/1    1.17414    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204353241137618 for eigenvalue
#  The estimated number of batches is 1636
#      1572/1    1.18905    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019780010095114 for eigenvalue
#  The estimated number of batches is 1635
#      1573/1    1.18456    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0191199900117829 for eigenvalue
#  The estimated number of batches is 1633
#      1574/1    1.18758    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018446303246402 for eigenvalue
#  The estimated number of batches is 1632
#      1575/1    1.19896    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0206251872600502 for eigenvalue
#  The estimated number of batches is 1640
#      1576/1    1.18885    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0203702790956495 for eigenvalue
#  The estimated number of batches is 1641
#      1577/1    1.17704    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198083309650556 for eigenvalue
#  The estimated number of batches is 1640
#      1578/1    1.18494    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193552734501277 for eigenvalue
#  The estimated number of batches is 1639
#      1579/1    1.17612    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193272037796448 for eigenvalue
#  The estimated number of batches is 1640
#      1580/1    1.18114    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018693106440465 for eigenvalue
#  The estimated number of batches is 1639
#      1581/1    1.18327    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180990117238888 for eigenvalue
#  The estimated number of batches is 1639
#      1582/1    1.17552    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177101478337598 for eigenvalue
#  The estimated number of batches is 1638
#      1583/1    1.18171    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017055617579926 for eigenvalue
#  The estimated number of batches is 1637
#      1584/1    1.18061    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166066394424342 for eigenvalue
#  The estimated number of batches is 1637
#      1585/1    1.18898    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166703721576775 for eigenvalue
#  The estimated number of batches is 1638
#      1586/1    1.19299    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170147113536505 for eigenvalue
#  The estimated number of batches is 1640
#      1587/1    1.18200    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164002888413703 for eigenvalue
#  The estimated number of batches is 1639
#      1588/1    1.17333    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163525080544988 for eigenvalue
#  The estimated number of batches is 1640
#      1589/1    1.17201    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163591592136667 for eigenvalue
#  The estimated number of batches is 1641
#      1590/1    1.19385    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0157396025627834 for eigenvalue
#  The estimated number of batches is 1640
#      1591/1    1.17461    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0153930863979466 for eigenvalue
#  The estimated number of batches is 1640
#      1592/1    1.18195    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147457542785452 for eigenvalue
#  The estimated number of batches is 1639
#      1593/1    1.17720    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141802130458109 for eigenvalue
#  The estimated number of batches is 1638
#      1594/1    1.17407    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0138467421118313 for eigenvalue
#  The estimated number of batches is 1638
#      1595/1    1.18518    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0131819493192356 for eigenvalue
#  The estimated number of batches is 1637
#      1596/1    1.18464    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0125456052706236 for eigenvalue
#  The estimated number of batches is 1636
#      1597/1    1.18597    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011912182478488 for eigenvalue
#  The estimated number of batches is 1635
#      1598/1    1.18274    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0117330866216734 for eigenvalue
#  The estimated number of batches is 1636
#      1599/1    1.17492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111431212777842 for eigenvalue
#  The estimated number of batches is 1635
#      1600/1    1.17466    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115921829661432 for eigenvalue
#  The estimated number of batches is 1637
#      1601/1    1.17892    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111091804467538 for eigenvalue
#  The estimated number of batches is 1637
#      1602/1    1.17046    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011036386897514 for eigenvalue
#  The estimated number of batches is 1638
#      1603/1    1.18729    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0104155377473154 for eigenvalue
#  The estimated number of batches is 1637
#      1604/1    1.17693    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0101722166241356 for eigenvalue
#  The estimated number of batches is 1637
#      1605/1    1.18002    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102251400270015 for eigenvalue
#  The estimated number of batches is 1638
#      1606/1    1.17419    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096029800085493 for eigenvalue
#  The estimated number of batches is 1637
#      1607/1    1.20125    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009310772641225 for eigenvalue
#  The estimated number of batches is 1637
#      1608/1    1.19361    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01003134212993 for eigenvalue
#  The estimated number of batches is 1641
#      1609/1    1.18837    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0103322457331263 for eigenvalue
#  The estimated number of batches is 1643
#      1610/1    1.18598    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097721002448734 for eigenvalue
#  The estimated number of batches is 1642
#      1611/1    1.16718    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099989214196454 for eigenvalue
#  The estimated number of batches is 1643
#      1612/1    1.18902    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097935254104733 for eigenvalue
#  The estimated number of batches is 1644
#      1613/1    1.17884    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009868904941159 for eigenvalue
#  The estimated number of batches is 1645
#      1614/1    1.18538    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00923643556946 for eigenvalue
#  The estimated number of batches is 1644
#      1615/1    1.17623    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0089435196061098 for eigenvalue
#  The estimated number of batches is 1644
#      1616/1    1.17859    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008905829515394 for eigenvalue
#  The estimated number of batches is 1645
#      1617/1    1.18204    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0082770770746678 for eigenvalue
#  The estimated number of batches is 1644
#      1618/1    1.18125    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0078402208466295 for eigenvalue
#  The estimated number of batches is 1644
#      1619/1    1.16938    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0072610890245743 for eigenvalue
#  The estimated number of batches is 1643
#      1620/1    1.17142    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007230250663518 for eigenvalue
#  The estimated number of batches is 1644
#      1621/1    1.18646    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0066032255007418 for eigenvalue
#  The estimated number of batches is 1643
#      1622/1    1.19101    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060696868892256 for eigenvalue
#  The estimated number of batches is 1642
#      1623/1    1.18579    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061795196531884 for eigenvalue
#  The estimated number of batches is 1643
#      1624/1    1.19450    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055575122805613 for eigenvalue
#  The estimated number of batches is 1642
#      1625/1    1.16829    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0053873296357614 for eigenvalue
#  The estimated number of batches is 1643
#      1626/1    1.18023    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0048340109843639 for eigenvalue
#  The estimated number of batches is 1642
#      1627/1    1.18033    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041977923388297 for eigenvalue
#  The estimated number of batches is 1641
#      1628/1    1.19163    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038282741136422 for eigenvalue
#  The estimated number of batches is 1641
#      1629/1    1.18492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032524589422542 for eigenvalue
#  The estimated number of batches is 1640
#      1630/1    1.19150    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029040132426896 for eigenvalue
#  The estimated number of batches is 1640
#      1631/1    1.17866    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025054245466567 for eigenvalue
#  The estimated number of batches is 1640
#      1632/1    1.17531    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020537859066725 for eigenvalue
#  The estimated number of batches is 1639
#      1633/1    1.19327    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015243856120508 for eigenvalue
#  The estimated number of batches is 1638
#      1634/1    1.18072    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000900482333582 for eigenvalue
#  The estimated number of batches is 1637
#      1635/1    1.18718    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004631248772617 for eigenvalue
#  The estimated number of batches is 1637
#      1636/1    1.18024    1.18161 +/- 0.00016
#  Triggers satisfied for batch 1636
#  Creating state point statepoint.01636.h5...
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.5020e+00 seconds
#    Reading cross sections          = 3.4659e+00 seconds
#  Total time in simulation          = 1.1285e+03 seconds
#    Time in transport only          = 1.1199e+03 seconds
#    Time in inactive batches        = 8.3742e+00 seconds
#    Time in active batches          = 1.1201e+03 seconds
#    Time synchronizing fission bank = 1.1071e+00 seconds
#      Sampling source sites         = 8.4232e-01 seconds
#      SEND/RECV source sites        = 2.6396e-01 seconds
#    Time accumulating tallies       = 6.2389e+00 seconds
#    Time writing statepoints        = 5.1530e-01 seconds
#  Total time for finalization       = 1.1527e+01 seconds
#  Total time elapsed                = 1.1436e+03 seconds
#  Calculation Rate (inactive)       = 119414 particles/second
#  Calculation Rate (active)         = 72135.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18174 +/- 0.00013
#  k-effective (Track-length)  = 1.18161 +/- 0.00016
#  k-effective (Absorption)    = 1.18170 +/- 0.00011
#  Combined k-effective        = 1.18170 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(statepoint_filename)

# %% [markdown]
# ## MGXS Tally Outputs

# %%
xs_names = [] 
for set in (mgxs_lib.domains):
    print(set.name)
    xs_names.append(set.name)

#print(mgxs_lib.domains)
# Out:
# fuel
# clad
# moderator
# gap
# steel_cell
# gap_cell
# pyrex_cell
# water_cell
# guide_cell
# gt-water-in
# gt-clad
# gt-water-out
# it-water-in
# it-clad
# it-water-out
# water_outside

# %%
if one_eighth:
    txt = 'one_eighth'
else:
    txt = 'one_quarter'

# %%
mgxs_lib.load_from_statepoint(sp)
    
h5_file_path = my_path + f'/mgxs_{my_case}_{txt}_{egroup_name}.h5'
print(h5_file_path)

# below, no need for xs_type = 'macro' as it is the default
mgxs_lib.create_mg_library(xsdata_names=xs_names).export_to_hdf5(h5_file_path)
# Out:
# ./mgxs_casl_2e/mgxs_2e_one_eighth_SHEM-361.h5

# %% [markdown]
# ## Power Tally Outputs

# %%
computed_power_tallies = sp.get_tally()
power_tally_values = computed_power_tallies.get_values()

pin_power_file_path = my_path + f'/pinpow_{my_case}_{txt}_{egroup_name}.npy'
np.save(pin_power_file_path, power_tally_values)

# %%
for score_id in range(0,len(computed_power_tallies.scores)):
     # get name of the score
    score = computed_power_tallies.scores[score_id]
    print('score = ',score)
    # extract + shape the data
    vals = power_tally_values[:,0,score_id].reshape(17,17)
    vals = vals[8:,8:]
    
    dd = np.copy(vals)

    # multiply axis of symeetry by 2 for power display
    dd[0,:] *= 2
    dd[np.diag_indices_from(dd)] *= 2

    dd = np.flip(dd,axis=0)
    
    # normalize
    idx_fuel_cells = np.argwhere(dd>0)
    nnz_fuel_cells = np.asarray(idx_fuel_cells).shape[0]
    dd /= np.sum(dd)
    dd *= nnz_fuel_cells

    table = PrettyTable()

    n_list = [str(n) for n in range(1, 10)]
    table.field_names = n_list

    # Convert ndarray to list of lists
    data_list = dd.tolist()

    for row in data_list:
        # Format each value to 2 decimal places
        formatted_row = [f"{x:.6g}" for x in row]
        table.add_row(formatted_row)

    print(table)
# Out:
# score =  fission
# +---+---------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2    |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+---------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     |    0     | 1.04475  |
# | 0 |    0    |    0     |    0     |    0     |    0     |    0     | 1.03551  | 1.03665  |
# | 0 |    0    |    0     |    0     |    0     |    0     | 1.04173  | 1.01768  | 1.02212  |
# | 0 |    0    |    0     |    0     |    0     |    0     | 1.04177  | 1.01049  | 1.01021  |
# | 0 |    0    |    0     |    0     | 1.02187  |  1.0242  | 0.954105 | 0.974582 | 1.00311  |
# | 0 |    0    |    0     |    0     |  1.0381  | 0.941444 |    0     | 0.939394 | 0.995634 |
# | 0 |    0    | 0.995556 | 1.02029  | 0.998207 | 0.957257 | 0.936146 | 0.97659  | 0.999025 |
# | 0 | 0.98246 | 0.962869 | 0.936334 | 0.968579 | 0.999629 | 1.03336  | 1.02756  | 1.03138  |
# | 0 | 1.00744 | 0.933919 |    0     | 0.945566 | 1.03292  |    0     |  1.0584  | 1.04316  |
# +---+---------+----------+----------+----------+----------+----------+----------+----------+
# score =  nu-fission
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.04467  |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |  1.0356  | 1.03657  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04136  | 1.01771  | 1.02219  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04139  | 1.01053  | 1.01027  |
# | 0 |    0     |    0     |    0     | 1.02172  | 1.02382  | 0.954457 | 0.974844 | 1.00317  |
# | 0 |    0     |    0     |    0     |  1.0376  | 0.941904 |    0     | 0.939881 | 0.995686 |
# | 0 |    0     | 0.995582 | 1.01996  | 0.998182 | 0.957651 | 0.936673 | 0.976824 | 0.999086 |
# | 0 | 0.982426 | 0.963167 | 0.936745 | 0.968847 | 0.999614 | 1.03301  | 1.02732  | 1.03102  |
# | 0 |  1.0071  | 0.934271 |    0     | 0.945947 | 1.03248  |    0     | 1.05804  | 1.04268  |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# score =  kappa-fission
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.04474  |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     | 1.03552  | 1.03664  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04168  | 1.01769  | 1.02213  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04171  |  1.0105  | 1.01023  |
# | 0 |    0     |    0     |    0     | 1.02184  | 1.02414  | 0.954154 | 0.974625 | 1.00313  |
# | 0 |    0     |    0     |    0     | 1.03802  | 0.941516 |    0     | 0.939469 | 0.995647 |
# | 0 |    0     | 0.995548 | 1.02023  | 0.998195 | 0.957302 | 0.936222 | 0.976625 | 0.999034 |
# | 0 | 0.982459 | 0.962909 | 0.936397 | 0.968617 | 0.999625 | 1.03331  | 1.02752  | 1.03133  |
# | 0 |  1.0074  | 0.93398  |    0     | 0.945608 | 1.03286  |    0     | 1.05834  | 1.04309  |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+

# %%
plt.figure()
plt.imshow(dd, cmap='viridis')  # You can change the colormap if desired
plt.title('2D Array Plot')
plt.colorbar()  # Adds a colorbar to show the scale
plt.clim([0.9,1.1])
plt.show()

# %% [markdown]
# ## Clean up by deleting unwanted files

# %%
def delete_runtime_files(directory='.'):
    """
    Deletes all files with a .xml extension, files named statepoint.NNNNN.h5 where N is a digit,
    and the file named summary.h5 in the specified directory.

    Parameters:
    directory (str): The directory to search for files. Defaults to the current directory.
    """
    
    # Regular expression pattern to match files named statepoint.NNNNN.h5
    pattern = re.compile(r'statepoint\.\d{5}\.h5')

    # Iterate through files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if the file has a .xml extension, matches the pattern, or is named summary.h5
        if filename.endswith('.xml') or pattern.match(filename) or filename == 'summary.h5' \
           or filename == 'tallies.out':
            # Delete the file
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")


# Example usage:
# delete_runtime_files('/path/to/directory')  # specify the directory path if needed

# %%
delete_runtime_files('./')
delete_runtime_files(my_path)
# Out:
# Deleted: ./model.xml
# Deleted: ./mgxs_casl_2e/statepoint.00793.h5
# Deleted: ./mgxs_casl_2e/tallies.out
# Deleted: ./mgxs_casl_2e/statepoint.00200.h5
# Deleted: ./mgxs_casl_2e/summary.h5
