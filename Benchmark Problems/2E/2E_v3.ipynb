# %% [markdown]
# # Fuel assembly: 2E

# %% [markdown]
# ## Import modules

# %%
import sys
import os
import pathlib
import re

import openmc
import openmc.mgxs as mgxs

import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import Counter
from prettytable import PrettyTable

# %% [markdown]
# ## Add location of OpenMC XS executable, setup ENDF xs path

# %%
# Add path to OpenMC binary
# os.environ['PATH'] += r':/path/to/openmc/bin'
#os.environ['PATH'] += r':/Users/jean.ragusa/repo/openmc/local/bin'

# Add location of OpenMC xs data
#%env OPENMC_CROSS_SECTIONS=/Users/jean.ragusa/repo/endfb-vii.1-hdf5/cross_sections.xml

# Are you ragusa?
your_files = os.getcwd()
print(your_files)
if 'ragusa' in your_files:
    os.environ['OPENMC_CROSS_SECTIONS'] = '/home/ragusa/xs/endfb-viii.0-hdf5/cross_sections.xml'
# Out:
# /home/brent10/github/VERA-Examples/Benchmark Problems/2E

# %% [markdown]
# # Start model

# %%
model=openmc.Model()

# %% [markdown]
# ## Define Materials
# ***

# %%
uo2 = openmc.Material(name='uo2')

uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')

uo2.set_density('g/cm3', 10.257 )

uo2.temperature = 600

# %%
zirconium = openmc.Material(name="zirconium")

zirconium.add_nuclide('Zr90',  2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91',  4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92',  7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94',  7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96',  1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112', 4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54',  8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56',  1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57',  3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58',  4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50',  3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52',  6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53',  7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54',  1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')

zirconium.set_density('g/cm3',  6.56)

zirconium.temperature = 600

# %%
water = openmc.Material(name="water")

water.add_nuclide('H1',  4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')

water.add_s_alpha_beta('c_H_in_H2O')

water.set_density('g/cm3', 0.743)

water.temperature=600

# %%
helium = openmc.Material(name="helium")

helium.add_nuclide('He4',1, 'ao')

helium.set_density('g/cm3', 0.178E-03 )

helium.temperature=600

# %%
pyrex_mat = openmc.Material(name="pyrex_mat")

pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')

pyrex_mat.set_density('g/cm3', 2.25 )

pyrex_mat.temperature=600

# %%
SS304 = openmc.Material(name="SS304")

SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')

SS304.set_density('g/cm3', 8.00 )

SS304.temperature=600

# %%
model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#print(model.materials)

# %% [markdown]
# ## Define individiual cells
# ***

# %%
# Global surfaces
pitch = 1.26

# Fuel radii
fuel_outer_radius = openmc.ZCylinder(r=0.4096)
clad_inner_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)

# Guide tube radii
gt_inner_radius = openmc.ZCylinder(r=0.561)
gt_outer_radius = openmc.ZCylinder(r=0.602)

# Instrumentation radii
it_inner_radius = openmc.ZCylinder(r=0.559)
it_outer_radius = openmc.ZCylinder(r=0.605)

#Pyrex
Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
Outer_Tube_Inner_Radius= openmc.ZCylinder(r= 0.437)
Outer_Tube_Outer_Radius= openmc.ZCylinder(r= 0.484)

# Universe bounds
left   = openmc.XPlane(-pitch/2, boundary_type='transmission')
right  = openmc.XPlane( pitch/2, boundary_type='transmission')
bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
top    = openmc.YPlane( pitch/2, boundary_type='transmission')

# %% [markdown]
# ### Define pincell universe

# %%
def pincell():

    fuel_region  = -fuel_outer_radius
    gap_region   = +fuel_outer_radius & -clad_inner_radius
    clad_region  = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius

    fuel = openmc.Cell(name='fuel')
    fuel.region = fuel_region
    fuel.fill = uo2
    #new_fuel = uo2.clone()
    #fuel.fill = new_fuel
    
    gap = openmc.Cell(name='gap')
    gap.region = gap_region
    gap.fill = helium     
    
    clad = openmc.Cell(name='clad')
    clad.region = clad_region
    clad.fill = zirconium
    
    moderator = openmc.Cell(name='moderator')
    moderator.region = water_region
    moderator.fill = water
    
    return openmc.Universe(name='pin-univ', cells=(fuel, clad, moderator,gap))

# %% [markdown]
# ### Create guide tube universe

# %%
def guide():
    
    gt_water_in_region  = -gt_inner_radius
    gt_clad_region      = +gt_inner_radius & -gt_outer_radius
    gt_water_out_region = +gt_outer_radius & +left & -right & +bottom & -top
     
    gt_water_in = openmc.Cell(name='gt-water-in')
    gt_water_in.region = gt_water_in_region
    gt_water_in.fill = water
 
    gt_clad = openmc.Cell(name='gt-clad')
    gt_clad.region = gt_clad_region
    gt_clad.fill = zirconium

    gt_water_out = openmc.Cell(name='gt-water-out')
    gt_water_out.region = gt_water_out_region
    gt_water_out.fill = water
    
    return openmc.Universe(name='gt-univ', cells=(gt_water_in, gt_clad, gt_water_out))

# %% [markdown]
# ### Create instrumentation tube universe

# %%
def instrument():
    
    it_water_in_region  = -it_inner_radius
    it_clad_region      = +it_inner_radius & -it_outer_radius
    it_water_out_region = +it_outer_radius & +left & -right & +bottom & -top
    
    it_water_in = openmc.Cell(name='it-water-in')
    it_water_in.region = it_water_in_region
    it_water_in.fill = water

    it_clad = openmc.Cell(name='it-clad')
    it_clad.region = it_clad_region
    it_clad.fill = zirconium

    it_water_out = openmc.Cell(name='it-water-out')
    it_water_out.region = it_water_out_region
    it_water_out.fill = water

    return openmc.Universe(name='it-univ', cells=(it_water_in, it_clad, it_water_out))

# %%
def pyrex_pin():

    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +gt_outer_radius | +Outer_Tube_Outer_Radius & -gt_inner_radius 
    guide_region = +gt_inner_radius & -gt_outer_radius
    steel_region = +Outer_Tube_Inner_Radius & -Outer_Tube_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Outer_Tube_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='pyrex_clad')
    steel_cell.fill = SS304
    steel_cell.region = steel_region  
    
    gap_cell = openmc.Cell(name='pyrex_gap')
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    
    pyrex_cell = openmc.Cell(name='pyrex')
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region  
    
    water_cell = openmc.Cell(name='pyrex_water')
    water_cell.fill = water
    water_cell.region = water_region
    
    guide_cell = openmc.Cell(name='pyrex_guide')
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    return openmc.Universe(name='py-univ', cells=(steel_cell,gap_cell,pyrex_cell,water_cell,guide_cell))

# %% [markdown]
# ### Generate universes

# %%
pc_univ  = pincell()
gt_univ  = guide()
it_univ  = instrument()
py_univ = pyrex_pin()

# %% [markdown]
# ## Generate assembly
# ***

# %%
height = 10 # height in z-dir
dr = 0.04   # cm of water that is outside assembly
one_eighth = True # either 1/8 or 1/4 of FA

# %%
def read_csv_to_2d_array(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        data = [row for row in reader]
    return np.asarray(data)

def count_frequencies(data):
    flattened_data = [item for row in data for item in row]  # Flatten 2D array into a 1D list
    cell_frequencies = Counter(flattened_data)
    print("cell name frequency:")
    total = 0
    for key, value in cell_frequencies.items():
        print(f'"{key}": {value}')
        total += value
    print("total: ",total)

csv_filepath = 'FA_cell_names_1_family.csv'

lattice_csv = read_csv_to_2d_array(csv_filepath)
count_frequencies(lattice_csv)

if lattice_csv.shape[0] != lattice_csv.shape[1]:
    raise Exception('CSV array of cell names is not square.')
    
size = lattice_csv.shape[0] #size of the assembly
# Out:
# cell name frequency:
# "fu": 264
# "p": 12
# "gt": 12
# "it": 1
# total:  289

# %% [markdown]
# ### Define assembly lattice

# %%
assembly = openmc.RectLattice()
assembly.pitch = (pitch,pitch)
assembly.lower_left = (-size*pitch/2, -size*pitch/2)

lattice_array = np.empty((size, size), dtype=openmc.universe.Universe)

for row in range(0,lattice_csv.shape[0]):
    for col in range(0,lattice_csv.shape[1]):
        if lattice_csv[row][col] == 'gt': 
            lattice_array[row][col] = gt_univ
        elif lattice_csv[row][col] == 'it':
            lattice_array[row][col] = it_univ
        elif lattice_csv[row][col] == 'fu':
            lattice_array[row][col] = pc_univ
        elif lattice_csv[row][col] == 'p':
            lattice_array[row][col] = py_univ
        else:
            mesg = 'i={},j={},cell-name {} not recognized'.format(col, row, lattice_csv[row][col])
            raise ValueError(mesg)

assembly.universes = lattice_array

# %% [markdown]
# ### Define moderator outside of the assembly

# %%
# create cell that will contain the lattice
moderator_outside_cell = openmc.Cell( name = 'water_outside', fill = water )
assembly.outer = openmc.Universe( name='outer', cells = [moderator_outside_cell] )

# %% [markdown]
# ### Define 1/8 or 1/4 of full assembly

# %%
min_x = openmc.XPlane(x0= 0.               , boundary_type='reflective')
max_x = openmc.XPlane(x0= size*pitch/2+dr  , boundary_type='reflective')
min_y = openmc.YPlane(y0= 0.               , boundary_type='reflective')
max_y = openmc.YPlane(y0= size*pitch/2+dr  , boundary_type='reflective')
min_z = openmc.ZPlane(z0=-height/2         , boundary_type='reflective')
max_z = openmc.ZPlane(z0= height/2         , boundary_type='reflective')
xy    = openmc.Plane(-1., 1.               , boundary_type='reflective')

# define root universe
root_cell = openmc.Cell( name = 'root cell', fill = assembly )

if one_eighth:
    root_cell.region = -max_x & +min_y & -xy
else:
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name = 'root universe', cells=[root_cell])

# %% [markdown]
# ## Plotting

# %%
color_opt = 'material'
root_cell.plot(origin=(5,5,0), pixels=(1500,1500), width=(15,15),color_by=color_opt,outline=True)
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# ##  Settings
# ***

# %%
settings = openmc.Settings()

# %% [markdown]
# ### Source

# %%
bbox = openmc.BoundingBox(lower_left  = [0., 0., -height/2], 
                          upper_right = [size*pitch/2, size*pitch/2, height/2])
uniform_dist = openmc.stats.Box(bbox.lower_left, bbox.upper_right, only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings.source = source
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/stats/multivariate.py:943: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "

# %% [markdown]
# ### Destination path

# %%
my_case = '2e'
my_path = './mgxs_casl_' + my_case

# check if folder exists
path = pathlib.Path(my_path)
path.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ### Batching

# %%
test_mode = False

# %%
# add additional parameters
settings.batches =  150
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies': True, 'path':my_path}
settings.temperature['method'] = 'interpolation'

if test_mode == True:
    settings.batches = 200
    settings.inactive = 50
    settings.particles = 1000
    settings.keff_trigger = {'type':'std_dev','threshold':0.001}

model.settings = settings

# %% [markdown]
# ## Tallies
# ***

# %%
# egroup_name = 'XMAS-172'
egroup_name = 'SHEM-361'
egroup = openmc.mgxs.GROUP_STRUCTURES[egroup_name]

# %% [markdown]
# ### Power Tally

# %%
tally_power = openmc.Tally(name='power')

# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [size, size]
mesh._lower_left = [-size*pitch/2, -size*pitch/2]
mesh._upper_right = [size*pitch/2,  size*pitch/2]

# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)
tally_power.filters = [mesh_filter]

tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']

tallies = openmc.Tallies([tally_power])
# model.tallies=tallies

# %% [markdown]
# ### MGXS Tally

# %%
leg = 7
mgxs_domain = 'cell'

# %%
# Setup MGXS lib
mgxs_lib = openmc.mgxs.Library(model.geometry)
mgxs_lib.energy_groups = openmc.mgxs.EnergyGroups(egroup)
mgxs_lib.scatter_format = "legendre"
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi',
                       'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']

# Legendre order
mgxs_lib.legendre_order = leg
if leg == leg:
    mgxs_lib.correction = None

# No by_nuclide
mgxs_lib.by_nuclide = False

# MGXS domain type
mgxs_lib.domain_type = mgxs_domain
if mgxs_domain == 'cell':
    mgxs_lib.domains = model.geometry.get_all_material_cells().values()
elif mgxs_domain == 'universe':
    mgxs_lib.domains = model.geometry.get_all_universes().values()

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()
mgxs_lib.check_library_for_openmc_mgxs()

mgxs_lib.add_to_tallies_file(tallies, merge=True)

model.tallies = tallies
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 7 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
# trick to make several runs work with jupyter
try:
    sp 
    print('sp found')
    sp.close()
except NameError:
    print('sp NOT found')
# Out:
# sp NOT found

# %%
statepoint_filename = model.run()
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=591.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev2
#      Commit Hash | 3f3649da086fd296cde37dcda9218514f8c16c98
#        Date/Time | 2025-04-05 14:23:12
#   OpenMP Threads | 8
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /home/brent10/nndc_hdf5/neutron/U234.h5
#  Reading U235 from /home/brent10/nndc_hdf5/neutron/U235.h5
#  Reading U236 from /home/brent10/nndc_hdf5/neutron/U236.h5
#  Reading U238 from /home/brent10/nndc_hdf5/neutron/U238.h5
#  Reading O16 from /home/brent10/nndc_hdf5/neutron/O16.h5
#  Reading Zr90 from /home/brent10/nndc_hdf5/neutron/Zr90.h5
#  Reading Zr91 from /home/brent10/nndc_hdf5/neutron/Zr91.h5
#  Reading Zr92 from /home/brent10/nndc_hdf5/neutron/Zr92.h5
#  Reading Zr94 from /home/brent10/nndc_hdf5/neutron/Zr94.h5
#  Reading Zr96 from /home/brent10/nndc_hdf5/neutron/Zr96.h5
#  Reading Sn112 from /home/brent10/nndc_hdf5/neutron/Sn112.h5
#  Reading Sn114 from /home/brent10/nndc_hdf5/neutron/Sn114.h5
#  Reading Sn115 from /home/brent10/nndc_hdf5/neutron/Sn115.h5
#  Reading Sn116 from /home/brent10/nndc_hdf5/neutron/Sn116.h5
#  Reading Sn117 from /home/brent10/nndc_hdf5/neutron/Sn117.h5
#  Reading Sn118 from /home/brent10/nndc_hdf5/neutron/Sn118.h5
#  Reading Sn119 from /home/brent10/nndc_hdf5/neutron/Sn119.h5
#  Reading Sn120 from /home/brent10/nndc_hdf5/neutron/Sn120.h5
#  Reading Sn122 from /home/brent10/nndc_hdf5/neutron/Sn122.h5
#  Reading Sn124 from /home/brent10/nndc_hdf5/neutron/Sn124.h5
#  Reading Fe54 from /home/brent10/nndc_hdf5/neutron/Fe54.h5
#  Reading Fe56 from /home/brent10/nndc_hdf5/neutron/Fe56.h5
#  Reading Fe57 from /home/brent10/nndc_hdf5/neutron/Fe57.h5
#  Reading Fe58 from /home/brent10/nndc_hdf5/neutron/Fe58.h5
#  Reading Cr50 from /home/brent10/nndc_hdf5/neutron/Cr50.h5
#  Reading Cr52 from /home/brent10/nndc_hdf5/neutron/Cr52.h5
#  Reading Cr53 from /home/brent10/nndc_hdf5/neutron/Cr53.h5
#  Reading Cr54 from /home/brent10/nndc_hdf5/neutron/Cr54.h5
#  Reading Hf174 from /home/brent10/nndc_hdf5/neutron/Hf174.h5
#  Reading Hf176 from /home/brent10/nndc_hdf5/neutron/Hf176.h5
#  Reading Hf177 from /home/brent10/nndc_hdf5/neutron/Hf177.h5
#  Reading Hf178 from /home/brent10/nndc_hdf5/neutron/Hf178.h5
#  Reading Hf179 from /home/brent10/nndc_hdf5/neutron/Hf179.h5
#  Reading Hf180 from /home/brent10/nndc_hdf5/neutron/Hf180.h5
#  Reading H1 from /home/brent10/nndc_hdf5/neutron/H1.h5
#  Reading B10 from /home/brent10/nndc_hdf5/neutron/B10.h5
#  Reading B11 from /home/brent10/nndc_hdf5/neutron/B11.h5
#  Reading He4 from /home/brent10/nndc_hdf5/neutron/He4.h5
#  Reading Si28 from /home/brent10/nndc_hdf5/neutron/Si28.h5
#  Reading Si29 from /home/brent10/nndc_hdf5/neutron/Si29.h5
#  Reading Si30 from /home/brent10/nndc_hdf5/neutron/Si30.h5
#  Reading C0 from /home/brent10/nndc_hdf5/neutron/C0.h5
#  Reading P31 from /home/brent10/nndc_hdf5/neutron/P31.h5
#  Reading Mn55 from /home/brent10/nndc_hdf5/neutron/Mn55.h5
#  Reading Ni58 from /home/brent10/nndc_hdf5/neutron/Ni58.h5
#  Reading Ni60 from /home/brent10/nndc_hdf5/neutron/Ni60.h5
#  Reading Ni61 from /home/brent10/nndc_hdf5/neutron/Ni61.h5
#  Reading Ni62 from /home/brent10/nndc_hdf5/neutron/Ni62.h5
#  Reading Ni64 from /home/brent10/nndc_hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from /home/brent10/nndc_hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 600 K
#  Maximum neutron data temperature: 900 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.06771
#         2/1    1.07375
#         3/1    1.06610
#         4/1    1.07338
#         5/1    1.06450
#         6/1    1.07594
#         7/1    1.06906
#         8/1    1.06737
#         9/1    1.07198
#        10/1    1.06466
#        11/1    1.07134
#        12/1    1.06294
#        13/1    1.06367
#        14/1    1.06444
#        15/1    1.07204
#        16/1    1.08513
#        17/1    1.07996
#        18/1    1.06876
#        19/1    1.06795
#        20/1    1.07304
#        21/1    1.06525
#        22/1    1.07090    1.06808 +/- 0.00282
#        23/1    1.07061    1.06892 +/- 0.00184
#        24/1    1.05729    1.06601 +/- 0.00318
#        25/1    1.06672    1.06615 +/- 0.00247
#        26/1    1.07608    1.06781 +/- 0.00261
#        27/1    1.07072    1.06822 +/- 0.00224
#        28/1    1.07067    1.06853 +/- 0.00197
#        29/1    1.06401    1.06803 +/- 0.00181
#        30/1    1.08276    1.06950 +/- 0.00219
#        31/1    1.07637    1.07012 +/- 0.00207
#        32/1    1.06917    1.07004 +/- 0.00189
#        33/1    1.07047    1.07008 +/- 0.00174
#        34/1    1.06085    1.06942 +/- 0.00174
#        35/1    1.07260    1.06963 +/- 0.00164
#        36/1    1.07099    1.06972 +/- 0.00153
#        37/1    1.06688    1.06955 +/- 0.00145
#        38/1    1.06552    1.06932 +/- 0.00139
#        39/1    1.07530    1.06964 +/- 0.00135
#        40/1    1.06203    1.06926 +/- 0.00133
#        41/1    1.07546    1.06955 +/- 0.00130
#        42/1    1.05069    1.06870 +/- 0.00151
#        43/1    1.07000    1.06875 +/- 0.00144
#        44/1    1.07202    1.06889 +/- 0.00139
#        45/1    1.06912    1.06890 +/- 0.00133
#        46/1    1.06282    1.06867 +/- 0.00130
#        47/1    1.07938    1.06906 +/- 0.00131
#        48/1    1.07151    1.06915 +/- 0.00127
#        49/1    1.07174    1.06924 +/- 0.00123
#        50/1    1.08012    1.06960 +/- 0.00124
#        51/1    1.07874    1.06990 +/- 0.00123
#        52/1    1.07353    1.07001 +/- 0.00120
#        53/1    1.06325    1.06981 +/- 0.00118
#        54/1    1.07359    1.06992 +/- 0.00115
#        55/1    1.05698    1.06955 +/- 0.00118
#        56/1    1.05374    1.06911 +/- 0.00123
#        57/1    1.07472    1.06926 +/- 0.00120
#        58/1    1.08137    1.06958 +/- 0.00121
#        59/1    1.07412    1.06969 +/- 0.00119
#        60/1    1.07677    1.06987 +/- 0.00117
#        61/1    1.07130    1.06991 +/- 0.00114
#        62/1    1.07298    1.06998 +/- 0.00112
#        63/1    1.07592    1.07012 +/- 0.00110
#        64/1    1.06897    1.07009 +/- 0.00107
#        65/1    1.07706    1.07025 +/- 0.00106
#        66/1    1.07531    1.07036 +/- 0.00104
#        67/1    1.07140    1.07038 +/- 0.00102
#        68/1    1.08046    1.07059 +/- 0.00102
#        69/1    1.06912    1.07056 +/- 0.00100
#        70/1    1.07368    1.07062 +/- 0.00098
#        71/1    1.08026    1.07081 +/- 0.00098
#        72/1    1.07260    1.07084 +/- 0.00096
#        73/1    1.06079    1.07066 +/- 0.00096
#        74/1    1.07926    1.07081 +/- 0.00096
#        75/1    1.06751    1.07075 +/- 0.00094
#        76/1    1.07318    1.07080 +/- 0.00093
#        77/1    1.07560    1.07088 +/- 0.00092
#        78/1    1.07009    1.07087 +/- 0.00090
#        79/1    1.07173    1.07088 +/- 0.00088
#        80/1    1.06536    1.07079 +/- 0.00087
#        81/1    1.07701    1.07089 +/- 0.00087
#        82/1    1.07424    1.07095 +/- 0.00085
#        83/1    1.06936    1.07092 +/- 0.00084
#        84/1    1.07510    1.07099 +/- 0.00083
#        85/1    1.08533    1.07121 +/- 0.00085
#        86/1    1.06981    1.07119 +/- 0.00083
#        87/1    1.06858    1.07115 +/- 0.00082
#        88/1    1.07465    1.07120 +/- 0.00081
#        89/1    1.06895    1.07117 +/- 0.00080
#        90/1    1.07022    1.07115 +/- 0.00079
#        91/1    1.06250    1.07103 +/- 0.00079
#        92/1    1.06501    1.07095 +/- 0.00078
#        93/1    1.06618    1.07088 +/- 0.00077
#        94/1    1.07211    1.07090 +/- 0.00076
#        95/1    1.07298    1.07093 +/- 0.00075
#        96/1    1.07569    1.07099 +/- 0.00074
#        97/1    1.06573    1.07092 +/- 0.00074
#        98/1    1.06771    1.07088 +/- 0.00073
#        99/1    1.06759    1.07084 +/- 0.00072
#       100/1    1.07108    1.07084 +/- 0.00071
#       101/1    1.07383    1.07088 +/- 0.00070
#       102/1    1.06997    1.07087 +/- 0.00070
#       103/1    1.06772    1.07083 +/- 0.00069
#       104/1    1.07007    1.07082 +/- 0.00068
#       105/1    1.06695    1.07077 +/- 0.00067
#       106/1    1.06342    1.07069 +/- 0.00067
#       107/1    1.07244    1.07071 +/- 0.00066
#       108/1    1.07655    1.07078 +/- 0.00066
#       109/1    1.07180    1.07079 +/- 0.00065
#       110/1    1.06721    1.07075 +/- 0.00065
#       111/1    1.06948    1.07073 +/- 0.00064
#       112/1    1.06337    1.07065 +/- 0.00064
#       113/1    1.06502    1.07059 +/- 0.00063
#       114/1    1.06913    1.07058 +/- 0.00063
#       115/1    1.07266    1.07060 +/- 0.00062
#       116/1    1.06692    1.07056 +/- 0.00062
#       117/1    1.06688    1.07052 +/- 0.00061
#       118/1    1.06804    1.07050 +/- 0.00060
#       119/1    1.07484    1.07054 +/- 0.00060
#       120/1    1.07239    1.07056 +/- 0.00059
#       121/1    1.07163    1.07057 +/- 0.00059
#       122/1    1.06156    1.07048 +/- 0.00059
#       123/1    1.06261    1.07041 +/- 0.00059
#       124/1    1.06594    1.07036 +/- 0.00058
#       125/1    1.07171    1.07038 +/- 0.00058
#       126/1    1.07119    1.07038 +/- 0.00057
#       127/1    1.07528    1.07043 +/- 0.00057
#       128/1    1.05836    1.07032 +/- 0.00058
#       129/1    1.07704    1.07038 +/- 0.00057
#       130/1    1.07144    1.07039 +/- 0.00057
#       131/1    1.07238    1.07041 +/- 0.00056
#       132/1    1.05398    1.07026 +/- 0.00058
#       133/1    1.06433    1.07021 +/- 0.00057
#       134/1    1.06294    1.07014 +/- 0.00057
#       135/1    1.07331    1.07017 +/- 0.00057
#       136/1    1.06719    1.07015 +/- 0.00056
#       137/1    1.05445    1.07001 +/- 0.00058
#       138/1    1.07112    1.07002 +/- 0.00057
#       139/1    1.06528    1.06998 +/- 0.00057
#       140/1    1.07110    1.06999 +/- 0.00056
#       141/1    1.06153    1.06992 +/- 0.00056
#       142/1    1.05727    1.06982 +/- 0.00057
#       143/1    1.07468    1.06986 +/- 0.00056
#       144/1    1.06703    1.06983 +/- 0.00056
#       145/1    1.07651    1.06989 +/- 0.00056
#       146/1    1.07301    1.06991 +/- 0.00055
#       147/1    1.05985    1.06983 +/- 0.00056
#       148/1    1.06821    1.06982 +/- 0.00055
#       149/1    1.07198    1.06984 +/- 0.00055
#       150/1    1.07356    1.06986 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4839967915720136 for eigenvalue
#  The estimated number of batches is 1598
#  Creating state point ./mgxs_casl_2e/statepoint.00150.h5...
#       151/1    1.06753    1.06985 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.478814042768888 for eigenvalue
#  The estimated number of batches is 1606
#       152/1    1.06326    1.06980 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.453172158523001 for eigenvalue
#  The estimated number of batches is 1595
#       153/1    1.07610    1.06984 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4385544935377146 for eigenvalue
#  The estimated number of batches is 1593
#       154/1    1.07055    1.06985 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.421612133017999 for eigenvalue
#  The estimated number of batches is 1589
#       155/1    1.05870    1.06977 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3923736759493996 for eigenvalue
#  The estimated number of batches is 1574
#       156/1    1.06012    1.06970 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.399668857649909 for eigenvalue
#  The estimated number of batches is 1592
#       157/1    1.06669    1.06967 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3743959246139568 for eigenvalue
#  The estimated number of batches is 1580
#       158/1    1.07450    1.06971 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3503548501763185 for eigenvalue
#  The estimated number of batches is 1570
#       159/1    1.07319    1.06973 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.339425279318426 for eigenvalue
#  The estimated number of batches is 1571
#       160/1    1.06769    1.06972 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.362383472176454 for eigenvalue
#  The estimated number of batches is 1603
#       161/1    1.06321    1.06967 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.336988848420793 for eigenvalue
#  The estimated number of batches is 1591
#       162/1    1.07597    1.06972 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.341895820045729 for eigenvalue
#  The estimated number of batches is 1606
#       163/1    1.05644    1.06963 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.314046529982647 for eigenvalue
#  The estimated number of batches is 1591
#       164/1    1.07564    1.06967 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2966695949479115 for eigenvalue
#  The estimated number of batches is 1585
#       165/1    1.06297    1.06962 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.27283885645273 for eigenvalue
#  The estimated number of batches is 1574
#       166/1    1.07189    1.06964 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2557000697876046 for eigenvalue
#  The estimated number of batches is 1568
#       167/1    1.06505    1.06961 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.233504411516137 for eigenvalue
#  The estimated number of batches is 1557
#       168/1    1.07787    1.06966 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.244972521157633 for eigenvalue
#  The estimated number of batches is 1579
#       169/1    1.06584    1.06964 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2325961318567926 for eigenvalue
#  The estimated number of batches is 1578
#       170/1    1.06844    1.06963 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2143395916443107 for eigenvalue
#  The estimated number of batches is 1570
#       171/1    1.06695    1.06961 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.192256662997504 for eigenvalue
#  The estimated number of batches is 1559
#       172/1    1.06301    1.06957 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.190091060029063 for eigenvalue
#  The estimated number of batches is 1567
#       173/1    1.07629    1.06961 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1725777682810268 for eigenvalue
#  The estimated number of batches is 1560
#       174/1    1.07035    1.06961 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1519052171673017 for eigenvalue
#  The estimated number of batches is 1550
#       175/1    1.06746    1.06960 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1354662234101656 for eigenvalue
#  The estimated number of batches is 1544
#       176/1    1.06616    1.06958 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1153874816473754 for eigenvalue
#  The estimated number of batches is 1535
#       177/1    1.06686    1.06956 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.098201701640964 for eigenvalue
#  The estimated number of batches is 1528
#       178/1    1.07206    1.06958 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0791661887214437 for eigenvalue
#  The estimated number of batches is 1519
#       179/1    1.07327    1.06960 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0623825273465695 for eigenvalue
#  The estimated number of batches is 1512
#       180/1    1.06567    1.06958 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.043840385365115 for eigenvalue
#  The estimated number of batches is 1503
#       181/1    1.07131    1.06959 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0282417879400096 for eigenvalue
#  The estimated number of batches is 1497
#       182/1    1.05737    1.06951 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.013129129127028 for eigenvalue
#  The estimated number of batches is 1491
#       183/1    1.06530    1.06949 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.998869738256267 for eigenvalue
#  The estimated number of batches is 1486
#       184/1    1.06641    1.06947 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.985887883373192 for eigenvalue
#  The estimated number of batches is 1483
#       185/1    1.06218    1.06942 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.972845494701556 for eigenvalue
#  The estimated number of batches is 1479
#       186/1    1.07672    1.06947 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.954242453140509 for eigenvalue
#  The estimated number of batches is 1469
#       187/1    1.07078    1.06947 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9368234023410884 for eigenvalue
#  The estimated number of batches is 1461
#       188/1    1.06573    1.06945 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.92151533530147 for eigenvalue
#  The estimated number of batches is 1454
#       189/1    1.06116    1.06940 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9046350704277057 for eigenvalue
#  The estimated number of batches is 1446
#       190/1    1.06828    1.06940 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.898250336069671 for eigenvalue
#  The estimated number of batches is 1448
#       191/1    1.06702    1.06938 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.8898323838080047 for eigenvalue
#  The estimated number of batches is 1449
#       192/1    1.06670    1.06937 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8824298241461386 for eigenvalue
#  The estimated number of batches is 1450
#       193/1    1.06982    1.06937 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8657542117878108 for eigenvalue
#  The estimated number of batches is 1441
#       194/1    1.07377    1.06939 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8548253273010245 for eigenvalue
#  The estimated number of batches is 1439
#       195/1    1.06945    1.06940 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.838578678097732 for eigenvalue
#  The estimated number of batches is 1431
#       196/1    1.07186    1.06941 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8470587097524023 for eigenvalue
#  The estimated number of batches is 1447
#       197/1    1.06615    1.06939 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8800436401853005 for eigenvalue
#  The estimated number of batches is 1489
#       198/1    1.07351    1.06941 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8638213023146157 for eigenvalue
#  The estimated number of batches is 1480
#       199/1    1.08433    1.06950 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.875820104533259 for eigenvalue
#  The estimated number of batches is 1501
#       200/1    1.07476    1.06953 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8648167098992534 for eigenvalue
#  The estimated number of batches is 1498
#       201/1    1.07743    1.06957 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8881536883014154 for eigenvalue
#  The estimated number of batches is 1530
#       202/1    1.06508    1.06955 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8727456749248406 for eigenvalue
#  The estimated number of batches is 1522
#       203/1    1.06259    1.06951 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8586618641274306 for eigenvalue
#  The estimated number of batches is 1516
#       204/1    1.06970    1.06951 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.847771904080643 for eigenvalue
#  The estimated number of batches is 1513
#       205/1    1.06734    1.06950 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.847659418861901 for eigenvalue
#  The estimated number of batches is 1521
#       206/1    1.07066    1.06950 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8326377789736057 for eigenvalue
#  The estimated number of batches is 1513
#       207/1    1.06470    1.06948 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8174595580496447 for eigenvalue
#  The estimated number of batches is 1505
#       208/1    1.07076    1.06948 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.802408905550849 for eigenvalue
#  The estimated number of batches is 1497
#       209/1    1.06464    1.06946 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.790940088850468 for eigenvalue
#  The estimated number of batches is 1493
#       210/1    1.06687    1.06944 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.78024136580349 for eigenvalue
#  The estimated number of batches is 1489
#       211/1    1.07684    1.06948 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7668599103326588 for eigenvalue
#  The estimated number of batches is 1483
#       212/1    1.07984    1.06954 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.776131369739836 for eigenvalue
#  The estimated number of batches is 1500
#       213/1    1.08048    1.06959 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7691377270920863 for eigenvalue
#  The estimated number of batches is 1500
#       214/1    1.06830    1.06959 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7549314185227542 for eigenvalue
#  The estimated number of batches is 1493
#       215/1    1.06217    1.06955 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7413912665591456 for eigenvalue
#  The estimated number of batches is 1486
#       216/1    1.07585    1.06958 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.731334580268251 for eigenvalue
#  The estimated number of batches is 1483
#       217/1    1.06185    1.06954 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7508273715222655 for eigenvalue
#  The estimated number of batches is 1511
#       218/1    1.07437    1.06957 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.737773434053837 for eigenvalue
#  The estimated number of batches is 1505
#       219/1    1.07920    1.06962 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7282082935561203 for eigenvalue
#  The estimated number of batches is 1502
#       220/1    1.07591    1.06965 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7268384385858053 for eigenvalue
#  The estimated number of batches is 1508
#       221/1    1.07125    1.06965 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7137561838189885 for eigenvalue
#  The estimated number of batches is 1501
#       222/1    1.06593    1.06964 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.704502795437256 for eigenvalue
#  The estimated number of batches is 1498
#       223/1    1.07692    1.06967 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6919778576582107 for eigenvalue
#  The estimated number of batches is 1492
#       224/1    1.06999    1.06967 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.707329560288347 for eigenvalue
#  The estimated number of batches is 1516
#       225/1    1.07004    1.06968 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6976698055202752 for eigenvalue
#  The estimated number of batches is 1512
#       226/1    1.07300    1.06969 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.687704896771543 for eigenvalue
#  The estimated number of batches is 1509
#       227/1    1.06592    1.06967 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6809657314837736 for eigenvalue
#  The estimated number of batches is 1508
#       228/1    1.06749    1.06966 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6730524290964106 for eigenvalue
#  The estimated number of batches is 1507
#       229/1    1.07505    1.06969 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6606541538733075 for eigenvalue
#  The estimated number of batches is 1500
#       230/1    1.06217    1.06965 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6480371899966477 for eigenvalue
#  The estimated number of batches is 1493
#       231/1    1.07415    1.06967 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6370870494583785 for eigenvalue
#  The estimated number of batches is 1488
#       232/1    1.05743    1.06962 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6458737629532587 for eigenvalue
#  The estimated number of batches is 1505
#       233/1    1.07000    1.06962 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6342500332134504 for eigenvalue
#  The estimated number of batches is 1499
#       234/1    1.06957    1.06962 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.621946573037977 for eigenvalue
#  The estimated number of batches is 1492
#       235/1    1.06240    1.06958 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.615413312412486 for eigenvalue
#  The estimated number of batches is 1491
#       236/1    1.06364    1.06956 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6040691558692295 for eigenvalue
#  The estimated number of batches is 1485
#       237/1    1.07567    1.06959 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6184078725380298 for eigenvalue
#  The estimated number of batches is 1508
#       238/1    1.06836    1.06958 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6088027368713123 for eigenvalue
#  The estimated number of batches is 1504
#       239/1    1.06230    1.06955 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6193290746132853 for eigenvalue
#  The estimated number of batches is 1523
#       240/1    1.06413    1.06952 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6103419641127203 for eigenvalue
#  The estimated number of batches is 1520
#       241/1    1.07298    1.06954 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.598792439374984 for eigenvalue
#  The estimated number of batches is 1513
#       242/1    1.06941    1.06954 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.588136884962224 for eigenvalue
#  The estimated number of batches is 1508
#       243/1    1.05780    1.06948 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5902312656375264 for eigenvalue
#  The estimated number of batches is 1517
#       244/1    1.06636    1.06947 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.578831077861398 for eigenvalue
#  The estimated number of batches is 1510
#       245/1    1.07618    1.06950 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.574328306194786 for eigenvalue
#  The estimated number of batches is 1512
#       246/1    1.06378    1.06947 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.565167137359152 for eigenvalue
#  The estimated number of batches is 1508
#       247/1    1.06626    1.06946 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5546832173218292 for eigenvalue
#  The estimated number of batches is 1502
#       248/1    1.06933    1.06946 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5551061902441763 for eigenvalue
#  The estimated number of batches is 1509
#       249/1    1.06251    1.06943 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5558561645922886 for eigenvalue
#  The estimated number of batches is 1516
#       250/1    1.06969    1.06943 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5449567744372206 for eigenvalue
#  The estimated number of batches is 1510
#       251/1    1.06288    1.06940 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5336247953348465 for eigenvalue
#  The estimated number of batches is 1503
#       252/1    1.07010    1.06941 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5246212696573735 for eigenvalue
#  The estimated number of batches is 1499
#       253/1    1.05846    1.06936 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.51976462767689 for eigenvalue
#  The estimated number of batches is 1500
#       254/1    1.06729    1.06935 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.509473739671229 for eigenvalue
#  The estimated number of batches is 1494
#       255/1    1.07814    1.06939 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5027321276978025 for eigenvalue
#  The estimated number of batches is 1492
#       256/1    1.07313    1.06940 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.495737451617911 for eigenvalue
#  The estimated number of batches is 1490
#       257/1    1.06097    1.06937 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.492643119831577 for eigenvalue
#  The estimated number of batches is 1493
#       258/1    1.06520    1.06935 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.4837881903989136 for eigenvalue
#  The estimated number of batches is 1489
#       259/1    1.07131    1.06936 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.4732032661762604 for eigenvalue
#  The estimated number of batches is 1482
#       260/1    1.06917    1.06936 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.4628674613434662 for eigenvalue
#  The estimated number of batches is 1476
#       261/1    1.06542    1.06934 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.453158454581305 for eigenvalue
#  The estimated number of batches is 1471
#       262/1    1.07301    1.06936 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.44403998573218 for eigenvalue
#  The estimated number of batches is 1466
#       263/1    1.06069    1.06932 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.452920130452997 for eigenvalue
#  The estimated number of batches is 1483
#       264/1    1.07288    1.06933 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4507569534365317 for eigenvalue
#  The estimated number of batches is 1486
#       265/1    1.06783    1.06933 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.443689789625496 for eigenvalue
#  The estimated number of batches is 1484
#       266/1    1.07029    1.06933 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.433974039489821 for eigenvalue
#  The estimated number of batches is 1478
#       267/1    1.07603    1.06936 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.437039844243537 for eigenvalue
#  The estimated number of batches is 1487
#       268/1    1.06013    1.06932 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.427458687473492 for eigenvalue
#  The estimated number of batches is 1482
#       269/1    1.08022    1.06937 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4181647692375643 for eigenvalue
#  The estimated number of batches is 1477
#       270/1    1.06188    1.06934 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4171588226244896 for eigenvalue
#  The estimated number of batches is 1481
#       271/1    1.07498    1.06936 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.408011788612384 for eigenvalue
#  The estimated number of batches is 1476
#       272/1    1.06986    1.06936 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.401226054933925 for eigenvalue
#  The estimated number of batches is 1474
#       273/1    1.06206    1.06933 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.396405644267971 for eigenvalue
#  The estimated number of batches is 1473
#       274/1    1.07964    1.06937 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.3964273015362645 for eigenvalue
#  The estimated number of batches is 1479
#       275/1    1.07565    1.06940 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.3927836587231934 for eigenvalue
#  The estimated number of batches is 1480
#       276/1    1.07523    1.06942 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.38497546017208 for eigenvalue
#  The estimated number of batches is 1477
#       277/1    1.07581    1.06944 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.3881506497871596 for eigenvalue
#  The estimated number of batches is 1486
#       278/1    1.07823    1.06948 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.390157407448271 for eigenvalue
#  The estimated number of batches is 1494
#       279/1    1.07810    1.06951 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.391213646364254 for eigenvalue
#  The estimated number of batches is 1501
#       280/1    1.06231    1.06948 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.3996284496539855 for eigenvalue
#  The estimated number of batches is 1518
#       281/1    1.06486    1.06947 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.408995540047023 for eigenvalue
#  The estimated number of batches is 1535
#       282/1    1.06714    1.06946 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4050674807783023 for eigenvalue
#  The estimated number of batches is 1536
#       283/1    1.07763    1.06949 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4021403327212294 for eigenvalue
#  The estimated number of batches is 1538
#       284/1    1.06338    1.06947 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.395833424754273 for eigenvalue
#  The estimated number of batches is 1536
#       285/1    1.07359    1.06948 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.386800351796157 for eigenvalue
#  The estimated number of batches is 1530
#       286/1    1.07444    1.06950 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3809792356530335 for eigenvalue
#  The estimated number of batches is 1528
#       287/1    1.07311    1.06951 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.372889773651196 for eigenvalue
#  The estimated number of batches is 1524
#       288/1    1.07108    1.06952 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3662396300337125 for eigenvalue
#  The estimated number of batches is 1521
#       289/1    1.06537    1.06950 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.365203616284497 for eigenvalue
#  The estimated number of batches is 1525
#       290/1    1.06483    1.06949 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.357117290891545 for eigenvalue
#  The estimated number of batches is 1521
#       291/1    1.07209    1.06950 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.349163203650383 for eigenvalue
#  The estimated number of batches is 1516
#       292/1    1.06345    1.06947 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3454216878659375 for eigenvalue
#  The estimated number of batches is 1517
#       293/1    1.06577    1.06946 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3372940865691683 for eigenvalue
#  The estimated number of batches is 1512
#       294/1    1.05670    1.06941 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3295131493135233 for eigenvalue
#  The estimated number of batches is 1507
#       295/1    1.06976    1.06941 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.321392366874501 for eigenvalue
#  The estimated number of batches is 1502
#       296/1    1.06973    1.06942 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3237175966963792 for eigenvalue
#  The estimated number of batches is 1511
#       297/1    1.07326    1.06943 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3159186423536333 for eigenvalue
#  The estimated number of batches is 1506
#       298/1    1.06641    1.06942 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.319864535150775 for eigenvalue
#  The estimated number of batches is 1517
#       299/1    1.08452    1.06947 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.336071636515579 for eigenvalue
#  The estimated number of batches is 1543
#       300/1    1.07590    1.06950 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.328448244195088 for eigenvalue
#  The estimated number of batches is 1539
#       301/1    1.07125    1.06950 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3228330241922235 for eigenvalue
#  The estimated number of batches is 1537
#       302/1    1.06190    1.06948 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.321761446721317 for eigenvalue
#  The estimated number of batches is 1541
#       303/1    1.06789    1.06947 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3142641321870894 for eigenvalue
#  The estimated number of batches is 1536
#       304/1    1.07270    1.06948 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.312305906322445 for eigenvalue
#  The estimated number of batches is 1539
#       305/1    1.05737    1.06944 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3144624161783938 for eigenvalue
#  The estimated number of batches is 1547
#       306/1    1.06802    1.06943 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3099023512777586 for eigenvalue
#  The estimated number of batches is 1546
#       307/1    1.06835    1.06943 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.303619069195497 for eigenvalue
#  The estimated number of batches is 1544
#       308/1    1.07477    1.06945 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3033139781146112 for eigenvalue
#  The estimated number of batches is 1548
#       309/1    1.06201    1.06942 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3140277448632056 for eigenvalue
#  The estimated number of batches is 1568
#       310/1    1.06618    1.06941 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3106338989807087 for eigenvalue
#  The estimated number of batches is 1569
#       311/1    1.06049    1.06938 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3096450682663114 for eigenvalue
#  The estimated number of batches is 1573
#       312/1    1.06450    1.06936 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3057468187474153 for eigenvalue
#  The estimated number of batches is 1573
#       313/1    1.06633    1.06935 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.299373064191907 for eigenvalue
#  The estimated number of batches is 1570
#       314/1    1.06611    1.06934 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.293317018813373 for eigenvalue
#  The estimated number of batches is 1567
#       315/1    1.05664    1.06930 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.2885839509088917 for eigenvalue
#  The estimated number of batches is 1566
#       316/1    1.06801    1.06930 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.28546820125881 for eigenvalue
#  The estimated number of batches is 1567
#       317/1    1.07369    1.06931 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.277248906372566 for eigenvalue
#  The estimated number of batches is 1561
#       318/1    1.06987    1.06931 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.2745751176250057 for eigenvalue
#  The estimated number of batches is 1562
#       319/1    1.06286    1.06929 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.2666941018478535 for eigenvalue
#  The estimated number of batches is 1557
#       320/1    1.07008    1.06929 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.259668384414924 for eigenvalue
#  The estimated number of batches is 1552
#       321/1    1.07345    1.06931 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.257565404757571 for eigenvalue
#  The estimated number of batches is 1555
#       322/1    1.07561    1.06933 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.2511677765310747 for eigenvalue
#  The estimated number of batches is 1551
#       323/1    1.06854    1.06933 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.2447258681316735 for eigenvalue
#  The estimated number of batches is 1547
#       324/1    1.06749    1.06932 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.238069547170346 for eigenvalue
#  The estimated number of batches is 1543
#       325/1    1.07538    1.06934 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2306747107061895 for eigenvalue
#  The estimated number of batches is 1538
#       326/1    1.07487    1.06936 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2301029597126316 for eigenvalue
#  The estimated number of batches is 1542
#       327/1    1.07097    1.06936 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2256074284639404 for eigenvalue
#  The estimated number of batches is 1541
#       328/1    1.07361    1.06938 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.223229321756711 for eigenvalue
#  The estimated number of batches is 1543
#       329/1    1.06831    1.06937 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.216300558418515 for eigenvalue
#  The estimated number of batches is 1538
#       330/1    1.06054    1.06934 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2098463214219235 for eigenvalue
#  The estimated number of batches is 1534
#       331/1    1.06866    1.06934 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.203159969709317 for eigenvalue
#  The estimated number of batches is 1530
#       332/1    1.06601    1.06933 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2015971036760913 for eigenvalue
#  The estimated number of batches is 1533
#       333/1    1.07091    1.06934 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.1946598409013243 for eigenvalue
#  The estimated number of batches is 1528
#       334/1    1.06757    1.06933 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.1882918316596642 for eigenvalue
#  The estimated number of batches is 1524
#       335/1    1.07295    1.06934 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.1809776635168068 for eigenvalue
#  The estimated number of batches is 1519
#       336/1    1.06345    1.06932 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.1763683027087737 for eigenvalue
#  The estimated number of batches is 1517
#       337/1    1.07090    1.06933 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.169437505291636 for eigenvalue
#  The estimated number of batches is 1512
#       338/1    1.06718    1.06932 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.163117773655659 for eigenvalue
#  The estimated number of batches is 1508
#       339/1    1.06902    1.06932 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.16118893407455 for eigenvalue
#  The estimated number of batches is 1510
#       340/1    1.07515    1.06934 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.155939661339446 for eigenvalue
#  The estimated number of batches is 1508
#       341/1    1.07320    1.06935 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1497098165810793 for eigenvalue
#  The estimated number of batches is 1504
#       342/1    1.06443    1.06934 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.151381307308585 for eigenvalue
#  The estimated number of batches is 1511
#       343/1    1.06916    1.06934 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.150106360707738 for eigenvalue
#  The estimated number of batches is 1514
#       344/1    1.07517    1.06935 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.144791195197108 for eigenvalue
#  The estimated number of batches is 1511
#       345/1    1.06776    1.06935 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.138323932992092 for eigenvalue
#  The estimated number of batches is 1507
#       346/1    1.07827    1.06938 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.132362854290222 for eigenvalue
#  The estimated number of batches is 1503
#       347/1    1.07350    1.06939 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1363944671336896 for eigenvalue
#  The estimated number of batches is 1513
#       348/1    1.06700    1.06938 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1309052034277935 for eigenvalue
#  The estimated number of batches is 1510
#       349/1    1.05812    1.06935 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.128684969215366 for eigenvalue
#  The estimated number of batches is 1511
#       350/1    1.07876    1.06938 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1309398498291006 for eigenvalue
#  The estimated number of batches is 1519
#       351/1    1.07823    1.06940 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1337136864184694 for eigenvalue
#  The estimated number of batches is 1527
#       352/1    1.06973    1.06940 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1282905756149044 for eigenvalue
#  The estimated number of batches is 1524
#       353/1    1.06247    1.06938 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.12323260495412 for eigenvalue
#  The estimated number of batches is 1522
#       354/1    1.06667    1.06937 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.1173963692752853 for eigenvalue
#  The estimated number of batches is 1518
#       355/1    1.06622    1.06936 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1119289389837586 for eigenvalue
#  The estimated number of batches is 1515
#       356/1    1.06624    1.06936 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.106848411239523 for eigenvalue
#  The estimated number of batches is 1512
#       357/1    1.06597    1.06935 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.100639867427288 for eigenvalue
#  The estimated number of batches is 1508
#       358/1    1.07876    1.06937 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0951803697350777 for eigenvalue
#  The estimated number of batches is 1504
#       359/1    1.06285    1.06935 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0904049146639143 for eigenvalue
#  The estimated number of batches is 1502
#       360/1    1.07660    1.06938 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0839760560965606 for eigenvalue
#  The estimated number of batches is 1497
#       361/1    1.07244    1.06938 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0783543317153588 for eigenvalue
#  The estimated number of batches is 1493
#       362/1    1.06682    1.06938 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0725420201424924 for eigenvalue
#  The estimated number of batches is 1490
#       363/1    1.06962    1.06938 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.066982456409393 for eigenvalue
#  The estimated number of batches is 1486
#       364/1    1.06413    1.06936 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0622459675419558 for eigenvalue
#  The estimated number of batches is 1483
#       365/1    1.06797    1.06936 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0558599285533528 for eigenvalue
#  The estimated number of batches is 1479
#       366/1    1.07702    1.06938 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.053868797944068 for eigenvalue
#  The estimated number of batches is 1480
#       367/1    1.07292    1.06939 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0547065199304537 for eigenvalue
#  The estimated number of batches is 1485
#       368/1    1.07297    1.06940 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.0565225886860277 for eigenvalue
#  The estimated number of batches is 1492
#       369/1    1.06527    1.06939 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.061703625777645 for eigenvalue
# ...
#      1547/1    1.17729    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0301035963435026 for eigenvalue
#  The estimated number of batches is 1641
#      1548/1    1.18031    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0300538740818195 for eigenvalue
#  The estimated number of batches is 1642
#      1549/1    1.18297    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0293793799791333 for eigenvalue
#  The estimated number of batches is 1641
#      1550/1    1.17603    1.18156 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028755726482358 for eigenvalue
#  The estimated number of batches is 1640
#      1551/1    1.18275    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028237282791269 for eigenvalue
#  The estimated number of batches is 1639
#      1552/1    1.19465    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0281418557430162 for eigenvalue
#  The estimated number of batches is 1640
#      1553/1    1.19815    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0282050446357744 for eigenvalue
#  The estimated number of batches is 1641
#      1554/1    1.18030    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0275472944250499 for eigenvalue
#  The estimated number of batches is 1640
#      1555/1    1.17580    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0269972897301543 for eigenvalue
#  The estimated number of batches is 1640
#      1556/1    1.18738    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.026386918526928 for eigenvalue
#  The estimated number of batches is 1639
#      1557/1    1.18066    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025790294234683 for eigenvalue
#  The estimated number of batches is 1638
#      1558/1    1.17388    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0254246381132006 for eigenvalue
#  The estimated number of batches is 1638
#      1559/1    1.17726    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.024897488408665 for eigenvalue
#  The estimated number of batches is 1637
#      1560/1    1.18453    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0243955101952398 for eigenvalue
#  The estimated number of batches is 1637
#      1561/1    1.18952    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023724800402937 for eigenvalue
#  The estimated number of batches is 1635
#      1562/1    1.18906    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0230504146796842 for eigenvalue
#  The estimated number of batches is 1634
#      1563/1    1.17200    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229731776748137 for eigenvalue
#  The estimated number of batches is 1635
#      1564/1    1.19330    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023644813917082 for eigenvalue
#  The estimated number of batches is 1638
#      1565/1    1.18698    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0231004180931969 for eigenvalue
#  The estimated number of batches is 1638
#      1566/1    1.18275    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0224387562644779 for eigenvalue
#  The estimated number of batches is 1637
#      1567/1    1.18114    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0222953823179548 for eigenvalue
#  The estimated number of batches is 1637
#      1568/1    1.17656    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0216800720811214 for eigenvalue
#  The estimated number of batches is 1636
#      1569/1    1.17750    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214739584148051 for eigenvalue
#  The estimated number of batches is 1637
#      1570/1    1.17708    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020973946587673 for eigenvalue
#  The estimated number of batches is 1636
#      1571/1    1.17414    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204353241137618 for eigenvalue
#  The estimated number of batches is 1636
#      1572/1    1.18905    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019780010095114 for eigenvalue
#  The estimated number of batches is 1635
#      1573/1    1.18456    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0191199900117829 for eigenvalue
#  The estimated number of batches is 1633
#      1574/1    1.18758    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018446303246402 for eigenvalue
#  The estimated number of batches is 1632
#      1575/1    1.19896    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0206251872600502 for eigenvalue
#  The estimated number of batches is 1640
#      1576/1    1.18885    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0203702790956495 for eigenvalue
#  The estimated number of batches is 1641
#      1577/1    1.17704    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198083309650556 for eigenvalue
#  The estimated number of batches is 1640
#      1578/1    1.18494    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193552734501277 for eigenvalue
#  The estimated number of batches is 1639
#      1579/1    1.17612    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193272037796448 for eigenvalue
#  The estimated number of batches is 1640
#      1580/1    1.18114    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018693106440465 for eigenvalue
#  The estimated number of batches is 1639
#      1581/1    1.18327    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180990117238888 for eigenvalue
#  The estimated number of batches is 1639
#      1582/1    1.17552    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177101478337598 for eigenvalue
#  The estimated number of batches is 1638
#      1583/1    1.18171    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017055617579926 for eigenvalue
#  The estimated number of batches is 1637
#      1584/1    1.18061    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166066394424342 for eigenvalue
#  The estimated number of batches is 1637
#      1585/1    1.18898    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166703721576775 for eigenvalue
#  The estimated number of batches is 1638
#      1586/1    1.19299    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170147113536505 for eigenvalue
#  The estimated number of batches is 1640
#      1587/1    1.18200    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164002888413703 for eigenvalue
#  The estimated number of batches is 1639
#      1588/1    1.17333    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163525080544988 for eigenvalue
#  The estimated number of batches is 1640
#      1589/1    1.17201    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163591592136667 for eigenvalue
#  The estimated number of batches is 1641
#      1590/1    1.19385    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0157396025627834 for eigenvalue
#  The estimated number of batches is 1640
#      1591/1    1.17461    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0153930863979466 for eigenvalue
#  The estimated number of batches is 1640
#      1592/1    1.18195    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147457542785452 for eigenvalue
#  The estimated number of batches is 1639
#      1593/1    1.17720    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141802130458109 for eigenvalue
#  The estimated number of batches is 1638
#      1594/1    1.17407    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0138467421118313 for eigenvalue
#  The estimated number of batches is 1638
#      1595/1    1.18518    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0131819493192356 for eigenvalue
#  The estimated number of batches is 1637
#      1596/1    1.18464    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0125456052706236 for eigenvalue
#  The estimated number of batches is 1636
#      1597/1    1.18597    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011912182478488 for eigenvalue
#  The estimated number of batches is 1635
#      1598/1    1.18274    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0117330866216734 for eigenvalue
#  The estimated number of batches is 1636
#      1599/1    1.17492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111431212777842 for eigenvalue
#  The estimated number of batches is 1635
#      1600/1    1.17466    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115921829661432 for eigenvalue
#  The estimated number of batches is 1637
#      1601/1    1.17892    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111091804467538 for eigenvalue
#  The estimated number of batches is 1637
#      1602/1    1.17046    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011036386897514 for eigenvalue
#  The estimated number of batches is 1638
#      1603/1    1.18729    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0104155377473154 for eigenvalue
#  The estimated number of batches is 1637
#      1604/1    1.17693    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0101722166241356 for eigenvalue
#  The estimated number of batches is 1637
#      1605/1    1.18002    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102251400270015 for eigenvalue
#  The estimated number of batches is 1638
#      1606/1    1.17419    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096029800085493 for eigenvalue
#  The estimated number of batches is 1637
#      1607/1    1.20125    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009310772641225 for eigenvalue
#  The estimated number of batches is 1637
#      1608/1    1.19361    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01003134212993 for eigenvalue
#  The estimated number of batches is 1641
#      1609/1    1.18837    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0103322457331263 for eigenvalue
#  The estimated number of batches is 1643
#      1610/1    1.18598    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097721002448734 for eigenvalue
#  The estimated number of batches is 1642
#      1611/1    1.16718    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099989214196454 for eigenvalue
#  The estimated number of batches is 1643
#      1612/1    1.18902    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097935254104733 for eigenvalue
#  The estimated number of batches is 1644
#      1613/1    1.17884    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009868904941159 for eigenvalue
#  The estimated number of batches is 1645
#      1614/1    1.18538    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00923643556946 for eigenvalue
#  The estimated number of batches is 1644
#      1615/1    1.17623    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0089435196061098 for eigenvalue
#  The estimated number of batches is 1644
#      1616/1    1.17859    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008905829515394 for eigenvalue
#  The estimated number of batches is 1645
#      1617/1    1.18204    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0082770770746678 for eigenvalue
#  The estimated number of batches is 1644
#      1618/1    1.18125    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0078402208466295 for eigenvalue
#  The estimated number of batches is 1644
#      1619/1    1.16938    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0072610890245743 for eigenvalue
#  The estimated number of batches is 1643
#      1620/1    1.17142    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007230250663518 for eigenvalue
#  The estimated number of batches is 1644
#      1621/1    1.18646    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0066032255007418 for eigenvalue
#  The estimated number of batches is 1643
#      1622/1    1.19101    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060696868892256 for eigenvalue
#  The estimated number of batches is 1642
#      1623/1    1.18579    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061795196531884 for eigenvalue
#  The estimated number of batches is 1643
#      1624/1    1.19450    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055575122805613 for eigenvalue
#  The estimated number of batches is 1642
#      1625/1    1.16829    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0053873296357614 for eigenvalue
#  The estimated number of batches is 1643
#      1626/1    1.18023    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0048340109843639 for eigenvalue
#  The estimated number of batches is 1642
#      1627/1    1.18033    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041977923388297 for eigenvalue
#  The estimated number of batches is 1641
#      1628/1    1.19163    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038282741136422 for eigenvalue
#  The estimated number of batches is 1641
#      1629/1    1.18492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032524589422542 for eigenvalue
#  The estimated number of batches is 1640
#      1630/1    1.19150    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029040132426896 for eigenvalue
#  The estimated number of batches is 1640
#      1631/1    1.17866    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025054245466567 for eigenvalue
#  The estimated number of batches is 1640
#      1632/1    1.17531    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020537859066725 for eigenvalue
#  The estimated number of batches is 1639
#      1633/1    1.19327    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015243856120508 for eigenvalue
#  The estimated number of batches is 1638
#      1634/1    1.18072    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000900482333582 for eigenvalue
#  The estimated number of batches is 1637
#      1635/1    1.18718    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004631248772617 for eigenvalue
#  The estimated number of batches is 1637
#      1636/1    1.18024    1.18161 +/- 0.00016
#  Triggers satisfied for batch 1636
#  Creating state point statepoint.01636.h5...
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.5020e+00 seconds
#    Reading cross sections          = 3.4659e+00 seconds
#  Total time in simulation          = 1.1285e+03 seconds
#    Time in transport only          = 1.1199e+03 seconds
#    Time in inactive batches        = 8.3742e+00 seconds
#    Time in active batches          = 1.1201e+03 seconds
#    Time synchronizing fission bank = 1.1071e+00 seconds
#      Sampling source sites         = 8.4232e-01 seconds
#      SEND/RECV source sites        = 2.6396e-01 seconds
#    Time accumulating tallies       = 6.2389e+00 seconds
#    Time writing statepoints        = 5.1530e-01 seconds
#  Total time for finalization       = 1.1527e+01 seconds
#  Total time elapsed                = 1.1436e+03 seconds
#  Calculation Rate (inactive)       = 119414 particles/second
#  Calculation Rate (active)         = 72135.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18174 +/- 0.00013
#  k-effective (Track-length)  = 1.18161 +/- 0.00016
#  k-effective (Absorption)    = 1.18170 +/- 0.00011
#  Combined k-effective        = 1.18170 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(statepoint_filename)

# %% [markdown]
# ## MGXS Tally Outputs

# %%
xs_names = [] 
for set in (mgxs_lib.domains):
    print(set.name)
    xs_names.append(set.name)

#print(mgxs_lib.domains)
# Out:
# fuel
# clad
# moderator
# gap
# pyrex_clad
# pyrex_gap
# pyrex
# pyrex_water
# pyrex_guide
# gt-water-in
# gt-clad
# gt-water-out
# it-water-in
# it-clad
# it-water-out
# water_outside

# %%
if one_eighth:
    txt = 'one_eighth'
else:
    txt = 'one_quarter'

# %%
mgxs_lib.load_from_statepoint(sp)
    
h5_file_path = my_path + f'/mgxs_{my_case}_{txt}_{egroup_name}.h5'
print(h5_file_path)

# below, no need for xs_type = 'macro' as it is the default
mgxs_lib.create_mg_library(xsdata_names=xs_names).export_to_hdf5(h5_file_path)
# Out:
# ./mgxs_casl_2e/mgxs_2e_one_eighth_SHEM-361.h5

# %% [markdown]
# ## Power Tally Outputs

# %%
computed_power_tallies = sp.get_tally()
power_tally_values = computed_power_tallies.get_values()

pin_power_file_path = my_path + f'/pinpow_{my_case}_{txt}_{egroup_name}.npy'
np.save(pin_power_file_path, power_tally_values)

# %%
for score_id in range(0,len(computed_power_tallies.scores)):
     # get name of the score
    score = computed_power_tallies.scores[score_id]
    print('score = ',score)
    # extract + shape the data
    vals = power_tally_values[:,0,score_id].reshape(17,17)
    vals = vals[8:,8:]
    
    dd = np.copy(vals)

    # multiply axis of symeetry by 2 for power display
    dd[0,:] *= 2
    dd[np.diag_indices_from(dd)] *= 2

    dd = np.flip(dd,axis=0)
    
    # normalize
    idx_fuel_cells = np.argwhere(dd>0)
    nnz_fuel_cells = np.asarray(idx_fuel_cells).shape[0]
    dd /= np.sum(dd)
    dd *= nnz_fuel_cells

    table = PrettyTable()

    n_list = [str(n) for n in range(1, 10)]
    table.field_names = n_list

    # Convert ndarray to list of lists
    data_list = dd.tolist()

    for row in data_list:
        # Format each value to 2 decimal places
        formatted_row = [f"{x:.6g}" for x in row]
        table.add_row(formatted_row)

    print(table)
# Out:
# score =  fission
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.05119  |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     | 1.02904  | 1.03875  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.03074  | 1.02296  | 1.03087  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04096  | 1.01281  | 1.01998  |
# | 0 |    0     |    0     |    0     |  1.0268  | 1.02163  | 0.956478 | 0.976528 |  1.0036  |
# | 0 |    0     |    0     |    0     | 1.03555  | 0.949812 |    0     | 0.933454 | 0.992005 |
# | 0 |    0     | 0.993908 | 1.02286  | 1.00074  | 0.973067 | 0.940469 | 0.975398 | 1.00372  |
# | 0 | 0.990553 | 0.961223 | 0.931511 | 0.967547 | 1.00137  | 1.03385  | 1.02017  | 1.02138  |
# | 0 | 1.01392  | 0.928192 |    0     | 0.932424 |  1.0269  |    0     | 1.05549  | 1.03216  |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# score =  nu-fission
# +---+----------+----------+----------+----------+----------+----------+----------+---------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9    |
# +---+----------+----------+----------+----------+----------+----------+----------+---------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.05097 |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     | 1.02903  | 1.03865 |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.03062  | 1.02297  | 1.03082 |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04059  | 1.01285  | 1.01998 |
# | 0 |    0     |    0     |    0     | 1.02644  | 1.02128  | 0.956815 | 0.976809 | 1.00367 |
# | 0 |    0     |    0     |    0     | 1.03508  | 0.95019  |    0     | 0.934074 | 0.99216 |
# | 0 |    0     | 0.993861 |  1.0225  | 1.00064  | 0.973261 | 0.940953 | 0.975641 | 1.00376 |
# | 0 | 0.990493 | 0.96146  | 0.932003 | 0.967751 | 1.00131  | 1.03345  | 1.02001  | 1.02127 |
# | 0 | 1.01359  | 0.928689 |    0     | 0.932926 | 1.02654  |    0     | 1.05495  | 1.03196 |
# +---+----------+----------+----------+----------+----------+----------+----------+---------+
# score =  kappa-fission
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.05116  |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     | 1.02904  | 1.03873  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.03073  | 1.02296  | 1.03086  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04091  | 1.01282  | 1.01998  |
# | 0 |    0     |    0     |    0     | 1.02674  | 1.02158  | 0.956528 | 0.976568 | 1.00361  |
# | 0 |    0     |    0     |    0     | 1.03548  | 0.949867 |    0     | 0.933544 | 0.992027 |
# | 0 |    0     |  0.9939  | 1.02281  | 1.00072  | 0.973095 | 0.940539 | 0.975434 | 1.00373  |
# | 0 | 0.990545 | 0.961258 | 0.931583 | 0.967577 | 1.00136  | 1.03379  | 1.02014  | 1.02137  |
# | 0 | 1.01387  | 0.928264 |    0     | 0.932497 | 1.02685  |    0     | 1.05542  | 1.03213  |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+

# %%
plt.figure()
plt.imshow(dd, cmap='viridis')  # You can change the colormap if desired
plt.title('2D Array Plot')
plt.colorbar()  # Adds a colorbar to show the scale
plt.clim([0.9,1.1])
plt.show()

# %% [markdown]
# ## Clean up by deleting unwanted files

# %%
def delete_runtime_files(directory='.'):
    """
    Deletes all files with a .xml extension, files named statepoint.NNNNN.h5 where N is a digit,
    and the file named summary.h5 in the specified directory.

    Parameters:
    directory (str): The directory to search for files. Defaults to the current directory.
    """
    
    # Regular expression pattern to match files named statepoint.NNNNN.h5
    pattern = re.compile(r'statepoint\.\d{5}\.h5')

    # Iterate through files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if the file has a .xml extension, matches the pattern, or is named summary.h5
        if filename.endswith('.xml') or pattern.match(filename) or filename == 'summary.h5' \
           or filename == 'tallies.out':
            # Delete the file
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")


# Example usage:
# delete_runtime_files('/path/to/directory')  # specify the directory path if needed

# %%
delete_runtime_files('./')
delete_runtime_files(my_path)
# Out:
# Deleted: ./model.xml
# Deleted: ./mgxs_casl_2e/tallies.out
# Deleted: ./mgxs_casl_2e/summary.h5
# Deleted: ./mgxs_casl_2e/statepoint.00150.h5
# Deleted: ./mgxs_casl_2e/statepoint.01580.h5
