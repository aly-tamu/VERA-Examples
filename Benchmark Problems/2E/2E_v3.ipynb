# %% [markdown]
# # Fuel assembly: 2E

# %% [markdown]
# ## Import modules

# %%
import sys
import os
import pathlib
import re

import openmc
import openmc.mgxs as mgxs

import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import Counter
from prettytable import PrettyTable

# %% [markdown]
# ## Add location of OpenMC XS executable, setup ENDF xs path

# %%
# Add path to OpenMC binary
# os.environ['PATH'] += r':/path/to/openmc/bin'
#os.environ['PATH'] += r':/Users/jean.ragusa/repo/openmc/local/bin'

# Add location of OpenMC xs data
#%env OPENMC_CROSS_SECTIONS=/Users/jean.ragusa/repo/endfb-vii.1-hdf5/cross_sections.xml

# Are you ragusa?
your_files = os.getcwd()
print(your_files)
if 'ragusa' in your_files:
    os.environ['OPENMC_CROSS_SECTIONS'] = '/home/ragusa/xs/endfb-viii.0-hdf5/cross_sections.xml'
# Out:
# /home/brent10/github/VERA-Examples/Benchmark Problems/2E

# %% [markdown]
# # Start model

# %%
model=openmc.Model()

# %% [markdown]
# ## Define Materials
# ***

# %%
uo2 = openmc.Material(name='uo2')

uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')

uo2.set_density('g/cm3', 10.257 )

uo2.temperature = 600

# %%
zirconium = openmc.Material(name="zirconium")

zirconium.add_nuclide('Zr90',  2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91',  4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92',  7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94',  7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96',  1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112', 4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54',  8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56',  1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57',  3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58',  4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50',  3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52',  6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53',  7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54',  1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')

zirconium.set_density('g/cm3',  6.56)

zirconium.temperature = 600

# %%
water = openmc.Material(name="water")

water.add_nuclide('H1',  4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')

water.add_s_alpha_beta('c_H_in_H2O')

water.set_density('g/cm3', 0.743)

water.temperature=600

# %%
helium = openmc.Material(name="helium")

helium.add_nuclide('He4',1, 'ao')

helium.set_density('g/cm3', 0.178E-03 )

helium.temperature=600

# %%
pyrex_mat = openmc.Material(name="pyrex_mat")

pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')

pyrex_mat.set_density('g/cm3', 2.25 )

pyrex_mat.temperature=600

# %%
SS304 = openmc.Material(name="SS304")

SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')

SS304.set_density('g/cm3', 8.00 )

SS304.temperature=600

# %%
model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#print(model.materials)

# %% [markdown]
# ## Define individiual cells
# ***

# %%
# Global surfaces
pitch = 1.26

# Fuel radii
fuel_outer_radius = openmc.ZCylinder(r=0.4096)
clad_inner_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)

# Guide tube radii
gt_inner_radius = openmc.ZCylinder(r=0.561)
gt_outer_radius = openmc.ZCylinder(r=0.602)

# Instrumentation radii
it_inner_radius = openmc.ZCylinder(r=0.559)
it_outer_radius = openmc.ZCylinder(r=0.605)

#Pyrex
Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
Outer_Tube_Inner_Radius= openmc.ZCylinder(r= 0.437)
Outer_Tube_Outer_Radius= openmc.ZCylinder(r= 0.484)

# Universe bounds
left   = openmc.XPlane(-pitch/2, boundary_type='transmission')
right  = openmc.XPlane( pitch/2, boundary_type='transmission')
bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
top    = openmc.YPlane( pitch/2, boundary_type='transmission')

# %% [markdown]
# ### Define pincell universe

# %%
def pincell():

    fuel_region  = -fuel_outer_radius
    gap_region   = +fuel_outer_radius & -clad_inner_radius
    clad_region  = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius

    fuel = openmc.Cell(name='fuel')
    fuel.region = fuel_region
    fuel.fill = uo2
    #new_fuel = uo2.clone()
    #fuel.fill = new_fuel
    
    gap = openmc.Cell(name='gap')
    gap.region = gap_region
    gap.fill = helium     
    
    clad = openmc.Cell(name='clad')
    clad.region = clad_region
    clad.fill = zirconium
    
    moderator = openmc.Cell(name='moderator')
    moderator.region = water_region
    moderator.fill = water
    
    return openmc.Universe(name='pin-univ', cells=(fuel, clad, moderator,gap))

# %% [markdown]
# ### Create guide tube universe

# %%
def guide():
    
    gt_water_in_region  = -gt_inner_radius
    gt_clad_region      = +gt_inner_radius & -gt_outer_radius
    gt_water_out_region = +gt_outer_radius & +left & -right & +bottom & -top
     
    gt_water_in = openmc.Cell(name='gt-water-in')
    gt_water_in.region = gt_water_in_region
    gt_water_in.fill = water
 
    gt_clad = openmc.Cell(name='gt-clad')
    gt_clad.region = gt_clad_region
    gt_clad.fill = zirconium

    gt_water_out = openmc.Cell(name='gt-water-out')
    gt_water_out.region = gt_water_out_region
    gt_water_out.fill = water
    
    return openmc.Universe(name='gt-univ', cells=(gt_water_in, gt_clad, gt_water_out))

# %% [markdown]
# ### Create instrumentation tube universe

# %%
def instrument():
    
    it_water_in_region  = -it_inner_radius
    it_clad_region      = +it_inner_radius & -it_outer_radius
    it_water_out_region = +it_outer_radius & +left & -right & +bottom & -top
    
    it_water_in = openmc.Cell(name='it-water-in')
    it_water_in.region = it_water_in_region
    it_water_in.fill = water

    it_clad = openmc.Cell(name='it-clad')
    it_clad.region = it_clad_region
    it_clad.fill = zirconium

    it_water_out = openmc.Cell(name='it-water-out')
    it_water_out.region = it_water_out_region
    it_water_out.fill = water

    return openmc.Universe(name='it-univ', cells=(it_water_in, it_clad, it_water_out))

# %%
def pyrex_pin():

    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +gt_outer_radius | +Outer_Tube_Outer_Radius & -gt_inner_radius | -Inner_Tube_Inner_Radius
    guide_region = +gt_inner_radius & -gt_outer_radius
    steel_region = +Outer_Tube_Inner_Radius & -Outer_Tube_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Outer_Tube_Inner_Radius 
     
    steel_cell = openmc.Cell(name='steel_cell')
    steel_cell.fill = SS304
    steel_cell.region = steel_region  
    
    gap_cell = openmc.Cell(name='gap_cell')
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    
    pyrex_cell = openmc.Cell(name='pyrex_cell')
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region  
    
    water_cell = openmc.Cell(name='water_cell')
    water_cell.fill = water
    water_cell.region = water_region
    
    guide_cell = openmc.Cell(name='guide_cell')
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    return openmc.Universe(name='py-univ', cells=(steel_cell,gap_cell,pyrex_cell,water_cell,guide_cell))

# %% [markdown]
# ### Generate universes

# %%
pc_univ  = pincell()
gt_univ  = guide()
it_univ  = instrument()
py_univ = pyrex_pin()

# %% [markdown]
# ## Generate assembly
# ***

# %%
height = 10 # height in z-dir
dr = 0.04   # cm of water that is outside assembly
one_eighth = True # either 1/8 or 1/4 of FA

# %%
def read_csv_to_2d_array(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        data = [row for row in reader]
    return np.asarray(data)

def count_frequencies(data):
    flattened_data = [item for row in data for item in row]  # Flatten 2D array into a 1D list
    cell_frequencies = Counter(flattened_data)
    print("cell name frequency:")
    total = 0
    for key, value in cell_frequencies.items():
        print(f'"{key}": {value}')
        total += value
    print("total: ",total)

csv_filepath = 'FA_cell_names_1_family.csv'

lattice_csv = read_csv_to_2d_array(csv_filepath)
count_frequencies(lattice_csv)

if lattice_csv.shape[0] != lattice_csv.shape[1]:
    raise Exception('CSV array of cell names is not square.')
    
size = lattice_csv.shape[0] #size of the assembly
# Out:
# cell name frequency:
# "fu": 264
# "p": 12
# "gt": 12
# "it": 1
# total:  289

# %% [markdown]
# ### Define assembly lattice

# %%
assembly = openmc.RectLattice()
assembly.pitch = (pitch,pitch)
assembly.lower_left = (-size*pitch/2, -size*pitch/2)

lattice_array = np.empty((size, size), dtype=openmc.universe.Universe)

for row in range(0,lattice_csv.shape[0]):
    for col in range(0,lattice_csv.shape[1]):
        if lattice_csv[row][col] == 'gt': 
            lattice_array[row][col] = gt_univ
        elif lattice_csv[row][col] == 'it':
            lattice_array[row][col] = it_univ
        elif lattice_csv[row][col] == 'fu':
            lattice_array[row][col] = pc_univ
        elif lattice_csv[row][col] == 'p':
            lattice_array[row][col] = py_univ
        else:
            mesg = 'i={},j={},cell-name {} not recognized'.format(col, row, lattice_csv[row][col])
            raise ValueError(mesg)

assembly.universes = lattice_array

# %% [markdown]
# ### Define moderator outside of the assembly

# %%
# create cell that will contain the lattice
moderator_outside_cell = openmc.Cell( name = 'water_outside', fill = water )
assembly.outer = openmc.Universe( name='outer', cells = [moderator_outside_cell] )

# %% [markdown]
# ### Define 1/8 or 1/4 of full assembly

# %%
min_x = openmc.XPlane(x0= 0.               , boundary_type='reflective')
max_x = openmc.XPlane(x0= size*pitch/2+dr  , boundary_type='reflective')
min_y = openmc.YPlane(y0= 0.               , boundary_type='reflective')
max_y = openmc.YPlane(y0= size*pitch/2+dr  , boundary_type='reflective')
min_z = openmc.ZPlane(z0=-height/2         , boundary_type='reflective')
max_z = openmc.ZPlane(z0= height/2         , boundary_type='reflective')
xy    = openmc.Plane(-1., 1.               , boundary_type='reflective')

# define root universe
root_cell = openmc.Cell( name = 'root cell', fill = assembly )

if one_eighth:
    root_cell.region = -max_x & +min_y & -xy
else:
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name = 'root universe', cells=[root_cell])

# %% [markdown]
# ## Plotting

# %%
color_opt = 'material'
root_cell.plot(origin=(5,5,0), pixels=(1500,1500), width=(15,15),color_by=color_opt,outline=True)
# Out:
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %% [markdown]
# ##  Settings
# ***

# %%
settings = openmc.Settings()

# %% [markdown]
# ### Source

# %%
bbox = openmc.BoundingBox(lower_left  = [0., 0., -height/2], 
                          upper_right = [size*pitch/2, size*pitch/2, height/2])
uniform_dist = openmc.stats.Box(bbox.lower_left, bbox.upper_right, only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings.source = source
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/stats/multivariate.py:943: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "

# %% [markdown]
# ### Destination path

# %%
my_case = '2e'
my_path = './mgxs_casl_' + my_case

# check if folder exists
path = pathlib.Path(my_path)
path.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ### Batching

# %%
test_mode = True

# %%
# add additional parameters
settings.batches =  150
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies': True, 'path':my_path}
settings.temperature['method'] = 'interpolation'

if test_mode == True:
    settings.batches = 400
    settings.inactive = 100
    settings.particles = 10000
    settings.keff_trigger = {'type':'std_dev','threshold':0.001}

model.settings = settings

# %% [markdown]
# ## Tallies
# ***

# %%
# egroup_name = 'XMAS-172'
egroup_name = 'SHEM-361'
egroup = openmc.mgxs.GROUP_STRUCTURES[egroup_name]

# %% [markdown]
# ### Power Tally

# %%
tally_power = openmc.Tally(name='power')

# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [size, size]
mesh._lower_left = [-size*pitch/2, -size*pitch/2]
mesh._upper_right = [size*pitch/2,  size*pitch/2]

# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)
tally_power.filters = [mesh_filter]

tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']

tallies = openmc.Tallies([tally_power])
# model.tallies=tallies

# %% [markdown]
# ### MGXS Tally

# %%
leg = 7
mgxs_domain = 'cell'

# %%
# Setup MGXS lib
mgxs_lib = openmc.mgxs.Library(model.geometry)
mgxs_lib.energy_groups = openmc.mgxs.EnergyGroups(egroup)
mgxs_lib.scatter_format = "legendre"
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi',
                       'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']

# Legendre order
mgxs_lib.legendre_order = leg
if leg == leg:
    mgxs_lib.correction = None

# No by_nuclide
mgxs_lib.by_nuclide = False

# MGXS domain type
mgxs_lib.domain_type = mgxs_domain
if mgxs_domain == 'cell':
    mgxs_lib.domains = model.geometry.get_all_material_cells().values()
elif mgxs_domain == 'universe':
    mgxs_lib.domains = model.geometry.get_all_universes().values()

# Construct all tallies needed for the multi-group cross section library
mgxs_lib.build_library()
mgxs_lib.check_library_for_openmc_mgxs()

mgxs_lib.add_to_tallies_file(tallies, merge=True)

model.tallies = tallies
# Out:
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 7 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
# trick to make several runs work with jupyter
try:
    sp 
    print('sp found')
    sp.close()
except NameError:
    print('sp NOT found')
# Out:
# sp NOT found

# %%
statepoint_filename = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev2
#      Commit Hash | 3f3649da086fd296cde37dcda9218514f8c16c98
#        Date/Time | 2025-03-30 16:32:50
#   OpenMP Threads | 8
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /home/brent10/nndc_hdf5/neutron/U234.h5
#  Reading U235 from /home/brent10/nndc_hdf5/neutron/U235.h5
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=591.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/brent10/openmc/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#  Reading U236 from /home/brent10/nndc_hdf5/neutron/U236.h5
#  Reading U238 from /home/brent10/nndc_hdf5/neutron/U238.h5
#  Reading O16 from /home/brent10/nndc_hdf5/neutron/O16.h5
#  Reading Zr90 from /home/brent10/nndc_hdf5/neutron/Zr90.h5
#  Reading Zr91 from /home/brent10/nndc_hdf5/neutron/Zr91.h5
#  Reading Zr92 from /home/brent10/nndc_hdf5/neutron/Zr92.h5
#  Reading Zr94 from /home/brent10/nndc_hdf5/neutron/Zr94.h5
#  Reading Zr96 from /home/brent10/nndc_hdf5/neutron/Zr96.h5
#  Reading Sn112 from /home/brent10/nndc_hdf5/neutron/Sn112.h5
#  Reading Sn114 from /home
#       380/1    1.06726    1.06609 +/- 0.00077
#       381/1    1.04776    1.06603 +/- 0.00077
#       382/1    1.04108    1.06594 +/- 0.00078
#       383/1    1.06612    1.06594 +/- 0.00077
#       384/1    1.06435    1.06593 +/- 0.00077
#       385/1    1.05936    1.06591 +/- 0.00077
#       386/1    1.07605    1.06595 +/- 0.00077
#       387/1    1.06857    1.06596 +/- 0.00076
#       388/1    1.06841    1.06596 +/- 0.00076
#       389/1    1.05211    1.06592 +/- 0.00076
#       390/1    1.05087    1.06586 +/- 0.00076
#       391/1    1.04405    1.06579 +/- 0.00076
#       392/1    1.06989    1.06580 +/- 0.00076
#       393/1    1.05542    1.06577 +/- 0.00076
#       394/1    1.05164    1.06572 +/- 0.00075
#       395/1    1.06513    1.06572 +/- 0.00075
#       396/1    1.06880    1.06573 +/- 0.00075
#       397/1    1.07317    1.06575 +/- 0.00075
#       398/1    1.09541    1.06585 +/- 0.00075
#       399/1    1.06752    1.06586 +/- 0.00075
#       400/1    1.05197    1.06581 +/- 0.00075
#  Triggers satisfied for batch 400
#  Creating state point ./mgxs_casl_2e/statepoint.00400.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.3398e+00 seconds
#    Reading cross sections          = 2.3241e+00 seconds
#  Total time in simulation          = 2.8166e+02 seconds
#    Time in transport only          = 2.7222e+02 seconds
#    Time in inactive batches        = 4.0527e+01 seconds
#    Time in active batches          = 2.4113e+02 seconds
#    Time synchronizing fission bank = 4.2949e-01 seconds
#      Sampling source sites         = 3.9885e-01 seconds
#      SEND/RECV source sites        = 3.0161e-02 seconds
#    Time accumulating tallies       = 8.1998e+00 seconds
#    Time writing statepoints        = 4.4350e-01 seconds
#  Total time for finalization       = 1.5751e+01 seconds
#  Total time elapsed                = 2.9994e+02 seconds
#  Calculation Rate (inactive)       = 24675.1 particles/second
#  Calculation Rate (active)         = 12441.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06636 +/- 0.00067
#  k-effective (Track-length)  = 1.06581 +/- 0.00075
#  k-effective (Absorption)    = 1.06814 +/- 0.00060
#  Combined k-effective        = 1.06726 +/- 0.00051
#  Leakage Fraction            = 0.00000 +/- 0.00000
#       107/1    1.18400    1.18229 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.584265640097214 for eigenvalue
#  The estimated number of batches is 1849
#       108/1    1.18394    1.18231 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.540079439619812 for eigenvalue
#  The estimated number of batches is 1834
#       109/1    1.18284    1.18232 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.4875020271755295 for eigenvalue
#  The estimated number of batches is 1813
#       110/1    1.17810    1.18227 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.464748725733281 for eigenvalue
#  The estimated number of batches is 1815
#       111/1    1.18738    1.18233 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.418428449040415 for eigenvalue
#  The estimated number of batches is 1797
#       112/1    1.18317    1.18234 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.399409720363216 for eigenvalue
#  The estimated number of batches is 1801
#       113/1    1.18292    1.18234 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.349491087176905 for eigenvalue
#  The estimated number of batches is 1780
#       114/1    1.18087    1.18233 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.340775621263865 for eigenvalue
#  The estimated number of batches is 1792
#       115/1    1.17928    1.18230 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.3323964601241896 for eigenvalue
#  The estimated number of batches is 1804
#       116/1    1.18006    1.18227 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.300374547038612 for eigenvalue
#  The estimated number of batches is 1796
#       117/1    1.18094    1.18226 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.25971384256243 for eigenvalue
#  The estimated number of batches is 1781
#       118/1    1.19274    1.18237 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.2352878056568155 for eigenvalue
#  The estimated number of batches is 1778
#       119/1    1.18907    1.18243 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.214920099735969 for eigenvalue
#  The estimated number of batches is 1779
#       120/1    1.17892    1.18240 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.1951743021061905 for eigenvalue
#  The estimated number of batches is 1780
#       121/1    1.19013    1.18248 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.169540377335941 for eigenvalue
#  The estimated number of batches is 1776
#       122/1    1.17672    1.18242 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.121950760401794 for eigenvalue
#  The estimated number of batches is 1754
#       123/1    1.18048    1.18240 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.0821266825662255 for eigenvalue
#  The estimated number of batches is 1737
#       124/1    1.17960    1.18237 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.0519574834684216 for eigenvalue
#  The estimated number of batches is 1728
#       125/1    1.18844    1.18243 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.031036442073689 for eigenvalue
#  The estimated number of batches is 1727
#       126/1    1.17661    1.18238 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.028024118715769 for eigenvalue
#  The estimated number of batches is 1740
#       127/1    1.18072    1.18236 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.982485779808597 for eigenvalue
#  The estimated number of batches is 1718
#       128/1    1.18850    1.18242 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.9448430932225325 for eigenvalue
#  The estimated number of batches is 1701
#       129/1    1.17875    1.18238 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.9364477640820006 for eigenvalue
#  The estimated number of batches is 1710
#       130/1    1.17960    1.18236 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.8946154965652044 for eigenvalue
#  The estimated number of batches is 1689
#       131/1    1.18089    1.18235 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.8617743524222887 for eigenvalue
#  The estimated number of batches is 1676
#       132/1    1.18364    1.18236 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.834817371761021 for eigenvalue
#  The estimated number of batches is 1668
#       133/1    1.18732    1.18240 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7970920697890342 for eigenvalue
#  The estimated number of batches is 1650
#       134/1    1.18002    1.18238 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.76268041196035 for eigenvalue
#  The estimated number of batches is 1634
#       135/1    1.18245    1.18238 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7396309038275226 for eigenvalue
#  The estimated number of batches is 1629
#       136/1    1.17657    1.18233 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7225384861694173 for eigenvalue
#  The estimated number of batches is 1628
#       137/1    1.17399    1.18226 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7225907018606708 for eigenvalue
#  The estimated number of batches is 1642
#       138/1    1.17218    1.18217 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.69317026395826 for eigenvalue
#  The estimated number of batches is 1630
#       139/1    1.17630    1.18212 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7115551382918595 for eigenvalue
#  The estimated number of batches is 1660
#       140/1    1.19679    1.18225 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7997768720480165 for eigenvalue
#  The estimated number of batches is 1753
#       141/1    1.18605    1.18228 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8112577896522453 for eigenvalue
#  The estimated number of batches is 1778
#       142/1    1.17615    1.18223 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7698199385969327 for eigenvalue
#  The estimated number of batches is 1754
#       143/1    1.17105    1.18214 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7511508596735097 for eigenvalue
#  The estimated number of batches is 1751
#       144/1    1.17320    1.18207 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7565942311946148 for eigenvalue
#  The estimated number of batches is 1770
#       145/1    1.19071    1.18213 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7390207321467486 for eigenvalue
#  The estimated number of batches is 1768
#       146/1    1.19437    1.18223 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.788667991481799 for eigenvalue
#  The estimated number of batches is 1829
#       147/1    1.18781    1.18228 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7687570975989844 for eigenvalue
#  The estimated number of batches is 1824
#       148/1    1.16360    1.18213 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7308316200136393 for eigenvalue
#  The estimated number of batches is 1802
#       149/1    1.18773    1.18217 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.744657360460063 for eigenvalue
#  The estimated number of batches is 1829
#       150/1    1.18789    1.18222 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.79774829073303 for eigenvalue
#  The estimated number of batches is 1895
#       151/1    1.17145    1.18213 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8231201773102756 for eigenvalue
#  The estimated number of batches is 1935
#       152/1    1.17510    1.18208 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8245359785710455 for eigenvalue
#  The estimated number of batches is 1951
#       153/1    1.18605    1.18211 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.805580412126631 for eigenvalue
#  The estimated number of batches is 1947
#       154/1    1.17635    1.18207 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7716939860806336 for eigenvalue
#  The estimated number of batches is 1927
#       155/1    1.18274    1.18207 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.738521831792075 for eigenvalue
#  The estimated number of batches is 1907
#       156/1    1.18265    1.18208 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7200832116715277 for eigenvalue
#  The estimated number of batches is 1903
#       157/1    1.18756    1.18212 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6948189572615773 for eigenvalue
#  The estimated number of batches is 1891
#       158/1    1.17735    1.18208 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.667882136497984 for eigenvalue
#  The estimated number of batches is 1877
#       159/1    1.18104    1.18208 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6408602198053783 for eigenvalue
#  The estimated number of batches is 1863
#       160/1    1.18227    1.18208 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.638801745132616 for eigenvalue
#  The estimated number of batches is 1874
#       161/1    1.18051    1.18207 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6248261996471633 for eigenvalue
#  The estimated number of batches is 1873
#       162/1    1.17740    1.18203 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.652073505722379 for eigenvalue
#  The estimated number of batches is 1914
#       163/1    1.17560    1.18199 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.629417458410664 for eigenvalue
#  The estimated number of batches is 1904
#       164/1    1.18557    1.18201 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6108626145532132 for eigenvalue
#  The estimated number of batches is 1898
#       165/1    1.18121    1.18201 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5929957688355976 for eigenvalue
#  The estimated number of batches is 1892
#       166/1    1.18371    1.18202 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5734698721656306 for eigenvalue
#  The estimated number of batches is 1885
#       167/1    1.17159    1.18195 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5585639289830135 for eigenvalue
#  The estimated number of batches is 1882
#       168/1    1.17607    1.18191 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5431374858218962 for eigenvalue
#  The estimated number of batches is 1878
#       169/1    1.18714    1.18194 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5226513974430773 for eigenvalue
#  The estimated number of batches is 1869
#       170/1    1.19119    1.18201 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.516739907730332 for eigenvalue
#  The estimated number of batches is 1876
#       171/1    1.18262    1.18201 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.509246830685597 for eigenvalue
#  The estimated number of batches is 1880
#       172/1    1.18182    1.18201 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.494857009272761 for eigenvalue
#  The estimated number of batches is 1877
#       173/1    1.18745    1.18204 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4799135236545857 for eigenvalue
#  The estimated number of batches is 1873
#       174/1    1.18338    1.18205 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4615464939073837 for eigenvalue
#  The estimated number of batches is 1866
#       175/1    1.17974    1.18204 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.439173213299155 for eigenvalue
#  The estimated number of batches is 1854
#       176/1    1.17474    1.18199 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4142820624094132 for eigenvalue
#  The estimated number of batches is 1839
#       177/1    1.19779    1.18209 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.414817156000171 for eigenvalue
#  The estimated number of batches is 1851
#       178/1    1.20395    1.18223 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.458094445914189 for eigenvalue
#  The estimated number of batches is 1910
#       179/1    1.17799    1.18220 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.440960847387517 for eigenvalue
#  The estimated number of batches is 1903
#       180/1    1.18181    1.18220 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4305708003518802 for eigenvalue
#  The estimated number of batches is 1904
#       181/1    1.17906    1.18218 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.445607794477892 for eigenvalue
#  The estimated number of batches is 1932
#       182/1    1.18718    1.18221 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.42908617308921 for eigenvalue
#  The estimated number of batches is 1925
#       183/1    1.18478    1.18223 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.415491700727099 for eigenvalue
#  The estimated number of batches is 1922
#       184/1    1.18761    1.18226 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.401784703454925 for eigenvalue
#  The estimated number of batches is 1918
#       185/1    1.17700    1.18223 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.385656429849863 for eigenvalue
#  The estimated number of batches is 1912
#       186/1    1.17974    1.18221 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3688998877975633 for eigenvalue
#  The estimated number of batches is 1905
#       187/1    1.18771    1.18225 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3486164711441955 for eigenvalue
#  The estimated number of batches is 1893
#       188/1    1.17908    1.18223 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3226812379237383 for eigenvalue
#  The estimated number of batches is 1875
#       189/1    1.17452    1.18218 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.291502612979145 for eigenvalue
#  The estimated number of batches is 1851
#       190/1    1.16295    1.18207 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2828775724521 for eigenvalue
#  The estimated number of batches is 1853
#       191/1    1.18411    1.18208 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2684231223774485 for eigenvalue
#  The estimated number of batches is 1847
#       192/1    1.17400    1.18203 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2556539437230607 for eigenvalue
#  The estimated number of batches is 1844
#       193/1    1.17867    1.18201 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.240625776284889 for eigenvalue
#  The estimated number of batches is 1837
#       194/1    1.17720    1.18199 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2234442074575416 for eigenvalue
#  The estimated number of batches is 1828
#       195/1    1.18247    1.18199 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.21064426238561 for eigenvalue
#  The estimated number of batches is 1824
#       196/1    1.18470    1.18200 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1938025371530347 for eigenvalue
#  The estimated number of batches is 1816
#       197/1    1.18546    1.18202 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1987804901529593 for eigenvalue
#  The estimated number of batches is 1832
#       198/1    1.17978    1.18201 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1831844773303475 for eigenvalue
#  The estimated number of batches is 1824
#       199/1    1.18590    1.18203 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.168141359158052 for eigenvalue
#  The estimated number of batches is 1817
#       200/1    1.17685    1.18200 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.166010199755993 for eigenvalue
#  The estimated number of batches is 1825
#       201/1    1.17176    1.18195 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.176816382814972 for eigenvalue
#  The estimated number of batches is 1847
#       202/1    1.17836    1.18193 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.169794798582658 for eigenvalue
#  The estimated number of batches is 1849
#       203/1    1.18076    1.18192 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.157195084993522 for eigenvalue
#  The estimated number of batches is 1845
#       204/1    1.17177    1.18187 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1578326149261002 for eigenvalue
#  The estimated number of batches is 1855
#       205/1    1.18244    1.18187 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1481271158532165 for eigenvalue
#  The estimated number of batches is 1854
#       206/1    1.18317    1.18188 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1303333394462394 for eigenvalue
#  The estimated number of batches is 1843
#       207/1    1.18102    1.18187 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.118685094578577 for eigenvalue
#  The estimated number of batches is 1839
#       208/1    1.18026    1.18186 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.100583474487964 for eigenvalue
#  The estimated number of batches is 1828
#       209/1    1.17964    1.18185 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.087055004628342 for eigenvalue
#  The estimated number of batches is 1822
#       210/1    1.17314    1.18181 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0906121401373 for eigenvalue
#  The estimated number of batches is 1835
#       211/1    1.18806    1.18184 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0920539169991734 for eigenvalue
#  The estimated number of batches is 1847
#       212/1    1.18617    1.18186 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0773964565812317 for eigenvalue
#  The estimated number of batches is 1839
#       213/1    1.16881    1.18179 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0591778546922486 for eigenvalue
#  The estimated number of batches is 1827
#       214/1    1.17201    1.18174 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0373538006581313 for eigenvalue
#  The estimated number of batches is 1810
#       215/1    1.17659    1.18172 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.035867884306091 for eigenvalue
#  The estimated number of batches is 1818
#       216/1    1.17948    1.18171 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.017200837566238 for eigenvalue
#  The estimated number of batches is 1805
#       217/1    1.17220    1.18166 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9995998607641563 for eigenvalue
#  The estimated number of batches is 1793
#       218/1    1.19147    1.18171 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.983365774700596 for eigenvalue
#  The estimated number of batches is 1783
#       219/1    1.18143    1.18171 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9730888386158334 for eigenvalue
#  The estimated number of batches is 1780
#       220/1    1.18707    1.18173 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9608248494295744 for eigenvalue
#  The estimated number of batches is 1774
#       221/1    1.16925    1.18167 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.947355963518998 for eigenvalue
#  The estimated number of batches is 1767
#       222/1    1.19328    1.18173 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9674565881090182 for eigenvalue
#  The estimated number of batches is 1799
#       223/1    1.17842    1.18171 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9534230376716684 for eigenvalue
#  The estimated number of batches is 1791
#       224/1    1.19068    1.18176 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9440896143796014 for eigenvalue
#  The estimated number of batches is 1789
#       225/1    1.17024    1.18170 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.941722097783243 for eigenvalue
#  The estimated number of batches is 1795
#       226/1    1.18733    1.18173 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9366172883038546 for eigenvalue
#  The estimated number of batches is 1797
#       227/1    1.18427    1.18174 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9284528219688566 for eigenvalue
#  The estimated number of batches is 1796
#       228/1    1.18432    1.18175 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9158544162849847 for eigenvalue
#  The estimated number of batches is 1789
#       229/1    1.17351    1.18171 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9099293828680337 for eigenvalue
#  The estimated number of batches is 1790
#       230/1    1.18815    1.18174 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9025494622571553 for eigenvalue
#  The estimated number of batches is 1790
#       231/1    1.18313    1.18175 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.886435425890765 for eigenvalue
#  The estimated number of batches is 1778
#       232/1    1.17899    1.18174 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.87444499209498 for eigenvalue
#  The estimated number of batches is 1772
#       233/1    1.19148    1.18178 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.870272559737594 for eigenvalue
#  The estimated number of batches is 1775
#       234/1    1.17625    1.18176 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.863869796815491 for eigenvalue
#  The estimated number of batches is 1776
#       235/1    1.19402    1.18181 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8582960666080006 for eigenvalue
#  The estimated number of batches is 1777
#       236/1    1.18054    1.18181 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8445481208849843 for eigenvalue
#  The estimated number of batches is 1768
#       237/1    1.18849    1.18184 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8355677462024844 for eigenvalue
#  The estimated number of batches is 1765
#       238/1    1.18318    1.18184 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.819911330571925 for eigenvalue
#  The estimated number of batches is 1754
#       239/1    1.17339    1.18181 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.803715770227718 for eigenvalue
#  The estimated number of batches is 1742
#       240/1    1.18433    1.18182 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.789277230221381 for eigenvalue
#  The estimated number of batches is 1732
#       241/1    1.17745    1.18180 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.778090784472746 for eigenvalue
#  The estimated number of batches is 1726
#       242/1    1.17930    1.18179 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7693336850948285 for eigenvalue
#  The estimated number of batches is 1723
#       243/1    1.17485    1.18175 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7696799983742935 for eigenvalue
#  The estimated number of batches is 1731
#       244/1    1.17602    1.18173 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7622527388404414 for eigenvalue
#  The estimated number of batches is 1730
#       245/1    1.17362    1.18169 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.77312231652606 for eigenvalue
#  The estimated number of batches is 1751
#       246/1    1.17903    1.18168 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7604175836563205 for eigenvalue
#  The estimated number of batches is 1743
#       247/1    1.18226    1.18168 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.747513736987187 for eigenvalue
#  The estimated number of batches is 1734
#       248/1    1.19329    1.18173 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.744911650619055 for eigenvalue
#  The estimated number of batches is 1738
#       249/1    1.18443    1.18175 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.732505684195378 for eigenvalue
#  The estimated number of batches is 1730
#       250/1    1.18235    1.18175 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7216257661089145 for eigenvalue
#  The estimated number of batches is 1724
#       251/1    1.18171    1.18175 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.713676373721603 for eigenvalue
#  The estimated number of batches is 1722
#       252/1    1.17771    1.18173 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.70288584015559 for eigenvalue
#  The estimated number of batches is 1715
#       253/1    1.18649    1.18175 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6925328230319727 for eigenvalue
#  The estimated number of batches is 1710
#       254/1    1.17256    1.18171 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.682880664023657 for eigenvalue
#  The estimated number of batches is 1705
#       255/1    1.17437    1.18168 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.673858542271505 for eigenvalue
#  The estimated number of batches is 1701
#       256/1    1.18242    1.18168 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6656367726709385 for eigenvalue
#  The estimated number of batches is 1697
#       257/1    1.17882    1.18167 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6540581105475733 for eigenvalue
#  The estimated number of batches is 1690
#       258/1    1.19223    1.18172 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6783954171745314 for eigenvalue
#  The estimated number of batches is 1728
#       259/1    1.17324    1.18168 +/- 0.00043
# ...
#      1547/1    1.17729    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0301035963435026 for eigenvalue
#  The estimated number of batches is 1641
#      1548/1    1.18031    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0300538740818195 for eigenvalue
#  The estimated number of batches is 1642
#      1549/1    1.18297    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0293793799791333 for eigenvalue
#  The estimated number of batches is 1641
#      1550/1    1.17603    1.18156 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028755726482358 for eigenvalue
#  The estimated number of batches is 1640
#      1551/1    1.18275    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028237282791269 for eigenvalue
#  The estimated number of batches is 1639
#      1552/1    1.19465    1.18157 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0281418557430162 for eigenvalue
#  The estimated number of batches is 1640
#      1553/1    1.19815    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0282050446357744 for eigenvalue
#  The estimated number of batches is 1641
#      1554/1    1.18030    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0275472944250499 for eigenvalue
#  The estimated number of batches is 1640
#      1555/1    1.17580    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0269972897301543 for eigenvalue
#  The estimated number of batches is 1640
#      1556/1    1.18738    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.026386918526928 for eigenvalue
#  The estimated number of batches is 1639
#      1557/1    1.18066    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025790294234683 for eigenvalue
#  The estimated number of batches is 1638
#      1558/1    1.17388    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0254246381132006 for eigenvalue
#  The estimated number of batches is 1638
#      1559/1    1.17726    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.024897488408665 for eigenvalue
#  The estimated number of batches is 1637
#      1560/1    1.18453    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0243955101952398 for eigenvalue
#  The estimated number of batches is 1637
#      1561/1    1.18952    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023724800402937 for eigenvalue
#  The estimated number of batches is 1635
#      1562/1    1.18906    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0230504146796842 for eigenvalue
#  The estimated number of batches is 1634
#      1563/1    1.17200    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229731776748137 for eigenvalue
#  The estimated number of batches is 1635
#      1564/1    1.19330    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023644813917082 for eigenvalue
#  The estimated number of batches is 1638
#      1565/1    1.18698    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0231004180931969 for eigenvalue
#  The estimated number of batches is 1638
#      1566/1    1.18275    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0224387562644779 for eigenvalue
#  The estimated number of batches is 1637
#      1567/1    1.18114    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0222953823179548 for eigenvalue
#  The estimated number of batches is 1637
#      1568/1    1.17656    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0216800720811214 for eigenvalue
#  The estimated number of batches is 1636
#      1569/1    1.17750    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214739584148051 for eigenvalue
#  The estimated number of batches is 1637
#      1570/1    1.17708    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020973946587673 for eigenvalue
#  The estimated number of batches is 1636
#      1571/1    1.17414    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204353241137618 for eigenvalue
#  The estimated number of batches is 1636
#      1572/1    1.18905    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019780010095114 for eigenvalue
#  The estimated number of batches is 1635
#      1573/1    1.18456    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0191199900117829 for eigenvalue
#  The estimated number of batches is 1633
#      1574/1    1.18758    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018446303246402 for eigenvalue
#  The estimated number of batches is 1632
#      1575/1    1.19896    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0206251872600502 for eigenvalue
#  The estimated number of batches is 1640
#      1576/1    1.18885    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0203702790956495 for eigenvalue
#  The estimated number of batches is 1641
#      1577/1    1.17704    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198083309650556 for eigenvalue
#  The estimated number of batches is 1640
#      1578/1    1.18494    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193552734501277 for eigenvalue
#  The estimated number of batches is 1639
#      1579/1    1.17612    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193272037796448 for eigenvalue
#  The estimated number of batches is 1640
#      1580/1    1.18114    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.018693106440465 for eigenvalue
#  The estimated number of batches is 1639
#      1581/1    1.18327    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180990117238888 for eigenvalue
#  The estimated number of batches is 1639
#      1582/1    1.17552    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177101478337598 for eigenvalue
#  The estimated number of batches is 1638
#      1583/1    1.18171    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017055617579926 for eigenvalue
#  The estimated number of batches is 1637
#      1584/1    1.18061    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166066394424342 for eigenvalue
#  The estimated number of batches is 1637
#      1585/1    1.18898    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166703721576775 for eigenvalue
#  The estimated number of batches is 1638
#      1586/1    1.19299    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170147113536505 for eigenvalue
#  The estimated number of batches is 1640
#      1587/1    1.18200    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164002888413703 for eigenvalue
#  The estimated number of batches is 1639
#      1588/1    1.17333    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163525080544988 for eigenvalue
#  The estimated number of batches is 1640
#      1589/1    1.17201    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163591592136667 for eigenvalue
#  The estimated number of batches is 1641
#      1590/1    1.19385    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0157396025627834 for eigenvalue
#  The estimated number of batches is 1640
#      1591/1    1.17461    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0153930863979466 for eigenvalue
#  The estimated number of batches is 1640
#      1592/1    1.18195    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147457542785452 for eigenvalue
#  The estimated number of batches is 1639
#      1593/1    1.17720    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141802130458109 for eigenvalue
#  The estimated number of batches is 1638
#      1594/1    1.17407    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0138467421118313 for eigenvalue
#  The estimated number of batches is 1638
#      1595/1    1.18518    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0131819493192356 for eigenvalue
#  The estimated number of batches is 1637
#      1596/1    1.18464    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0125456052706236 for eigenvalue
#  The estimated number of batches is 1636
#      1597/1    1.18597    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011912182478488 for eigenvalue
#  The estimated number of batches is 1635
#      1598/1    1.18274    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0117330866216734 for eigenvalue
#  The estimated number of batches is 1636
#      1599/1    1.17492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111431212777842 for eigenvalue
#  The estimated number of batches is 1635
#      1600/1    1.17466    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115921829661432 for eigenvalue
#  The estimated number of batches is 1637
#      1601/1    1.17892    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0111091804467538 for eigenvalue
#  The estimated number of batches is 1637
#      1602/1    1.17046    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011036386897514 for eigenvalue
#  The estimated number of batches is 1638
#      1603/1    1.18729    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0104155377473154 for eigenvalue
#  The estimated number of batches is 1637
#      1604/1    1.17693    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0101722166241356 for eigenvalue
#  The estimated number of batches is 1637
#      1605/1    1.18002    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102251400270015 for eigenvalue
#  The estimated number of batches is 1638
#      1606/1    1.17419    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096029800085493 for eigenvalue
#  The estimated number of batches is 1637
#      1607/1    1.20125    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009310772641225 for eigenvalue
#  The estimated number of batches is 1637
#      1608/1    1.19361    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01003134212993 for eigenvalue
#  The estimated number of batches is 1641
#      1609/1    1.18837    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0103322457331263 for eigenvalue
#  The estimated number of batches is 1643
#      1610/1    1.18598    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097721002448734 for eigenvalue
#  The estimated number of batches is 1642
#      1611/1    1.16718    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099989214196454 for eigenvalue
#  The estimated number of batches is 1643
#      1612/1    1.18902    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097935254104733 for eigenvalue
#  The estimated number of batches is 1644
#      1613/1    1.17884    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009868904941159 for eigenvalue
#  The estimated number of batches is 1645
#      1614/1    1.18538    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00923643556946 for eigenvalue
#  The estimated number of batches is 1644
#      1615/1    1.17623    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0089435196061098 for eigenvalue
#  The estimated number of batches is 1644
#      1616/1    1.17859    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008905829515394 for eigenvalue
#  The estimated number of batches is 1645
#      1617/1    1.18204    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0082770770746678 for eigenvalue
#  The estimated number of batches is 1644
#      1618/1    1.18125    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0078402208466295 for eigenvalue
#  The estimated number of batches is 1644
#      1619/1    1.16938    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0072610890245743 for eigenvalue
#  The estimated number of batches is 1643
#      1620/1    1.17142    1.18158 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007230250663518 for eigenvalue
#  The estimated number of batches is 1644
#      1621/1    1.18646    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0066032255007418 for eigenvalue
#  The estimated number of batches is 1643
#      1622/1    1.19101    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060696868892256 for eigenvalue
#  The estimated number of batches is 1642
#      1623/1    1.18579    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061795196531884 for eigenvalue
#  The estimated number of batches is 1643
#      1624/1    1.19450    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055575122805613 for eigenvalue
#  The estimated number of batches is 1642
#      1625/1    1.16829    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0053873296357614 for eigenvalue
#  The estimated number of batches is 1643
#      1626/1    1.18023    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0048340109843639 for eigenvalue
#  The estimated number of batches is 1642
#      1627/1    1.18033    1.18159 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041977923388297 for eigenvalue
#  The estimated number of batches is 1641
#      1628/1    1.19163    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038282741136422 for eigenvalue
#  The estimated number of batches is 1641
#      1629/1    1.18492    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032524589422542 for eigenvalue
#  The estimated number of batches is 1640
#      1630/1    1.19150    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029040132426896 for eigenvalue
#  The estimated number of batches is 1640
#      1631/1    1.17866    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025054245466567 for eigenvalue
#  The estimated number of batches is 1640
#      1632/1    1.17531    1.18160 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020537859066725 for eigenvalue
#  The estimated number of batches is 1639
#      1633/1    1.19327    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015243856120508 for eigenvalue
#  The estimated number of batches is 1638
#      1634/1    1.18072    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000900482333582 for eigenvalue
#  The estimated number of batches is 1637
#      1635/1    1.18718    1.18161 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004631248772617 for eigenvalue
#  The estimated number of batches is 1637
#      1636/1    1.18024    1.18161 +/- 0.00016
#  Triggers satisfied for batch 1636
#  Creating state point statepoint.01636.h5...
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.5020e+00 seconds
#    Reading cross sections          = 3.4659e+00 seconds
#  Total time in simulation          = 1.1285e+03 seconds
#    Time in transport only          = 1.1199e+03 seconds
#    Time in inactive batches        = 8.3742e+00 seconds
#    Time in active batches          = 1.1201e+03 seconds
#    Time synchronizing fission bank = 1.1071e+00 seconds
#      Sampling source sites         = 8.4232e-01 seconds
#      SEND/RECV source sites        = 2.6396e-01 seconds
#    Time accumulating tallies       = 6.2389e+00 seconds
#    Time writing statepoints        = 5.1530e-01 seconds
#  Total time for finalization       = 1.1527e+01 seconds
#  Total time elapsed                = 1.1436e+03 seconds
#  Calculation Rate (inactive)       = 119414 particles/second
#  Calculation Rate (active)         = 72135.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18174 +/- 0.00013
#  k-effective (Track-length)  = 1.18161 +/- 0.00016
#  k-effective (Absorption)    = 1.18170 +/- 0.00011
#  Combined k-effective        = 1.18170 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# Load the last statepoint file
sp = openmc.StatePoint(statepoint_filename)

# %% [markdown]
# ## MGXS Tally Outputs

# %%
xs_names = [] 
for set in (mgxs_lib.domains):
    print(set.name)
    xs_names.append(set.name)

#print(mgxs_lib.domains)
# Out:
# fuel
# clad
# moderator
# gap
# steel_cell
# gap_cell
# pyrex_cell
# water_cell
# guide_cell
# gt-water-in
# gt-clad
# gt-water-out
# it-water-in
# it-clad
# it-water-out
# water_outside

# %%
if one_eighth:
    txt = 'one_eighth'
else:
    txt = 'one_quarter'

# %%
mgxs_lib.load_from_statepoint(sp)
    
h5_file_path = my_path + f'/mgxs_{my_case}_{txt}_{egroup_name}.h5'
print(h5_file_path)

# below, no need for xs_type = 'macro' as it is the default
mgxs_lib.create_mg_library(xsdata_names=xs_names).export_to_hdf5(h5_file_path)
# Out:
# ./mgxs_casl_2e/mgxs_2e_one_eighth_SHEM-361.h5

# %% [markdown]
# ## Power Tally Outputs

# %%
computed_power_tallies = sp.get_tally()
power_tally_values = computed_power_tallies.get_values()

pin_power_file_path = my_path + f'/pinpow_{my_case}_{txt}_{egroup_name}.npy'
np.save(pin_power_file_path, power_tally_values)

# %%
for score_id in range(0,len(computed_power_tallies.scores)):
     # get name of the score
    score = computed_power_tallies.scores[score_id]
    print('score = ',score)
    # extract + shape the data
    vals = power_tally_values[:,0,score_id].reshape(17,17)
    vals = vals[8:,8:]
    
    dd = np.copy(vals)

    # multiply axis of symeetry by 2 for power display
    dd[0,:] *= 2
    dd[np.diag_indices_from(dd)] *= 2

    dd = np.flip(dd,axis=0)
    
    # normalize
    idx_fuel_cells = np.argwhere(dd>0)
    nnz_fuel_cells = np.asarray(idx_fuel_cells).shape[0]
    dd /= np.sum(dd)
    dd *= nnz_fuel_cells

    table = PrettyTable()

    n_list = [str(n) for n in range(1, 10)]
    table.field_names = n_list

    # Convert ndarray to list of lists
    data_list = dd.tolist()

    for row in data_list:
        # Format each value to 2 decimal places
        formatted_row = [f"{x:.6g}" for x in row]
        table.add_row(formatted_row)

    print(table)
# Out:
# score =  fission
# +---+---------+----------+----------+----------+---------+----------+----------+----------+
# | 1 |    2    |    3     |    4     |    5     |    6    |    7     |    8     |    9     |
# +---+---------+----------+----------+----------+---------+----------+----------+----------+
# | 0 |    0    |    0     |    0     |    0     |    0    |    0     |    0     | 1.04306  |
# | 0 |    0    |    0     |    0     |    0     |    0    |    0     | 1.02844  | 1.03716  |
# | 0 |    0    |    0     |    0     |    0     |    0    | 1.02942  |  1.023   | 1.02869  |
# | 0 |    0    |    0     |    0     |    0     |    0    | 1.04189  | 1.00677  | 1.02171  |
# | 0 |    0    |    0     |    0     | 1.03086  | 1.02445 | 0.955317 | 0.973947 | 1.00146  |
# | 0 |    0    |    0     |    0     | 1.03729  |  0.9556 |    0     | 0.932726 | 0.992757 |
# | 0 |    0    | 0.999197 | 1.02237  | 1.00032  | 0.97281 | 0.940616 | 0.973438 | 1.00137  |
# | 0 | 0.98905 | 0.959973 | 0.930116 | 0.965686 | 1.00456 | 1.03865  | 1.01891  | 1.02116  |
# | 0 | 1.01573 | 0.926391 |    0     | 0.936185 | 1.03007 |    0     | 1.05742  | 1.03143  |
# +---+---------+----------+----------+----------+---------+----------+----------+----------+
# score =  nu-fission
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4     |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     |    0     | 1.04291  |
# | 0 |    0     |    0     |    0     |    0     |    0     |    0     | 1.02851  | 1.03711  |
# | 0 |    0     |    0     |    0     |    0     |    0     |  1.0293  | 1.02299  |  1.0287  |
# | 0 |    0     |    0     |    0     |    0     |    0     | 1.04148  | 1.00685  | 1.02169  |
# | 0 |    0     |    0     |    0     | 1.03049  | 1.02407  | 0.955622 | 0.974237 | 1.00153  |
# | 0 |    0     |    0     |    0     | 1.03685  | 0.95597  |    0     | 0.933294 | 0.992908 |
# | 0 |    0     | 0.999084 | 1.02204  | 1.00029  | 0.973034 | 0.941099 | 0.973664 | 1.00137  |
# | 0 | 0.988994 | 0.960217 | 0.930619 | 0.965942 | 1.00449  | 1.03821  | 1.01876  | 1.02102  |
# | 0 | 1.01533  | 0.926889 |    0     | 0.936654 | 1.02969  |    0     | 1.05686  | 1.03124  |
# +---+----------+----------+----------+----------+----------+----------+----------+----------+
# score =  kappa-fission
# +---+----------+----------+---------+----------+----------+----------+----------+----------+
# | 1 |    2     |    3     |    4    |    5     |    6     |    7     |    8     |    9     |
# +---+----------+----------+---------+----------+----------+----------+----------+----------+
# | 0 |    0     |    0     |    0    |    0     |    0     |    0     |    0     | 1.04304  |
# | 0 |    0     |    0     |    0    |    0     |    0     |    0     | 1.02845  | 1.03715  |
# | 0 |    0     |    0     |    0    |    0     |    0     |  1.0294  |  1.023   | 1.02869  |
# | 0 |    0     |    0     |    0    |    0     |    0     | 1.04183  | 1.00678  |  1.0217  |
# | 0 |    0     |    0     |    0    | 1.03082  |  1.0244  | 0.955364 | 0.973987 | 1.00147  |
# | 0 |    0     |    0     |    0    | 1.03722  | 0.955652 |    0     | 0.932812 | 0.992778 |
# | 0 |    0     | 0.999183 | 1.02232 | 1.00031  | 0.972838 | 0.940685 | 0.973476 | 1.00137  |
# | 0 | 0.989041 | 0.960008 | 0.93019 | 0.965723 | 1.00455  | 1.03859  | 1.01889  | 1.02114  |
# | 0 | 1.01567  | 0.926463 |    0    | 0.936254 | 1.03001  |    0     | 1.05733  |  1.0314  |
# +---+----------+----------+---------+----------+----------+----------+----------+----------+

# %%
plt.figure()
plt.imshow(dd, cmap='viridis')  # You can change the colormap if desired
plt.title('2D Array Plot')
plt.colorbar()  # Adds a colorbar to show the scale
plt.clim([0.9,1.1])
plt.show()

# %% [markdown]
# ## Clean up by deleting unwanted files

# %%
def delete_runtime_files(directory='.'):
    """
    Deletes all files with a .xml extension, files named statepoint.NNNNN.h5 where N is a digit,
    and the file named summary.h5 in the specified directory.

    Parameters:
    directory (str): The directory to search for files. Defaults to the current directory.
    """
    
    # Regular expression pattern to match files named statepoint.NNNNN.h5
    pattern = re.compile(r'statepoint\.\d{5}\.h5')

    # Iterate through files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if the file has a .xml extension, matches the pattern, or is named summary.h5
        if filename.endswith('.xml') or pattern.match(filename) or filename == 'summary.h5' \
           or filename == 'tallies.out':
            # Delete the file
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")


# Example usage:
# delete_runtime_files('/path/to/directory')  # specify the directory path if needed

# %%
delete_runtime_files('./')
delete_runtime_files(my_path)
# Out:
# Deleted: ./model.xml
# Deleted: ./mgxs_casl_2e/statepoint.00400.h5
# Deleted: ./mgxs_casl_2e/tallies.out
# Deleted: ./mgxs_casl_2e/summary.h5
